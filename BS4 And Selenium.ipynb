# %%
# !pip install selenium
# Out:
# ...
#   Using cached selenium-4.3.0-py3-none-any.whl (981 kB)
# ...
#   Using cached trio-0.21.0-py3-none-any.whl (358 kB)
# ...
#   Using cached trio_websocket-0.9.2-py3-none-any.whl (16 kB)
# ...
#   Using cached outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# ...
#   Using cached wsproto-1.1.0-py3-none-any.whl (24 kB)
# ...
#   Using cached h11-0.13.0-py3-none-any.whl (58 kB)
# ...

# %%
# Importing necessary libraries
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
# Connecting to the web Browser.
driver=webdriver.Chrome(r'C:\Users\91749\Downloads\chromedriver_win32\chromedriver.exe')

# %%
# Q)1. and Q)2.
url='https://www.amazon.in/?tag=msndeskabkin-21&hvadid=72705283629710&hvqmt=e&hvbmt=be&hvdev=c&ref=pd_sl_7qhce485bd_e'
driver.get(url)

# %%
from selenium.webdriver.common.by import By

# %%
Search_btn=driver.find_element(By.CLASS_NAME,"nav-fill")
Search_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="e19b181ab8ae8ed017bee1f9a779cf6d", element="8b20fdd8-6b19-4f76-8140-1e911395df1b")>

# %%
search1=driver.find_element("xpath",'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input')
search1
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="e19b181ab8ae8ed017bee1f9a779cf6d", element="4224f0ec-5f29-4326-8248-3c2677372d43")>

# %%
search1.send_keys('Guitar')

# %%
search2=driver.find_element("xpath",'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div')
search2
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="e19b181ab8ae8ed017bee1f9a779cf6d", element="f1f56414-e5af-4500-b87e-c4fef4f20fe2")>

# %%
search2.click()

# %%
brand=driver.find_elements("xpath",'//span[@class="a-size-base-plus a-color-base a-text-normal"]')
len(brand)
# Out:
# 67

# %%
brand_name=[]
for i in brand:
    brand_name.append(i.text)
brand_name
# Out:
# ['Kadence Frontier guitar with Online Guitar learning course, Wine Red Acoustic Guitar with Die Cast Keys, Set of Strings, Strap, Picks and Bag (Wine Red, Acoustic)',
#  'Kadence Frontier Jumbo Semi Acoustic Guitar With Die Cast Keys Super Combo (Bag, 1 pack Strings, Strap, Picks, Capo, Tuner (natural)',
#  'Photron Acoustic Guitar, 38 inches Cutaway, PH38C/BK with Picks Only, Black (Without Bag, Strap and Extra Strings)',
#  'Blueberry 38C, 38" Acoustic Guitar Kit with Bag, Strap, One Pack Strings And Picks (Black)',
#  'Intern INT-38C Acoustic Guitar Kit, With Bag, Strings, Pick And Strap, Black',
#  'Juârez Acoustic Guitar, 38 Inch Cutaway, 038C with Bag, Strings, Pick and Strap, Black',
#  'Juarez Acoustic Guitar, 38 Inch Curved Body Cutaway, 38CUR with Bag, Strings, Pick and Strap, Black',
#  'Intern INT-38C Acoustic Guitar Kit, With Bag, Strings, Pick And Strap, Black',
# ...

# %%
exp_delivery=driver.find_elements("xpath",'//span[@class="a-color-base a-text-bold"]')
len(exp_delivery)
# Out:
# 58

# %%
expect_delivery=[]
for i in exp_delivery:
    expect_delivery.append(i.text)
expect_delivery
# Out:
# ['Tuesday, July 26',
#  'Wednesday, July 27',
#  'Monday, July 25',
#  'Friday, July 29',
#  'Monday, July 25',
#  'Monday, July 25',
#  'Monday, July 25',
#  'Tuesday, July 26',
#  'Monday, July 25',
#  'Monday, July 25',
#  'Monday, July 25',
#  'Monday, July 25',
#  'Monday, July 25',
#  'Monday, July 25',
#  'Monday, July 25',
#  'Monday, August 1',
#  'Monday, July 25',
#  'Monday, July 25',
#  'Monday, July 25',
#  'Tuesday, July 26',
#  'Saturday, July 30',
#  'Tuesday, August 2',
#  'Thursday, July 28',
#  'Friday, July 29',
#  'Monday, July 25',
#  'Monday, July 25',
#  'Tuesday, July 26',
#  'Monday, July 25',
#  'Friday, July 29',
#  'Monday, July 25',
#  'Monday, July 25',
#  'Monday, July 25',
#  'Monday, July 25',
#  'Wednesday, July 27',
#  'Monday, July 25',
#  'Tuesday, July 26',
#  'Monday, July 25',
#  'tomorrow, July 24',
#  'Friday, July 29',
#  'Saturday, July 30',
#  'Wednesday, August 3',
#  'Friday, July 29',
#  'Monday, July 25',
#  'Monday, July 25',
# ...

# %%
price=driver.find_elements("xpath",'//span[@class="a-price-whole"]')
len(price)
# Out:
# 69

# %%
prices=[]
for i in price:
    prices.append(i.text)
prices
# Out:
# ['6,630',
#  '6,499',
#  '',
#  '4,749',
#  '7,348',
#  '2,490',
#  '2,695',
#  '1,799',
#  '1,775',
#  '2,490',
#  '6,499',
#  '1,799',
#  '4,749',
#  '',
#  '',
#  '3,999',
#  '6,630',
#  '9,750',
#  '1,749',
#  '1,890',
#  '2,519',
#  '2,490',
#  '2,999',
#  '2,185',
#  '2,123',
#  '4,066',
#  '1,839',
#  '2,374',
#  '2,280',
#  '5,362',
#  '4,099',
#  '899',
#  '4,295',
#  '11,248',
#  '7,200',
#  '4,749',
#  '4,499',
#  '2,090',
#  '3,049',
#  '1,790',
#  '2,299',
#  '2,190',
#  '5,248',
#  '3,119',
#  '2,190',
#  '2,447',
#  '2,499',
#  '6,649',
#  '159',
#  '2,695',
#  '2,350',
#  '789',
#  '5,701',
#  '18,969',
#  '1,790',
#  '2,290',
#  '2,490',
#  '2,998',
#  '2,299',
#  '8,399',
#  '2,499',
#  '4,799',
#  '9,907',
#  '3,750',
#  '249',
#  '6,546',
#  '2,655',
#  '2,560',
#  '1,549']

# %%
# Q3. Write a python program to access the search bar and search button on images.google.com 
# scrape 10 images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes

# Connecting to the web Browser.
driver=webdriver.Chrome(r'C:\Users\91749\Downloads\chromedriver_win32\chromedriver.exe')

# %%
url='https://images.google.com/'
driver.get(url)

# %%
search_bar=driver.find_element("xpath",'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input')
search_bar
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="c6fc2e06f193bc494ea01ad53ad27532", element="88707c2b-263f-4546-a3f3-484852b17046")>

# %%
search_bar.send_keys('fruits')

# %%
search_btn=driver.find_element("xpath",'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button/div/span')
search_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="c6fc2e06f193bc494ea01ad53ad27532", element="c9cbdcb5-330e-48cc-8198-8d2f627fb128")>

# %%
search_btn.click()

# %%
image=driver.find_elements("xpath",'//span[@class="OztcRd "]')
len(image)
# Out:
# 48

# %%
images=[]
for i in image:
    images.append(i.text)
images
# Out:
# ['25 Healthiest Fruits You Can Eat - Best ...',
#  'Fruit - Wikipedia',
#  'Fruits',
#  'List of 40+ Popular Fruit Names ...',
#  'Buy Fruits Chart (50 x 70 cm) Book ...',
#  '50+ List of All Fruits Name In English ...',
#  'Fruit - English Vocabulary List and ...',
#  'How to Store Fruit to Keep them Fresh ...',
#  'high demand during Ramadan season in Kerala',
#  'Fruit Images | Free Vectors, Stock ...',
#  "11 Rare and Unusual Fruits You Can't ...",
#  'Tropical Fruits: List of 25+ Popular ...',
#  '2022 Fresh Trends report reveals top 20 ...',
#  'Fruit Antioxidants? - Diagnosis Diet',
#  '4 Best Fruits To Eat After 50, Says ...',
#  '5 Fruits To Get A Glowing Skin',
#  '10 Boring Fruits With Amazing Health ...',
#  '8 Best Power Fruits for Better Health',
#  '100+ Fruits Pictures | Download Free ...',
#  'Fruit and Diabetes - Can Diabetics Eat ...',
#  '25 Healthiest Fruits You Can Eat - Best ...',
#  '5 Fruits Names with Pictures - EngDic',
# ...

# %%
search_bar1=driver.find_element("xpath",'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input')
search_bar1
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="c6fc2e06f193bc494ea01ad53ad27532", element="0519340d-2173-401c-8431-453fc51b2a57")>

# %%
search_bar1.send_keys('cars')

# %%
search_btn2=driver.find_element("xpath",'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button/div')
search_btn2
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="c6fc2e06f193bc494ea01ad53ad27532", element="15d3b5a1-f075-4740-b0c2-2317f5a60ee2")>

# %%
search_btn2.click()

# %%
car=driver.find_elements("xpath",'//span[@class="OztcRd "]')
len(car)
# Out:
# 48

# %%
cars=[]
for i in car:
    cars.append(i.text)
cars
# Out:
# ['Here Are The Coolest New Cars For 2020',
#  'Cool Cars - Coolest Cars, SUVs and ...',
#  'These Are The 25 Fastest Cars In The ...',
#  'MG Cars Price in India - MG New Models ...',
#  'Best New Cars Coming Out in 2021 | New ...',
#  'JD Power Says Korean Cars Beat US and ...',
#  'Best Luxury Cars in India - 2022 Top 10 ...',
#  'TOP 10 Craziest Concept Cars 2021 - YouTube',
#  'Cars (film) - Wikipedia',
#  'Automobili Lamborghini - Official ...',
#  'Mercedes-Benz Cars Price in India ...',
#  'Top 10 best luxury cars 2022 | Autocar',
#  'Cars will change more in the next ...',
#  'The 12 Most Expensive Cars on the ...',
#  'Most Expensive Cars In The World (2022 ...',
#  'Carmakers move from cars to building ...',
#  '20 of the Most Luxurious Cars You Can Buy',
#  'Official Trailer: Cars (2006) - YouTube',
#  'Cars Pictures | Download Free Images ...',
#  'Volvo Car Price, Images, Reviews and ...',
#  'Top 5 fastest cars in the world right ...',
# ...

# %%
search_bar2=driver.find_element("xpath",'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input')
search_bar2
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="c6fc2e06f193bc494ea01ad53ad27532", element="a51ccf91-abae-4979-a1af-74ffe3c25e6b")>

# %%
search_bar2.send_keys('machine learning')

# %%
search_btn3=driver.find_element("xpath",'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button/div')
search_btn3
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="c6fc2e06f193bc494ea01ad53ad27532", element="962a6beb-789b-472e-b940-5bdda9e8c63d")>

# %%
search_btn3.click()

# %%
machine=driver.find_elements("xpath",'//span[@class="OztcRd "]')
len(machine)
# Out:
# 48

# %%
machine_learning=[]
for i in machine:
    machine_learning.append(i.text)
machine_learning
# Out:
# ['Machine Learning Tutorial - All the ...',
#  '10 Companies Using Machine Learning in ...',
#  'Why Machine Learning Needs Semantics ...',
#  'machine learning | artificial ...',
#  'Machine Learning',
#  'Machine learning in industry | ATRIA ...',
#  'Machine Learning vs. Deep Learning ...',
#  'An Introduction to Machine Learning ...',
#  'Machine Learning Vs. Deep Learning ...',
#  'Machine Learning - GeeksforGeeks',
#  'EURIX develops Machine Learning models ...',
#  'What Is Machine Learning and Why Is It ...',
#  'Machine Learning and Deep Learning ...',
#  'Machine learning algorithms explained ...',
#  'Machine Learning Projects Fail ...',
#  'Deep Learning vs. Machine Learning ...',
#  'Machine Learning: definition, types and ...',
#  'Machine Learning: how to choose the ...',
#  'Deep Learning Analytics Center of ...',
#  'What is machine learning? | Definition ...',
#  'Top 10 Machine Learning Algorithms',
#  'How Machine Learning Is Changing SEO ...',
# ...

# %%
search_bar3=driver.find_element("xpath",'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input')
search_bar3
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="c6fc2e06f193bc494ea01ad53ad27532", element="a51ccf91-abae-4979-a1af-74ffe3c25e6b")>

# %%
search_bar3.send_keys('guitars')

# %%
search_btn4=driver.find_element("xpath",'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button/div')
search_btn4
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="c6fc2e06f193bc494ea01ad53ad27532", element="962a6beb-789b-472e-b940-5bdda9e8c63d")>

# %%
search_btn4.click()

# %%
guitar=driver.find_elements("xpath",'//span[@class="OztcRd "]')
len(guitar)
# Out:
# 48

# %%
guitars=[]
for i in guitar:
    guitars.append(i.text)
guitars
# Out:
# ['Acoustic guitar - Wikipedia',
#  'Guitar - Wikipedia',
#  'Jasmine S35 Acoustic Guitar Natural ...',
#  'Guitar World',
#  'Guitars Pictures | Download Free Images ...',
#  'Buy Electro Acoustic Guitar Online in ...',
#  'Guitars & Basses - Musical Instruments ...',
#  'Best electric guitars under $500 of ...',
#  'Acoustic Guitars - Guitars & Basses ...',
#  'electric guitars Royalty Free Vector Image',
#  'Sigma Guitars DM-ST « Acoustic Guitar ...',
#  'The 11 Best Electric Guitars for 2021 ...',
#  'Best acoustic guitars 2022 | MusicRadar',
#  'Classical & Nylon - Guitars & Basses ...',
#  '687,521 Guitar Images, Stock Photos ...',
#  'Acoustic Guitar (एकॉस्टिक गिटार ...',
#  'The 11 most expensive guitars sold at ...',
#  'Types Of Acoustic Guitars (An ...',
#  'Bizarre Guitar',
#  'Electro Acoustic Guitars Online : Buy ...',
#  'Guitar Brando',
#  'Acoustic Guitars - Guitars & Basses ...',
#  'Gino Guitars: Your Guitar Boutique',
# ...

# %%
search_bar4=driver.find_element("xpath",'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input')
search_bar4
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="c6fc2e06f193bc494ea01ad53ad27532", element="6272bae3-d0eb-45a2-a8bd-d36059bcca51")>

# %%
search_bar4.send_keys('cakes')

# %%
search_btn5=driver.find_element("xpath",'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button/div')
search_btn5
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="c6fc2e06f193bc494ea01ad53ad27532", element="f289632a-4500-4cd1-9b62-f4fac7f41c8e")>

# %%
search_btn5.click()

# %%
cake=driver.find_elements("xpath",'//span[@class="OztcRd "]')
len(cake)
# Out:
# 48

# %%
cakes=[]
for i in cake:
    cakes.append(i.text)
cakes
# Out:
# ['Best Cake Shop in Nagpur',
#  'Sadar Sadar Nagpur',
#  'Super Simple Birthday Cake Recipe ...',
#  'Top 100 Cake Shops in Nagpur - Best ...',
#  'Round Birthday Cakes, Weight: 1 Pound ...',
#  'Best Birthday Cake {Easy and Fun ...',
#  'Best Cake Shop in Nagpur',
#  'Birthday cake recipes | BBC Good Food',
#  'Bake N Nuts (Closed Down) in Central ...',
#  'Cake - Wikipedia',
#  "Rainbow Cake Recipe | Land O'Lakes",
#  '350+ Cakes Pictures [HD] | Download ...',
#  'How To Decorate Your First Cake (Step ...',
#  'Cream Layer Cake Recipe ...',
#  'Fancy Cakes Shop In Hasanbag Nagpur',
#  '4 Extra-Special Birthday Cakes ...',
#  'Chocolate Fingers Cake - Bake Play Smile',
#  'Peppa Pig Birthday Cake | Kit Kat Cake ...',
#  'One Bowl Chocolate Cake Recipe | Allrecipes',
#  'Birthday cake decorating ...',
#  'Wedding cake - Wikipedia',
#  'Baking recipes | BBC Good Food',
#  'Birthday Cake Hacks ...',
#  'Top 10 Cake Delivery Services in Nagpur ...',
# ...

# %%
Google=pd.DataFrame()
Google['Fruits']=images
Google['Cars']=cars
Google['Machine_learning']=machine_learning
Google['Guitars']=guitars
Google['Cake']=cakes
Google.head()
# Out:
#                                         Fruits  \
# 0  25 Healthiest Fruits You Can Eat - Best ...
# 1                            Fruit - Wikipedia
# 2                                       Fruits
# 3          List of 40+ Popular Fruit Names ...
# 4       Buy Fruits Chart (50 x 70 cm) Book ...
#
#                                          Cars  \
# 0      Here Are The Coolest New Cars For 2020
# 1      Cool Cars - Coolest Cars, SUVs and ...
# 2    These Are The 25 Fastest Cars In The ...
# 3  MG Cars Price in India - MG New Models ...
# 4  Best New Cars Coming Out in 2021 | New ...
#
#                              Machine_learning  \
# 0     Machine Learning Tutorial - All the ...
# 1  10 Companies Using Machine Learning in ...
# 2    Why Machine Learning Needs Semantics ...
# 3           machine learning | artificial ...
# 4                            Machine Learning
#
#                                        Guitars  \
# 0                  Acoustic guitar - Wikipedia
# ...

# %%
# Q4.Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.)

# %%
url='https://www.flipkart.com/'
driver.get(url)

# %%
search_bar=driver.find_element("xpath",'/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input')
search_bar
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="afe9c95af948a9f924126c52002822a0", element="b41bf398-5d17-404b-9239-9aad1b08f79a")>

# %%
search_bar.send_keys('Oneplus mobile')

# %%
search_btn=driver.find_element("xpath",'/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button')
search_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="afe9c95af948a9f924126c52002822a0", element="f2ef5ad7-0729-4eb7-87cc-2572e53de9da")>

# %%
search_btn.click()

# %%
brand=driver.find_elements("xpath",'//div[@class="_4rR01T"]')
len(brand)
# Out:
# 24

# %%
brands=[]
for i in brand:
    brands.append(i.text)
brands
# Out:
# ['OnePlus OnePlus 5 (Slate Gray, 128 GB)',
#  'OnePlus One (Silk White, 16 GB)',
#  'OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)',
#  'OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)',
#  'OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)',
#  'OnePlus Nord 2T 5G (Jade Fog, 128 GB)',
#  'OnePlus Nord 2T 5G (Jade Fog, 256 GB)',
#  'OnePlus 10R 5G (Forest Green, 256 GB)',
#  'OnePlus 10R 5G (Sierra Black, 256 GB)',
#  'OnePlus 9RT 5G (Hacker Black, 128 GB)',
#  'OnePlus 9RT 5G (Hacker Black, 256 GB)',
#  'OnePlus Nord 2T 5G (Gray Shadow, 128 GB)',
#  'OnePlus 9 5G (Astral Black, 256 GB)',
#  'OnePlus Nord CE 5G (Blue Void, 128 GB)',
#  'OnePlus 10R 5G (Sierra Black, 128 GB)',
#  'OnePlus 10R 5G (Forest Green, 128 GB)',
#  'OnePlus 10R 5G (Sierra Black, 256 GB)',
#  'OnePlus Nord CE 2 5G (Gray Mirror, 128 GB)',
#  'OnePlus 9RT 5G (Nano Silver, 128 GB)',
#  'OnePlus Nord 2 5G (Blue Haze, 128 GB)',
#  'OnePlus 9 5G (Winter Mist, 256 GB)',
#  'OnePlus 9 5G (Astral Black, 128 GB)',
# ...

# %%
price=driver.find_elements("xpath",'//div[@class="_30jeq3 _1_WHN1"]')
len(price)
# Out:
# 24

# %%
prices=[]
for i in price:
    prices.append(i.text)
prices
# Out:
# ['₹37,999',
#  '₹18,998',
#  '₹19,848',
#  '₹21,999',
#  '₹19,853',
#  '₹28,999',
#  '₹33,999',
#  '₹40,864',
#  '₹41,287',
#  '₹39,400',
#  '₹44,999',
#  '₹28,985',
#  '₹41,699',
#  '₹24,999',
#  '₹35,479',
#  '₹35,177',
#  '₹41,375',
#  '₹24,988',
#  '₹41,499',
#  '₹29,125',
#  '₹41,300',
#  '₹39,999',
#  '₹28,999',
#  '₹37,990']

# %%
Ram=driver.find_elements("xpath",'//li[@class="rgWa7D"]')
len(Ram)
# Out:
# 123

# %%
Rom=[]
for i in Ram:
    Rom.append(i.text)
Rom
# Out:
# ['8 GB RAM | 128 GB ROM',
#  '13.97 cm (5.5 inch) Full HD Display',
#  '16MP + 20MP | 16MP Front Camera',
#  '3300 mAh Battery',
#  'Qualcomm Snapdragon 835 Processor',
#  'Brand Warranty of 1 Year Available for Mobile and 6 Months for Accessories',
#  '3 GB RAM | 16 GB ROM',
#  '13.97 cm (5.5 inch) Full HD Display',
#  '13MP Rear Camera | 5MP Front Camera',
#  '3100 mAh Li-Polymer Battery',
#  'Qualcomm Snapdragon 801 Processor',
#  'Brand Warranty of 1 Year Available for Mobile and 6 Months for Accessories',
#  '6 GB RAM | 128 GB ROM',
#  '16.74 cm (6.59 inch) Display',
#  '64MP Rear Camera',
#  '5000 mAh Battery',
#  '12 months',
#  '8 GB RAM | 128 GB ROM',
#  '16.74 cm (6.59 inch) Display',
#  '64MP Rear Camera',
#  '5000 mAh Battery',
#  '12 months',
#  '6 GB RAM | 128 GB ROM',
#  '16.74 cm (6.59 inch) Display',
#  '64MP Rear Camera | 16MP Front Camera',
#  '5000 mAh Battery',
#  '12 months',
#  '8 GB RAM | 128 GB ROM',
#  '17.02 cm (6.7 inch) Display',
#  '50MP Rear Camera',
# ...

# %%
mobile=pd.DataFrame()
mobile['Brand_Name']=brands
mobile['Price']=prices
mobile.head()
# Out:
#                                        Brand_Name    Price
# 0          OnePlus OnePlus 5 (Slate Gray, 128 GB)  ₹37,999
# 1                 OnePlus One (Silk White, 16 GB)  ₹18,998
# 2  OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)  ₹19,848
# 3   OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)  ₹21,999
# 4   OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)  ₹19,853

# %%
from bs4 import BeautifulSoup
import requests

# %%
# Q6. Write a program to scrap details of all the funding deals for second quarter (i.e Jan 21 – March 21)

# %%
fund=driver.find_elements("xpath",'//td[@class="column-2"]')
len(fund)
# Out:
# 392

# %%
funds=[]
for i in fund:
    funds.append(i.text)
funds
# Out:
# ['01/04/2021',
#  '05/04/2021',
#  '14/04/2021',
#  '07/04/2021',
#  '14/04/2021',
#  '04/03/2021',
#  '31/03/2021',
#  '30/03/2021',
#  '30/03/2021',
#  '23/03/2021',
#  '25/03/2021',
#  '26/03/2021',
#  '11/02/2021',
#  '22/02/2021',
#  '19/02/2021',
#  '17/02/2021',
#  '15/02/2021',
#  '12/02/2021',
#  '12/02/2021',
#  '09/02/2021',
#  '09/02/2021',
#  '15/01/2021',
#  '28/01/2021',
#  '19/01/2021',
#  '19/01/2021',
#  '18/01/2021',
#  '18/01/2021',
#  '11/01/2021',
#  '13/01/2021',
#  '15/12/2020',
#  '21/12/2020',
#  '15/12/2020',
#  '22/12/2020',
#  '15/12/2020',
#  '18/12/2020',
#  '30/11/2020',
#  '30/11/2020',
#  '29/11/2020',
#  '27/11/2020',
#  '25/11/2020',
#  '25/11/2020',
#  '25/11/2020',
#  '24/11/2020',
#  '30/11/2020',
#  '23/11/2020',
#  '28/10/2020',
#  '28/10/2020',
#  '28/10/2020',
#  '27/10/2020',
#  '27/10/2020',
#  '27/10/2020',
#  '27/10/2020',
#  '15/10/2020',
#  '26/10/2020',
#  '28/10/2020',
#  '08/09/2020',
#  '12/09/2020',
#  '09/09/2020',
# ...

# %%
company=driver.find_elements("xpath",'//td[@class="column-3"]')
len(company)
# Out:
# 392

# %%
company_name=[]
for i in company:
    company_name.append(i.text)
company_name
# Out:
# ['BYJU’S',
#  'Meesho',
#  'Swiggy',
#  'Groww',
#  'Beldara',
#  'DealShare',
#  'Uniphore',
#  'Dunzo',
#  'BYJU’S',
#  'SkilloVilla',
#  'CityMall',
#  'DotPe',
#  'Doubtnut',
#  'Zomato',
#  'Fingerlix',
#  'Zolve',
#  'KreditBee',
#  'Pepperfry',
#  'Grofers',
#  'Nothing',
#  'SplashLearn',
#  'Digit Insurance',
#  'Bombay Shaving Company',
#  'DeHaat',
#  'Darwinbox',
#  'mfine',
#  'Udayy',
#  'True Elements',
#  'Saveo',
#  'Bira 91',
#  'Pine Labs',
#  'Zenoti',
#  'Tax Buddy India',
#  'Delhivery',
#  'PagarBook',
#  'Codingal',
#  'CRED',
#  'Bira 91',
#  'Chumbak',
#  'Cityflo',
#  'Shipsy',
#  'Unacademy',
#  'Cashfree',
#  'Credgenics',
#  'Country Delight',
#  'Nykaa',
#  'Betterplace',
#  'FlexiLoans',
#  'GetVantage',
#  'FreshToHome',
#  'Origo',
#  'Origo',
#  'Treebo Hotels',
#  'Hubilo',
#  'CredAble',
#  'Byju’s',
#  'mCaffeine',
#  'Qshala',
#  'Winzo',
#  'Hippo Video',
#  'Melorra',
#  '1mg',
#  'mfine',
#  'Apna',
#  'Railofy',
#  'Practo',
#  'Medlife',
# ...

# %%
industry=driver.find_elements("xpath",'//td[@class="column-4"]')
len(industry)
# Out:
# 392

# %%
industries=[]
for i in industry:
    industries.append(i.text)
industries
# Out:
# ['Edu-tech',
#  'E-commerce',
#  'Online Food Delivery',
#  'FinTech',
#  'E-commerce',
#  'E-commerce',
#  'Technology',
#  'E-commerce',
#  'Edu-tech',
#  'Edu-tech',
#  'E-commerce',
#  'FinTech',
#  'Edu Tech',
#  'Hospitality',
#  'Hospitality',
#  'FinTech',
#  'Finance',
#  'E-commerce',
#  'E-Commerce',
#  'Technology',
#  'EdTech',
#  'Financial Services',
#  'Consumer Goods Company',
#  'AgriTech Startup',
#  'SaaS',
#  'Health Tech Startup',
#  'EdTech',
#  'Food Startup',
#  'B2B E-commerce',
#  'Food and Beverage',
#  'Financial Services',
#  'Technology Provider',
#  'FinTech',
#  'Supply chain',
#  'SaaS',
#  'EduTech',
#  'Financial Services',
#  'Food and Beverage',
#  'Lifestyle',
#  'Transportation',
#  'SaaS',
#  'Edutech',
#  'FinTech',
#  'Fintech',
#  'Dairy Tech',
#  'E-commerce',
#  'Digital Solutions',
#  'FinTech',
#  'FinTech',
#  'E-commerce',
#  'AgriTech',
#  'Advertising',
#  'Hospitality',
#  'Information Technology',
#  'FinTech',
#  'EduTech',
# ...

# %%
sub=driver.find_elements("xpath",'//td[@class="column-5"]')
len(sub)
# Out:
# 392

# %%
verified=[]
for i in sub:
    verified.append(i.text)
verified
# Out:
# ['Online tutoring',
#  'Online reselling platform',
#  'Online Food Delivery',
#  'Investment platform',
#  'Global B2B marketplace',
#  'Online shopping platform',
#  'Conversational Service Automation (CSA)',
#  'Hyper-local delivery app',
#  'Online tutoring',
#  'Career and job-oriented upskilling.',
#  'Social ecommerce and online grocery platform',
#  'Commerce and payments platform to offline enterprise businesses.',
#  'E-Learning Platform',
#  'Online Food Delivery Platform',
#  'Semi-cooked food delivery app',
#  'Global Neobank Venture',
#  'Digital lending platform',
#  'Multi-brand furniture brand',
#  'Online supermarket',
#  'Consumer Technology Venture',
#  'Game-based learning programme',
#  'Insurance Services',
#  'Shave care, beard care, and skincare products',
#  'online marketplace for farm products and services',
#  'HR Tech',
#  'AI-powered telemedicine mobile app',
#  'Online learning platform for kids in class 1-5',
#  'Whole Food plant based Nashta',
# ...

# %%
city=driver.find_elements("xpath",'//td[@class="column-6"]')
len(city)
# Out:
# 392

# %%
cities=[]
for i in city:
    cities.append(i.text)
cities
# Out:
# ['Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Mumbai',
#  'Jaipur, Rajasthan',
#  'Palo Alto',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'Gurgaon',
#  'Gurgaon',
#  'Gurgaon',
#  'Gurgaon',
#  'Mumbai',
#  'Mumbai',
#  'Bengaluru',
#  'Mumbai',
#  'Gurgaon',
#  'London',
#  'Gurgaon',
#  'Bengaluru',
#  'New Delhi',
#  'Patna',
#  'Mumbai',
#  'Bengaluru',
#  'Gurgaon',
#  'Pune',
#  'Bengaluru',
#  'New Delhi',
#  'Noida',
#  'Washington',
#  'Mumbai',
#  'Gurgaon',
#  'Bengaluru',
#  'Bengaluru',
#  'Bengaluru',
#  'New Delhi',
#  'Bengaluru',
#  'Mumbai',
#  'Gurgaon',
#  'Bengaluru',
#  'Bengaluru',
#  'Gurgaon',
#  'Gurugram',
#  'Mumbai',
#  'Bangalore',
#  'Mumbai',
#  'Mumbai',
#  'Bangalore',
#  'Gurgaon',
#  'Mumbai',
#  'Bangalore',
#  'Wilmington, Delaware, United States',
#  'Mumbai',
#  'Bangalore',
#  'Mumbai',
#  'Bangalore',
#  'New Delhi',
#  'Newark, Delaware, United States of Amercia',
#  'Bangalore',
#  'Gurgaon',
#  'Bangalore',
# ...

# %%
name=driver.find_elements("xpath",'//td[@class="column-7"]')
len(name)
# Out:
# 392

# %%
investor=[]
for i in name:
    investor.append(i.text)
investor
# Out:
# ['Innoven Capital',
#  'SoftBank Vision Fund 2',
#  'Amansa Holdings, Carmignac, Falcon Edge Capital, Goldman Sachs, Think Investments',
#  'MC Global Edtech, B Capital, Baron, others',
#  'Hindustan Media Ventures',
#  'Innoven Capital',
#  'Sorenson Capital Partners',
#  'Krishtal Advisors Pte Ltd',
#  'MC Global Edtech, B Capital, Baron, others',
#  'Titan Capital, others',
#  'Accel Partners',
#  'PayU',
#  'SIG Global, Sequoia Capital, WaterBridge Ventures and ON Mauritius',
#  'Tiger Global, Kora',
#  'Rhodium Trust, Accel Partners and Swiggy',
#  'Accel Partners and Lightspeed Venture Partners',
#  'Azim Premji’s PremjiInvest and South Korea’s Mirae Asset Venture',
#  'InnoVen Capital',
#  'SoftBank Vision Fund (SVF)',
#  'GV',
#  'Owl Ventures',
#  'A91 Partners, Faering Capital, TVS Capital Funds',
#  'Reckitt Benckiser',
#  'Prosus Ventures',
#  'Salesforce Ventures',
#  'Heritas Capital Management',
#  'Sequoia Capital',
#  'SIDBI Venture Capital',
# ...

# %%
invest=driver.find_elements("xpath",'//td[@class="column-8"]')
len(invest)
# Out:
# 392

# %%
investment=[]
for i in invest:
    investment.append(i.text)
investment
# Out:
# ['Series F',
#  'Series E',
#  'Series J',
#  'Series D',
#  'Venture',
#  'Debt Financing',
#  'Series D',
#  'Series E',
#  'Series F',
#  'Seed',
#  'Series A',
#  'Series A',
#  'Series B',
#  'Venture',
#  'Series C',
#  'Seed',
#  'Series C',
#  'Debt Financing',
#  'Unspecified',
#  'Series A',
#  'Series C',
#  'Venture',
#  'Venture',
#  'Series C',
#  'Seed',
#  'Venture Round',
#  'Seed Funding',
#  'Series',
#  'Seed',
#  'Funding',
#  'Secondary Market',
#  'Series D',
#  'Seed',
#  'Secondary Market',
#  'Series A',
#  'Seed',
#  'Series C',
#  'Bridge Funding',
#  'Pre-series E',
#  'Series A',
#  'Series A',
#  'Venture',
#  'Series B',
#  'Pre-Series A',
#  'Series C',
#  'Personal Investment',
#  'Series B',
#  'Equity and Debt',
#  'Seed',
#  'Series C',
#  'Debt',
#  'Series A',
#  '',
#  'Seed',
#  'Follow-On',
#  'Private Equity',
#  'Series B',
#  'Angel',
#  'Series B',
#  'Series A',
#  'Debt Financing',
#  'In Progress',
#  'Series B',
#  'Series A',
# ...

# %%
amount=driver.find_elements("xpath",'//td[@class="column-9"]')
len(amount)
# Out:
# 392

# %%
Amount=[]
for i in amount:
    Amount.append(i.text)
Amount
# Out:
# ['460,000,000',
#  '300,000,000',
#  '343,000,000',
#  '83,000,000',
#  '7,400,000',
#  '250,000,000',
#  '140,000,000',
#  '8,000,000',
#  '460,000,000',
#  '300,000,000',
#  '11,000,000',
#  '27,500,000',
#  '2,500,000',
#  '250,000,000',
#  '2,747,045.20',
#  '1,50,00,000',
#  '75,000,000',
#  '4,773,958',
#  '55,000,000',
#  '15,000,000',
#  '18,000,000',
#  '1,80,00,000',
#  '6,172,258.50',
#  '30,000,000',
#  '15,000,000',
#  '16,000,000',
#  '15,000,000',
#  '100,000,000',
#  '4,000,000',
#  '1,273,634.07',
#  'Undisclosed',
#  '160,000,000',
#  '1,000,000',
#  '25,000,000',
#  '15,000,000',
#  '560,000',
#  '80,000,000',
#  '3,000,000',
#  '1,001,047.92',
#  '7,700,000',
#  '6,003,806',
#  '75,000,000-100,000,000',
#  '35,300,000',
#  '3,500,000',
#  '25,000,000',
#  'NA',
#  '10,000,000',
#  '20,160,000',
#  '5,000,000',
#  '121,000,000',
#  '4,700,000',
#  '15,000,000',
#  '6,000,000',
#  '4,500,000',
#  '4,500,000',
#  '500,000,000',
#  '3,000,000',
#  '370,000',
# ...

# %%
funding=pd.DataFrame()
funding['Date']=funds
funding['Startup Name']=company_name
funding['Industry']=industries
funding['Sub-Vertical']=verified
funding['City']=cities
funding['Investor Name']=investor
funding['Investment Type']=investment
funding['Amount in USD']=Amount
funding.head()
# Out:
#          Date Startup Name              Industry               Sub-Vertical  \
# 0  01/04/2021       BYJU’S              Edu-tech            Online tutoring
# 1  05/04/2021       Meesho            E-commerce  Online reselling platform
# 2  14/04/2021       Swiggy  Online Food Delivery       Online Food Delivery
# 3  07/04/2021        Groww               FinTech        Investment platform
# 4  14/04/2021      Beldara            E-commerce     Global B2B marketplace
#
#         City                                      Investor Name  \
# 0  Bengaluru                                    Innoven Capital
# 1  Bengaluru                             SoftBank Vision Fund 2
# 2  Bengaluru  Amansa Holdings, Carmignac, Falcon Edge Capita...
# 3  Bengaluru         MC Global Edtech, B Capital, Baron, others
# 4     Mumbai                           Hindustan Media Ventures
#
#   Investment Type Amount in USD
# 0        Series F   460,000,000
# 1        Series E   300,000,000
# ...

# %%
# Q)7. Write a program to scrap all the available details of best gaming laptops from digit.in.

url='https://www.digit.in/'
driver.get(url)

# %%
msi=driver.find_elements("xpath",'//div[@class="TopNumbeHeading sticky-footer"]')
len(msi)
# Out:
# 9

# %%
MSI=[]
for i in msi:
    MSI.append(i.text)
MSI
# Out:
# ['1.\nMSI TITAN GT77-12UHS',
#  '3.\nACER PREDATOR TRITON 500 SE PT516-52S',
#  '4.\nOMEN BY HP (16-B1371TX)',
#  '5.\nACER PREDATOR HELIOS 300 AN515-45 (NH.QBRSI.0',
#  '6.\nMSI DELTA 15 (A5EFK-083IN)',
#  '7.\nOMEN BY HP (16-C0141AX)',
#  '8.\nLENOVO LEGION 5I PRO (82RF00MGIN)',
#  '9.\nALIENWARE M15 R5 RYZEN EDITION ICC-C780001WIN',
#  '10.\nLENOVO SLIM 7 GEN 6 (82K8002JIN)']

# %%
window=driver.find_elements("xpath",'//div[@class="value"]')
len(window)
# Out:
# 40

# %%
windows=[]
for i in window:
    windows.append(i.text)
windows
# Out:
# ['WINDOWS 11 HOME OS',
#  '17.3" (3840 X 2160) DISPLAY',
#  '12TH GEN INTEL CORE I9-12900HX | NA PROCESSOR',
#  '2 TB SSD/64 GB DDR5 MEMORY',
#  'WINDOWS 11 HOME OS',
#  '17.3" (1920X1080) DISPLAY',
#  '12TH GEN INTEL CORE I9-12900HK | 5.00 GHZ PROCESSOR',
#  '1 TB SSD/32 GB DDR5 MEMORY',
#  'WINDOWS 11 HOME OS',
#  '16" (2560 X 1600) DISPLAY',
#  '12TH GEN INTEL CORE I7-12700H | 3.50 GHZ PROCESSOR',
#  '2 TB SSD/32 GB DDR5 MEMORY',
#  'WINDOWS 11 HOME OS',
#  '16.1" (2560 X 1440) DISPLAY',
#  '12TH GEN INTEL CORE I7-12700H | 4.7 GHZ PROCESSOR',
#  '1 TB SSD/8 GB DDR5 MEMORY',
#  'WINDOWS 11 HOME OS',
#  '15.6" (2560 X 1440) DISPLAY',
#  'AMD RYZEN 9-5900HX | NA PROCESSOR',
#  '512 GB SSD/16 GB DDR4 MEMORY',
#  'WINDOWS 11 HOME OS',
#  '15.6" (1920 X 1080) DISPLAY',
#  'AMD 5TH GEN RYZEN 9-5900HX | 3.3GHZ PROCESSOR',
#  '1 TB SSD/16 GB DDR4 MEMORY',
#  'WINDOWS 11 HOME OS',
#  '16.1" (2560 X 1440) DISPLAY',
#  'AMD RYZEN™ 9 5900HX | 3.3 GHZ PROCESSOR',
# ...

# %%
price=driver.find_elements("xpath",'//td[@class="smprice"]')
len(price)
# Out:
# 10

# %%
prices=[]
for i in price:
    prices.append(i.text)
prices
# Out:
# ['N/A',
#  '₹ 389,990',
#  '₹ 300,000',
#  '₹ 170,990',
#  '₹ 172,999',
#  '₹ 188,990',
#  '₹ 129,899',
#  '₹ 230,890',
#  '₹ 144,990',
#  '₹ 142,990']

# %%
del prices[0]

# %%
prices
# Out:
# ['₹ 389,990',
#  '₹ 300,000',
#  '₹ 170,990',
#  '₹ 172,999',
#  '₹ 188,990',
#  '₹ 129,899',
#  '₹ 230,890',
#  '₹ 144,990',
#  '₹ 142,990']

# %%
laptop=pd.DataFrame()
laptop['Brand_name']=MSI
laptop['Price']=prices
laptop.head()
# Out:
#                                           Brand_name      Price
# 0                           1.\nMSI TITAN GT77-12UHS  ₹ 389,990
# 1          3.\nACER PREDATOR TRITON 500 SE PT516-52S  ₹ 300,000
# 2                        4.\nOMEN BY HP (16-B1371TX)  ₹ 170,990
# 3  5.\nACER PREDATOR HELIOS 300 AN515-45 (NH.QBRSI.0  ₹ 172,999
# 4                     6.\nMSI DELTA 15 (A5EFK-083IN)  ₹ 188,990

# %%
from bs4 import BeautifulSoup
import requests

# %%
# Q)8. Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be 

url='https://www.forbes.com/real-time-billionaires/#23a9b5b43d78'
driver.get(url)

# %%
name=driver.find_elements("xpath",'//div[@class="ng-scope"]')
len(name)
# Out:
# 165

# %%
names=[]
for i in name:
    names.append(i.text)
names
# Out:
# ['',
#  '',
#  '',
#  'Today’s Winners and Losers\nReflects changes since 5pm EST of prior trading day\n$936 M\nWarren Buffett\n$700 M\nHarold Hamm\n$691 M\nColin Zheng Huang\n$661 M\nBernard Arnault\n$638 M\nWilliam Lei Ding\n- $758 M\nJeff Bezos\n- $866 M\nRobin Zeng\n- $922 M\nMark Zuckerberg\n- $949 M\nElon Musk\n- $2.9 B\nMukesh Ambani',
#  'Filter list by:\nOLDEST\nYOUNGEST\nWOMEN\nINDUSTRY\nCOUNTRY/TERRITORY',
#  'OLDEST',
#  '1',
#  'Elon Musk',
#  '$252.4 B',
#  '51',
#  'Tesla, SpaceX',
#  'United States',
#  '2',
#  'Bernard Arnault & family',
#  '$157.8 B',
#  '73',
#  'LVMH',
#  'France',
#  '3',
#  'Jeff Bezos',
#  '$147.2 B',
#  '58',
#  'Amazon',
#  'United States',
#  '4',
#  'Gautam Adani & family',
#  '$116.4 B',
#  '60',
#  'infrastructure, commodities',
#  'India',
#  '5',
#  'Bill Gates',
#  '$105.0 B',
#  '66',
#  'Microsoft',
#  'United States',
#  '6',
#  'Larry Ellison',
#  '$103.8 B',
#  '77',
#  'software',
#  'United States',
#  '7',
#  'Warren Buffett',
# ...

# %%
# Q)5. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google

# !pip install geopy

# %%
from geopy.geocoders import ArcGIS

# %%
nom=ArcGIS()

# %%
nom.geocode('London')
# Out:
# Location(London, Greater London, England, (51.507408360000056, -0.12769869299995662, 0.0))

# %%
nom.geocode('Delhi')
# Out:
# Location(Delhi, Connaught Place, New Delhi, Delhi, (28.63409000000007, 77.21693000000005, 0.0))

# %%
# Q)9. Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted from any YouTube Video.

# !pip install youtube-comment-scraper-python
# Out:
# ...
#   Created wheel for youtube-comment-scraper-python: filename=youtube_comment_scraper_python-1.0.0-py3-none-any.whl size=2499 sha256=5a9204905b6dbfb43ff4f16e015836d21bf15248b0395d1f52b6c7eb211dfc18
#   Stored in directory: c:\users\91749\appdata\local\pip\cache\wheels\86\31\e4\ddf67abcab05e0648915e34601631657c1c9c6b60ce67fc8f9
# ...
#   Created wheel for bot-studio: filename=bot_studio-1.4.0-py3-none-any.whl size=55391279 sha256=e9445f78a8b19a8220567168f1da106389a6087a73a7d5ea532414721dc62d5f
#   Stored in directory: c:\users\91749\appdata\local\pip\cache\wheels\34\bd\42\d1df11be0be60bb4272430ce77f26516b187fc374a607448b2
# Successfully built youtube-comment-scraper-python bot-studio
# ...

# %%
from youtube_comment_scraper_python import *
import pandas as pd

link = input("Youtube links: ")
saved = input("Output name: ")
youtube.open(link)

response = youtube.video_comments()
data = response['body']

df = pd.DataFrame(data)
df.to_csv(saved)
# Out:
# Starting DataKund...
# Youtube links: https://www.youtube.com/watch?v=4dgW1JeCAgA
# Output name: youtube.csv
# Progress: 100%|████████████████████████████████████████████████████████████████████| 200.0/200 [00:34<00:00,  5.74it/s]

# %%
all_data = []
for i in range(0, 10): # It will scroll 10 times
    response = youtube.video_comments()
    data = response['body']
    all_data.extend(data)
df = pd.DataFrame(data)
df.to_csv(saved)
# Out:
# Progress:  71%|████████████████████████████████████████████████▎                   | 142.2/200 [00:53<00:36,  1.60it/s]
# Progress:  74%|██████████████████████████████████████████████████▏                 | 147.6/200 [01:05<01:07,  1.29s/it]
# Progress:  82%|███████████████████████████████████████████████████████▍            | 163.0/200 [01:12<00:26,  1.37it/s]
# Progress:  89%|████████████████████████████████████████████████████████████▋       | 178.4/200 [01:14<00:09,  2.24it/s]
# Progress:  97%|█████████████████████████████████████████████████████████████████▉  | 193.8/200 [01:20<00:02,  2.35it/s]
# Progress: 210.40000000000003it [01:28,  1.96it/s]
# Progress: 212.8it [01:30,  1.84it/s]                                                | 78.2/200 [00:32<00:56,  2.17it/s]
# Progress: 216.60000000000002it [01:32,  1.83it/s]                                   | 82.0/200 [00:34<00:55,  2.12it/s]
# ...

# %%
you=pd.read_csv('youtube.csv')

# %%
you.head(100)
# Out:
#     Unnamed: 0                                            Comment  Likes  \
# 0            0  This shows that how much they all have enjoyed...     21
# 1            1  Sonu sir  deserves all the respect because he ...    281
# 2            2  Agarwal sahab really sang wellAfter all their ...    177
# 3            3  The prank on Chandan and Rajiv was amazing. I ...     99
# 4            4  It shows how grounded and lovely person deepik...     45
# ..         ...                                                ...    ...
# 95          95            Sonu sir is real hero baki entertainers      6
# 96          96                                Sonu is a real hero      0
# 97          97                                 real hero sonu sir      0
# 98          98  None of them insulted anyone it was all about ...      0
# 99          99                             the prank omg. so real      1
#
#              Time                                           UserLink  \
# ...
