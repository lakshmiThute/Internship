# %%
# Importing necessary libraries for web scrapping flight price data.

import pandas as pd
import selenium
from selenium import webdriver
import time
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import warnings
warnings.filterwarnings('ignore')

# %%
# Connecting to the webdriver.

driver = webdriver.Chrome(r'C:\Users\91749\Downloads\chromedriver_win32\chromedriver.exe')

# %%
# Getting the desired url.
url='https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BOM&destinationCountry=IN&flexi=0&flight_depart_date=21%2F09%2F2022&hb=0&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=1663597293098&viewName=normal'
driver.get(url)

# %% [markdown]
# # Scrapping data for Mumbai and Delhi Loacation.

# %%
airline=driver.find_elements("xpath",'//span[@class="i-b text ellipsis"]')
len(airline)
# Out:
# 158

# %%
Airline=[]
for i in airline:
    Airline.append(i.text)
Airline
# Out:
# ['Go First',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'Go First',
#  'SpiceJet',
#  'Go First',
#  'SpiceJet',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Air India',
#  'Vistara',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'SpiceJet',
#  'IndiGo',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'Air India',
#  'Go First',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Vistara',
#  'IndiGo',
#  'Air Asia',
#  'Go First',
#  'Air Asia',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Go First',
#  'SpiceJet',
#  'SpiceJet',
# ...

# %%
flight_no=driver.find_elements("xpath",'//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]')
len(flight_no)
# Out:
# 158

# %%
Flight_no=[]
for i in flight_no:
    Flight_no.append(i.text)
Flight_no
# Out:
# ['G8-2501',
#  'G8-334',
#  'G8-336',
#  'SG-8709',
#  'G8-330',
#  'SG-8701',
#  'G8-323',
#  'SG-711',
#  '6E-5306',
#  '6E-2138',
#  '6E-5023',
#  '6E-5342',
#  '6E-5318',
#  '6E-2519',
#  '6E-2009',
#  '6E-2112',
#  '6E-2176',
#  '6E-864',
#  '6E-2017',
#  '6E-5328',
#  'UK-975',
#  'AI-887',
#  'UK-933',
#  'AI-805',
#  'AI-814',
#  'AI-678',
#  'AI-863',
#  'AI-441',
#  'AI-624',
#  'UK-945',
#  'AI-605',
#  'AI-865',
#  'AI-636',
#  'UK-929/956',
#  'SG-8169',
#  '6E-6814',
#  'AI-665',
#  '6E-153/6794',
#  '6E-6939/6794',
#  '6E-2114',
#  'UK-951',
#  'UK-941',
#  '6E-153/605',
#  'AI-443/400',
#  'G8-717/413',
#  'UK-955',
#  'UK-929/918',
#  'UK-969/918',
#  '6E-2141/5302',
#  '6E-2141/803',
#  '6E-2175/577',
#  'AI-471/644',
#  'UK-927',
#  '6E-2033/605',
#  'I5-745/338',
#  'G8-2511/352',
#  'I5-744/632',
#  'SG-272/945',
#  'SG-8963/945',
#  'SG-8171/487',
#  '6E-607/605',
#  '6E-2033/6004',
#  '6E-607/6004',
#  'I5-798/472',
#  'I5-548/338',
#  'I5-552/472',
# ...

# %%
source=driver.find_elements('xpath','//p[@class="fs-10 font-lightgrey no-wrap city ellipsis"]')
len(source)
# Out:
# 316

# %%
sources=[]
for i in source:
    sources.append(i.text)
sources
# Out:
# ['New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
#  'New Delhi',
#  'Mumbai',
# ...

# %%
list1 = [sources[i] for i in range(len(sources)) if i % 2 != 0]

# %%
len(list1)
# Out:
# 158

# %%
list1
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %%
list2=sources[::2]

# %%
len(list2)
# Out:
# 158

# %%
list2
# Out:
# ['New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
# ...

# %%
duration_tag=driver.find_elements("xpath",'//p[@class="fs-12 bold du mb-2"]')
len(duration_tag)
# Out:
# 158

# %%
duration=[]
for i in duration_tag:
    duration.append(i.text)
duration
# Out:
# ['2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '1h 55m',
#  '2h 00m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 25m',
#  '2h 00m',
#  '2h 05m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 20m',
#  '2h 20m',
#  '2h 35m',
#  '3h 40m',
#  '25h 55m',
#  '2h 15m',
#  '2h 10m',
#  '2h 10m',
#  '5h 05m',
#  '7h 20m',
#  '2h 15m',
#  '2h 10m',
#  '2h 10m',
#  '9h 55m',
#  '4h 40m',
#  '6h 50m',
#  '2h 20m',
#  '8h 55m',
#  '12h 05m',
#  '5h 10m',
#  '6h 05m',
#  '7h 25m',
#  '4h 50m',
#  '2h 05m',
#  '5h 15m',
#  '5h 20m',
#  '6h 00m',
#  '6h 05m',
#  '6h 20m',
#  '6h 45m',
#  '6h 45m',
#  '7h 00m',
#  '7h 45m',
#  '9h 30m',
#  '10h 55m',
#  '11h 00m',
#  '13h 05m',
#  '14h 00m',
#  '14h 05m',
#  '15h 10m',
#  '17h 10m',
#  '18h 45m',
#  '23h 45m',
#  '4h 20m',
#  '5h 15m',
#  '7h 10m',
#  '5h 10m',
# ...

# %%
arr_t=driver.find_elements("xpath",'//div[@class="fs-15 bold time"]')
len(arr_t)
# Out:
# 158

# %%
Arr_t=[]
for i in arr_t:
    Arr_t.append(i.text)
Arr_t
# Out:
# ['02:40',
#  '08:15',
#  '15:45',
#  '19:00',
#  '20:50',
#  '07:20',
#  '18:20',
#  '21:40',
#  '15:25',
#  '11:55',
#  '06:30',
#  '10:45',
#  '17:00',
#  '23:35',
#  '02:00',
#  '05:30',
#  '14:10',
#  '16:15',
#  '18:10',
#  '09:35',
#  '05:55',
#  '07:00',
#  '15:30',
#  '20:00',
#  '22:30',
#  '09:00',
#  '14:00',
#  '17:55',
#  '19:00',
#  '11:40',
#  '21:15',
#  '10:00',
#  '14:30',
#  '21:20',
#  '19:45',
#  '07:20',
#  '08:00',
#  '19:35',
#  '17:20',
#  '21:55',
#  '14:20',
#  '16:55',
#  '19:35',
#  '05:20',
#  '16:45',
#  '17:45',
#  '21:20',
#  '18:10',
#  '13:35',
#  '13:35',
#  '08:30',
#  '13:15',
#  '09:30',
#  '00:15',
#  '13:00',
#  '11:00',
#  '08:00',
#  '09:50',
#  '09:25',
#  '12:05',
#  '22:30',
#  '00:15',
#  '22:30',
#  '12:50',
#  '07:20',
#  '10:40',
#  '05:45',
#  '15:10',
#  '08:45',
#  '12:05',
#  '18:55',
#  '15:10',
#  '17:50',
#  '05:20',
#  '10:15',
#  '17:10',
#  '13:40',
#  '07:20',
#  '13:00',
#  '18:05',
#  '21:05',
#  '20:20',
#  '05:05',
# ...

# %%
dep_t=driver.find_elements("xpath",'//p[@class="bold fs-15 mb-2 pr time"]')
len(dep_t)
# Out:
# 158

# %%
Dep_t=[]
for i in dep_t:
    Dep_t.append(i.text)
Dep_t
# Out:
# ['04:50',
#  '10:25',
#  '17:55',
#  '21:10',
#  '23:00',
#  '09:35',
#  '20:35',
#  '23:55',
#  '17:20',
#  '13:55',
#  '08:35',
#  '12:50',
#  '19:05',
#  '01:40\n+ 1 day',
#  '04:10',
#  '07:40',
#  '16:20',
#  '18:25',
#  '20:25',
#  '12:00',
#  '07:55',
#  '09:05',
#  '17:40',
#  '22:10',
#  '00:40\n+ 1 day',
#  '11:15',
#  '16:15',
#  '20:10',
#  '21:15',
#  '14:00',
#  '23:35',
#  '12:35',
#  '18:10',
#  '23:15\n+ 1 day',
#  '22:00',
#  '09:30',
#  '10:10',
#  '00:40\n+ 1 day',
#  '00:40\n+ 1 day',
#  '00:10\n+ 1 day',
#  '16:30',
#  '19:05',
#  '05:30\n+ 1 day',
#  '10:00',
#  '23:35',
#  '20:05',
#  '06:15\n+ 1 day',
#  '06:15\n+ 1 day',
#  '18:45',
#  '19:40',
#  '15:55',
#  '18:05',
#  '11:35',
#  '05:30',
#  '18:20',
#  '17:00',
#  '14:05',
#  '16:10',
#  '16:10',
#  '18:50',
#  '05:30\n+ 1 day',
#  '08:00',
#  '08:00\n+ 1 day',
#  '23:45',
#  '18:20',
#  '23:45',
#  '19:45',
#  '05:15\n+ 1 day',
#  '23:55',
#  '05:15\n+ 1 day',
#  '13:40\n+ 1 day',
#  '14:55\n+ 1 day',
# ...

# %%
total_t=driver.find_elements("xpath",'//p[@class="fs-12 bold du mb-2"]')
len(total_t)
# Out:
# 158

# %%
Total_t=[]
for i in total_t:
    Total_t.append(i.text)
Total_t
# Out:
# ['2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '1h 55m',
#  '2h 00m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 25m',
#  '2h 00m',
#  '2h 05m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 20m',
#  '2h 20m',
#  '2h 35m',
#  '3h 40m',
#  '25h 55m',
#  '2h 15m',
#  '2h 10m',
#  '2h 10m',
#  '5h 05m',
#  '7h 20m',
#  '2h 15m',
#  '2h 10m',
#  '2h 10m',
#  '9h 55m',
#  '4h 40m',
#  '6h 50m',
#  '2h 20m',
#  '8h 55m',
#  '12h 05m',
#  '5h 10m',
#  '6h 05m',
#  '7h 25m',
#  '4h 50m',
#  '2h 05m',
#  '5h 15m',
#  '5h 20m',
#  '6h 00m',
#  '6h 05m',
#  '6h 20m',
#  '6h 45m',
#  '6h 45m',
#  '7h 00m',
#  '7h 45m',
#  '9h 30m',
#  '10h 55m',
#  '11h 00m',
#  '13h 05m',
#  '14h 00m',
#  '14h 05m',
#  '15h 10m',
#  '17h 10m',
#  '18h 45m',
#  '23h 45m',
#  '4h 20m',
#  '5h 15m',
#  '7h 10m',
#  '5h 10m',
# ...

# %%
total_s=driver.find_elements("xpath",'//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')
len(total_s)
# Out:
# 158

# %%
Total_s=[]
for i in total_s:
    Total_s.append(i.text)
Total_s
# Out:
# ['Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
# ...

# %%
cost=driver.find_elements("xpath",'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
len(cost)
# Out:
# 158

# %%
price=[]
for i in cost:
    price.append(i.text)
price
# Out:
# ['5,950',
#  '5,950',
#  '5,950',
#  '5,950',
#  '5,950',
#  '5,950',
#  '5,950',
#  '5,950',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '6,092',
#  '6,111',
#  '6,374',
#  '6,480',
#  '6,757',
#  '6,757',
#  '6,794',
#  '6,827',
#  '6,827',
#  '6,974',
#  '7,602',
#  '7,668',
#  '7,698',
#  '7,835',
#  '7,835',
#  '7,868',
#  '7,868',
#  '8,107',
#  '8,160',
#  '8,578',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,894',
#  '8,894',
#  '8,894',
#  '9,000',
#  '9,000',
#  '9,052',
#  '9,052',
#  '9,086',
#  '9,157',
#  '9,169',
#  '9,306',
# ...

# %%
meal_tag=driver.find_elements("xpath",'//span[@class="text"]')
len(meal_tag)
# Out:
# 80

# %%
Add_info=[]
for i in meal_tag:
    Add_info.append(i.text)
Add_info
# Out:
# ['Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
# ...

# %%
# Creating the Dataframe.

flights = pd.DataFrame({})
flights['Airline'] = Airline
flights['Destination'] = list1
flights['Source'] = list2
flights['Arrival_time'] = Arr_t
flights['Departure_time'] =Dep_t
flights['Total_Stops']=Total_s
flights['Total_Duration']=duration
flights['Additional_Info']=pd.Series(Add_info)
flights['Price']=price
flights
# Out:
#        Airline Destination     Source Arrival_time  Departure_time  \
# 0     Go First      Mumbai  New Delhi        02:40           04:50
# 1     Go First      Mumbai  New Delhi        08:15           10:25
# 2     Go First      Mumbai  New Delhi        15:45           17:55
# 3     SpiceJet      Mumbai  New Delhi        19:00           21:10
# 4     Go First      Mumbai  New Delhi        20:50           23:00
# ..         ...         ...        ...          ...             ...
# 153   Air Asia      Mumbai  New Delhi        08:10           21:20
# 154    Vistara      Mumbai  New Delhi        08:50           11:10
# 155  Air India      Mumbai  New Delhi        13:30           21:05
# 156   Go First      Mumbai  New Delhi        11:15           18:40
# 157   SpiceJet      Mumbai  New Delhi        17:35  18:25\n+ 1 day
#
#     Total_Stops Total_Duration Additional_Info   Price
# 0      Non Stop         2h 10m       Free Meal   5,950
# ...

# %% [markdown]
# # Scrapping data for Banglore and Delhi Loacation

# %%
driver = webdriver.Chrome(r'C:\Users\91749\Downloads\chromedriver_win32\chromedriver.exe')

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BLR&destinationCountry=IN&flexi=0&flight_depart_date=20%2F09%2F2022&hb=0&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=1663598550870&viewName=normal'
driver.get(url)

# %%
airline=driver.find_elements("xpath",'//span[@class="i-b text ellipsis"]')
len(airline)
# Out:
# 80

# %%
Airline=[]
for i in airline:
    Airline.append(i.text)
Airline
# Out:
# ['SpiceJet',
#  'IndiGo',
#  'Air India',
#  'Go First',
#  'IndiGo',
#  'Air Asia',
#  'Air Asia',
#  'IndiGo',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'SpiceJet',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'IndiGo',
#  'Go First',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'Vistara',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'Vistara',
# ...

# %%
flight_no=driver.find_elements("xpath",'//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]')
len(flight_no)
# Out:
# 80

# %%
Flight_no=[]
for i in flight_no:
    Flight_no.append(i.text)
Flight_no
# Out:
# ['SG-537',
#  '6E-6565',
#  'AI-815',
#  'G8-119',
#  '6E-2131',
#  'I5-768/1427',
#  'I5-1732',
#  '6E-2532',
#  'G8-330/7122',
#  'G8-346/7122',
#  'G8-330/317',
#  'G8-346/317',
#  'G8-717/804',
#  '6E-781',
#  'G8-1171/284',
#  '6E-2168/6318',
#  '6E-6187/979',
#  '6E-671/284',
#  '6E-2187/285',
#  '6E-147/6336',
#  '6E-2187/6505',
#  'SG-8190/538',
#  'SG-8938/538',
#  'AI-814/603',
#  'AI-605/603',
#  'AI-805/603',
#  'AI-441/603',
#  '6E-6823/6505',
#  '6E-2187/6352',
#  'AI-814/607',
#  'AI-605/607',
#  'AI-814/641',
#  'AI-805/607',
#  'AI-605/641',
#  'AI-441/607',
#  'AI-805/641',
#  'AI-441/641',
#  'UK-973/554',
#  '6E-2066/6874',
#  'G8-713/802',
#  'UK-935/916',
#  'UK-879/898',
#  'UK-855/868',
#  'UK-807',
#  'UK-637/658',
#  '6E-2015',
#  'UK-973/552',
#  'AI-814/639',
#  'AI-605/639',
#  'AI-805/639',
#  'AI-441/639',
#  'UK-637/652/853',
#  'UK-637/654/853',
#  'UK-637/652/843',
#  'UK-637/654/843',
#  'UK-991/554',
#  'UK-817',
#  'UK-953/853',
#  'UK-953/843',
# ...

# %%
source=driver.find_elements('xpath','//p[@class="fs-10 font-lightgrey no-wrap city ellipsis"]')
len(source)
# Out:
# 160

# %%
sources=[]
for i in source:
    sources.append(i.text)
sources
# Out:
# ['New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
#  'New Delhi',
#  'Bangalore',
# ...

# %%
list1 = [sources[i] for i in range(len(sources)) if i % 2 != 0]

# %%
len(list1)
# Out:
# 80

# %%
list1
# Out:
# ['Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
# ...

# %%
list2=sources[::2]

# %%
len(list2)
# Out:
# 80

# %%
list2
# Out:
# ['New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
# ...

# %%
arr_t=driver.find_elements("xpath",'//div[@class="fs-15 bold time"]')
len(arr_t)
# Out:
# 80

# %%
Arr_t=[]
for i in arr_t:
    Arr_t.append(i.text)
Arr_t
# Out:
# ['20:00',
#  '22:55',
#  '15:30',
#  '20:45',
#  '21:30',
#  '15:30',
#  '21:50',
#  '20:10',
#  '20:50',
#  '19:45',
#  '20:50',
#  '19:45',
#  '16:45',
#  '15:20',
#  '19:40',
#  '17:50',
#  '15:15',
#  '21:20',
#  '15:00',
#  '23:30',
#  '15:00',
#  '20:25',
#  '17:05',
#  '22:30',
#  '21:55',
#  '20:00',
#  '17:55',
#  '18:05',
#  '15:00',
#  '22:30',
#  '21:55',
#  '22:30',
#  '20:00',
#  '21:55',
#  '17:55',
#  '20:00',
#  '17:55',
#  '20:50',
#  '15:20',
#  '20:20',
#  '18:00',
#  '17:35',
#  '18:40',
#  '20:40',
#  '17:10',
#  '18:30',
#  '20:50',
#  '22:30',
#  '21:55',
#  '20:00',
#  '17:55',
#  '17:10',
#  '17:10',
#  '17:10',
#  '17:10',
#  '17:45',
#  '16:05',
#  '20:40',
#  '20:40',
#  '21:15',
#  '17:15',
#  '18:40',
#  '18:40',
#  '17:45',
#  '17:35',
#  '20:30',
#  '20:40',
#  '17:35',
#  '15:30',
#  '16:55',
#  '15:30',
#  '17:55',
#  '19:45',
#  '19:00',
#  '19:45',
#  '19:00',
#  '20:40',
#  '17:45',
#  '19:45',
#  '19:00']

# %%
dep_t=driver.find_elements("xpath",'//p[@class="bold fs-15 mb-2 pr time"]')
len(dep_t)
# Out:
# 80

# %%
Dep_t=[]
for i in dep_t:
    Dep_t.append(i.text)
Dep_t
# Out:
# ['22:30',
#  '01:45\n+ 1 day',
#  '18:20',
#  '23:25',
#  '00:15\n+ 1 day',
#  '21:00',
#  '00:35\n+ 1 day',
#  '23:00',
#  '08:30\n+ 1 day',
#  '08:30\n+ 1 day',
#  '07:35\n+ 1 day',
#  '07:35\n+ 1 day',
#  '23:30',
#  '18:15',
#  '00:10\n+ 1 day',
#  '22:40',
#  '20:30',
#  '02:35\n+ 1 day',
#  '21:35',
#  '06:05\n+ 1 day',
#  '23:40',
#  '16:50\n+ 1 day',
#  '16:50\n+ 1 day',
#  '07:50\n+ 1 day',
#  '07:50\n+ 1 day',
#  '07:50\n+ 1 day',
#  '07:50\n+ 1 day',
#  '23:40',
#  '20:40',
#  '18:20\n+ 1 day',
#  '18:20\n+ 1 day',
#  '20:40\n+ 1 day',
#  '18:20\n+ 1 day',
#  '20:40\n+ 1 day',
#  '18:20\n+ 1 day',
#  '20:40\n+ 1 day',
#  '20:40\n+ 1 day',
#  '20:30\n+ 1 day',
#  '21:45',
#  '10:45\n+ 1 day',
#  '21:50',
#  '08:45\n+ 1 day',
#  '15:55\n+ 1 day',
#  '23:20',
#  '18:15\n+ 1 day',
#  '21:15',
#  '08:30\n+ 1 day',
#  '11:10\n+ 1 day',
#  '11:10\n+ 1 day',
#  '11:10\n+ 1 day',
#  '11:10\n+ 1 day',
#  '17:45\n+ 1 day',
#  '17:45\n+ 1 day',
#  '19:15\n+ 1 day',
# ...

# %%
total_s=driver.find_elements("xpath",'//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')
len(total_s)
# Out:
# 80

# %%
Total_s=[]
for i in total_s:
    Total_s.append(i.text)
Total_s
# Out:
# ['Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  'Non Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
# ...

# %%
duration_tag=driver.find_elements("xpath",'//p[@class="fs-12 bold du mb-2"]')
len(duration_tag)
# Out:
# 80

# %%
duration=[]
for i in duration_tag:
    duration.append(i.text)
duration
# Out:
# ['2h 30m',
#  '2h 50m',
#  '2h 50m',
#  '2h 40m',
#  '2h 45m',
#  '5h 30m',
#  '2h 45m',
#  '2h 50m',
#  '11h 40m',
#  '12h 45m',
#  '10h 45m',
#  '11h 50m',
#  '6h 45m',
#  '2h 55m',
#  '4h 30m',
#  '4h 50m',
#  '5h 15m',
#  '5h 15m',
#  '6h 35m',
#  '6h 35m',
#  '8h 40m',
#  '20h 25m',
#  '23h 45m',
#  '9h 20m',
#  '9h 55m',
#  '11h 50m',
#  '13h 55m',
#  '5h 35m',
#  '5h 40m',
#  '19h 50m',
#  '20h 25m',
#  '22h 10m',
#  '22h 20m',
#  '22h 45m',
#  '24h 25m',
#  '24h 40m',
#  '26h 45m',
#  '23h 40m',
#  '6h 25m',
#  '14h 25m',
#  '3h 50m',
#  '15h 10m',
#  '21h 15m',
#  '2h 40m',
#  '25h 05m',
#  '2h 45m',
#  '11h 40m',
#  '12h 40m',
#  '13h 15m',
#  '15h 10m',
#  '17h 15m',
#  '24h 35m',
#  '24h 35m',
#  '26h 05m',
#  '26h 05m',
#  '26h 45m',
#  '2h 45m',
#  '21h 05m',
#  '22h 35m',
#  '2h 50m',
#  '3h 00m',
#  '23h 05m',
#  '24h 35m',
#  '14h 45m',
#  '2h 50m',
#  '21h 15m',
#  '14h 30m',
#  '25h 55m',
#  '5h 25m',
#  '14h 55m',
#  '16h 20m',
#  '6h 00m',
#  '22h 00m',
# ...

# %%
cost=driver.find_elements("xpath",'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
len(cost)
# Out:
# 80

# %%
price=[]
for i in cost:
    price.append(i.text)
price
# Out:
# ['7,419',
#  '7,424',
#  '7,425',
#  '7,623',
#  '7,687',
#  '7,710',
#  '7,897',
#  '8,212',
#  '8,259',
#  '8,259',
#  '8,903',
#  '8,903',
#  '9,162',
#  '9,314',
#  '9,418',
#  '9,419',
#  '9,419',
#  '9,419',
#  '9,419',
#  '9,419',
#  '9,419',
#  '9,419',
#  '9,419',
#  '9,453',
#  '9,453',
#  '9,453',
#  '9,453',
#  '9,734',
#  '9,960',
#  '10,083',
#  '10,083',
#  '10,083',
#  '10,083',
#  '10,083',
#  '10,083',
#  '10,083',
#  '10,083',
#  '10,680',
#  '11,041',
#  '11,143',
#  '11,552',
#  '11,583',
#  '11,867',
#  '11,940',
#  '12,150',
#  '12,569',
#  '12,673',
#  '12,708',
#  '12,708',
#  '12,708',
#  '12,708',
#  '12,866',
#  '12,866',
#  '12,866',
#  '12,866',
#  '13,303',
#  '14,355',
#  '14,626',
#  '14,626',
#  '14,880',
#  '14,880',
#  '15,239',
#  '15,239',
#  '15,296',
#  '16,035',
#  '16,121',
#  '16,246',
#  '19,248',
#  '19,815',
#  '19,815',
#  '19,815',
#  '20,339',
#  '21,768',
#  '21,768',
#  '21,768',
#  '21,768',
#  '22,438',
#  '24,855',
#  '29,580',
# ...

# %%
add_info=driver.find_elements("xpath",'//span[@class="text"]')
len(add_info)
# Out:
# 52

# %%
Add_info=[]
for i in add_info:
    Add_info.append(i.text)
Add_info
# Out:
# ['Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal']

# %%
flights1 = pd.DataFrame({})
flights1['Airline'] = Airline
flights1['Destination'] = list1
flights1['Source'] = list2
flights1['Arrival_time'] = Arr_t
flights1['Departure_time'] =Dep_t
flights1['Total_Stops']=Total_s
flights1['Total_Duration']=duration
flights1['Additional_Info']=pd.Series(Add_info)
flights1['Price']=price
flights1
# Out:
#       Airline Destination     Source Arrival_time  Departure_time Total_Stops  \
# 0    SpiceJet   Bangalore  New Delhi        20:00           22:30    Non Stop
# 1      IndiGo   Bangalore  New Delhi        22:55  01:45\n+ 1 day    Non Stop
# 2   Air India   Bangalore  New Delhi        15:30           18:20    Non Stop
# 3    Go First   Bangalore  New Delhi        20:45           23:25    Non Stop
# 4      IndiGo   Bangalore  New Delhi        21:30  00:15\n+ 1 day    Non Stop
# ..        ...         ...        ...          ...             ...         ...
# 75    Vistara   Bangalore  New Delhi        19:00  19:15\n+ 1 day      1 Stop
# 76    Vistara   Bangalore  New Delhi        20:40  07:50\n+ 1 day      1 Stop
# 77    Vistara   Bangalore  New Delhi        17:45  07:50\n+ 1 day      1 Stop
# 78    Vistara   Bangalore  New Delhi        19:45  07:50\n+ 1 day      1 Stop
# 79    Vistara   Bangalore  New Delhi        19:00  07:50\n+ 1 day      1 Stop
#
# ...

# %%
Flight1=pd.concat([flights, flights1], ignore_index=True)

# %%
Flight1.shape
# Out:
# (238, 9)

# %% [markdown]
# # Scrapping data for Hydrabad and Delhi Loacation

# %%
driver = webdriver.Chrome(r'C:\Users\91749\Downloads\chromedriver_win32\chromedriver.exe')

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=HYD&destinationCountry=IN&flexi=0&flight_depart_date=24%2F09%2F2022&hb=0&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=1663519857148&viewName=normal'
driver.get(url)

# %%
airline=driver.find_elements("xpath",'//span[@class="i-b text ellipsis"]')
len(airline)
# Out:
# 125

# %%
Airline=[]
for i in airline:
    Airline.append(i.text)
Airline
# Out:
# ['SpiceJet',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air India',
#  'Vistara',
#  'IndiGo',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'Vistara',
#  'Air India',
#  'Vistara',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Go First',
#  'Vistara',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Vistara',
# ...

# %%
flight_no=driver.find_elements("xpath",'//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]')
len(flight_no)
# Out:
# 125

# %%
Flight_no=[]
for i in flight_no:
    Flight_no.append(i.text)
Flight_no
# Out:
# ['SG-8103',
#  'G8-423',
#  'G8-422',
#  'SG-164',
#  '6E-2004',
#  '6E-2153',
#  '6E-6823',
#  '6E-2325',
#  '6E-2187',
#  '6E-2136',
#  '6E-2005',
#  '6E-155',
#  '6E-2331',
#  '6E-2774',
#  '6E-2104',
#  '6E-7405/471',
#  '6E-2077/7272',
#  '6E-2175/311',
#  '6E-2697/501',
#  '6E-2026/278',
#  '6E-307/523',
#  '6E-6187/7249',
#  '6E-5042/6916',
#  '6E-6267/278',
#  '6E-2077/511',
#  '6E-2191/278',
#  '6E-698/752',
#  '6E-216/7249',
#  '6E-2008/7122',
#  'UK-829',
#  'AI-560',
#  'UK-859',
#  'UK-879',
#  'UK-871',
#  'I5-798/974',
#  'I5-798/1518',
#  'I5-552/974',
#  'AI-542',
#  'UK-899',
#  '6E-7403/311',
#  'G8-346/509',
#  'G8-323/509',
#  'SG-953/4006',
#  'SG-957/3735',
#  'SG-8171/3735',
#  'SG-8211/3735',
#  'AI-839',
#  'UK-955/869',
#  'UK-941/869',
#  'AI-814/615',
#  'UK-993/869',
#  'AI-605/615',
#  'UK-953/873',
#  'AI-805/615',
#  'AI-624/615',
#  'AI-441/615',
#  'AI-863/615',
#  'AI-865/615',
#  'AI-678/615',
#  'AI-665/615',
#  'AI-887/615',
#  'G8-336/509',
# ...

# %%
source=driver.find_elements('xpath','//p[@class="fs-10 font-lightgrey no-wrap city ellipsis"]')
len(source)
# Out:
# 250

# %%
sources=[]
for i in source:
    sources.append(i.text)
sources
# Out:
# ['New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
#  'New Delhi',
#  'Hyderabad',
# ...

# %%
list1 = [sources[i] for i in range(len(sources)) if i % 2 != 0]

# %%
list1
# Out:
# ['Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
# ...

# %%
list2=sources[::2]

# %%
list2
# Out:
# ['New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
# ...

# %%
arr_t=driver.find_elements("xpath",'//div[@class="fs-15 bold time"]')
len(arr_t)
# Out:
# 125

# %%
Arr_t=[]
for i in arr_t:
    Arr_t.append(i.text)
Arr_t
# Out:
# ['18:20',
#  '05:45',
#  '18:05',
#  '21:55',
#  '12:45',
#  '13:25',
#  '18:05',
#  '01:50',
#  '15:00',
#  '21:15',
#  '09:55',
#  '22:30',
#  '06:40',
#  '07:55',
#  '19:30',
#  '15:30',
#  '05:20',
#  '08:30',
#  '06:50',
#  '15:50',
#  '05:30',
#  '15:15',
#  '10:15',
#  '14:10',
#  '05:20',
#  '12:45',
#  '21:05',
#  '11:55',
#  '06:00',
#  '07:20',
#  '07:10',
#  '10:25',
#  '17:35',
#  '20:35',
#  '12:50',
#  '12:50',
#  '10:40',
#  '09:45',
#  '14:45',
#  '07:20',
#  '19:45',
#  '17:30',
#  '14:50',
#  '15:10',
#  '12:05',
#  '09:00',
#  '21:30',
#  '17:45',
#  '16:55',
#  '22:30',
#  '12:45',
#  '21:15',
#  '20:40',
#  '20:00',
#  '19:00',
#  '17:55',
#  '14:00',
#  '10:00',
#  '09:00',
#  '08:00',
#  '07:00',
#  '14:30',
#  '17:10',
#  '14:00',
#  '10:00',
#  '09:00',
#  '08:00',
#  '07:00',
#  '17:10',
#  '11:40',
#  '07:20',
#  '17:10',
#  '13:00',
#  '13:00',
#  '08:10',
#  '09:35',
#  '08:10',
#  '09:35',
#  '13:00',
#  '07:40',
#  '05:50',
#  '15:30',
#  '14:20',
# ...

# %%
dep_t=driver.find_elements("xpath",'//p[@class="bold fs-15 mb-2 pr time"]')
len(dep_t)
# Out:
# 125

# %%
Dep_t=[]
for i in dep_t:
    Dep_t.append(i.text)
Dep_t
# Out:
# ['20:25',
#  '07:55',
#  '20:25',
#  '00:15\n+ 1 day',
#  '14:50',
#  '15:30',
#  '20:10',
#  '04:00',
#  '17:10',
#  '23:25',
#  '12:10',
#  '00:45\n+ 1 day',
#  '09:00',
#  '10:15',
#  '21:50',
#  '19:55',
#  '10:35',
#  '13:45',
#  '12:35',
#  '22:15',
#  '12:00',
#  '22:20',
#  '18:10',
#  '22:15',
#  '13:30',
#  '22:15',
#  '06:55\n+ 1 day',
#  '22:20',
#  '16:40',
#  '09:25',
#  '09:25',
#  '12:40',
#  '19:50',
#  '22:55',
#  '19:45',
#  '21:15',
#  '19:45',
#  '11:50',
#  '17:00',
#  '13:45',
#  '00:40\n+ 1 day',
#  '00:40\n+ 1 day',
#  '18:55',
#  '22:40',
#  '22:40',
#  '22:40',
#  '23:45',
#  '22:40',
#  '22:40',
#  '07:30\n+ 1 day',
#  '22:40',
#  '07:30\n+ 1 day',
#  '07:50\n+ 1 day',
#  '07:30\n+ 1 day',
#  '07:30\n+ 1 day',
#  '07:30\n+ 1 day',
#  '07:30\n+ 1 day',
#  '07:30\n+ 1 day',
#  '07:30\n+ 1 day',
#  '07:30\n+ 1 day',
#  '07:30\n+ 1 day',
#  '00:40\n+ 1 day',
#  '07:50\n+ 1 day',
#  '21:40',
#  '21:40',
#  '21:40',
#  '21:40',
#  '21:40',
#  '17:30\n+ 1 day',
# ...

# %%
duration_tag=driver.find_elements("xpath",'//p[@class="fs-12 bold du mb-2"]')
len(duration_tag)
# Out:
# 125

# %%
Duration=[]
for i in duration_tag:
    Duration.append(i.text)
Duration
# Out:
# ['2h 05m',
#  '2h 10m',
#  '2h 20m',
#  '2h 20m',
#  '2h 05m',
#  '2h 05m',
#  '2h 05m',
#  '2h 10m',
#  '2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '2h 15m',
#  '2h 20m',
#  '2h 20m',
#  '2h 20m',
#  '4h 25m',
#  '5h 15m',
#  '5h 15m',
#  '5h 45m',
#  '6h 25m',
#  '6h 30m',
#  '7h 05m',
#  '7h 55m',
#  '8h 05m',
#  '8h 10m',
#  '9h 30m',
#  '9h 50m',
#  '10h 25m',
#  '10h 40m',
#  '2h 05m',
#  '2h 15m',
#  '2h 15m',
#  '2h 15m',
#  '2h 20m',
#  '6h 55m',
#  '8h 25m',
#  '9h 05m',
#  '2h 05m',
#  '2h 15m',
#  '6h 25m',
#  '4h 55m',
#  '7h 10m',
#  '4h 05m',
#  '7h 30m',
#  '10h 35m',
#  '13h 40m',
#  '2h 15m',
#  '4h 55m',
#  '5h 45m',
#  '9h 00m',
#  '9h 55m',
#  '10h 15m',
#  '11h 10m',
#  '11h 30m',
#  '12h 30m',
#  '13h 35m',
#  '17h 30m',
#  '21h 30m',
#  '22h 30m',
#  '23h 30m',
#  '24h 30m',
#  '10h 10m',
#  '14h 40m',
#  '7h 40m',
#  '11h 40m',
#  '12h 40m',
#  '13h 40m',
#  '14h 40m',
#  '24h 20m',
#  '11h 00m',
#  '6h 35m',
#  '27h 45m',
#  '6h 45m',
#  '8h 15m',
#  '5h 45m',
# ...

# %%
total_s=driver.find_elements("xpath",'//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')
len(total_s)
# Out:
# 125

# %%
Total_s=[]
for i in total_s:
    Total_s.append(i.text)
Total_s
# Out:
# ['Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
# ...

# %%
cost=driver.find_elements("xpath",'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
len(cost)
# Out:
# 125

# %%
price=[]
for i in cost:
    price.append(i.text)
price
# Out:
# ['5,952',
#  '5,952',
#  '5,952',
#  '5,952',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,954',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '5,955',
#  '7,320',
#  '7,698',
#  '7,907',
#  '8,577',
#  '8,577',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '9,105',
#  '9,840',
#  '9,840',
#  '9,840',
#  '9,840',
#  '9,840',
#  '9,840',
#  '9,840',
#  '9,840',
#  '9,840',
#  '9,840',
#  '9,840',
#  '9,840',
#  '9,840',
#  '9,840',
#  '9,997',
#  '10,132',
#  '10,365',
#  '10,365',
#  '10,365',
#  '10,365',
#  '10,365',
#  '10,470',
#  '10,712',
#  '10,767',
#  '11,132',
#  '11,227',
#  '11,227',
#  '11,229',
#  '11,229',
#  '11,229',
#  '11,229',
#  '11,325',
#  '11,325',
#  '11,371',
# ...

# %%
Add_tag=driver.find_elements("xpath",'//span[@class="text"]')
len(Add_tag)
# Out:
# 73

# %%
Add_info=[]
for i in Add_tag:
    Add_info.append(i.text)
Add_info
# Out:
# ['Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
# ...

# %%
flights2 = pd.DataFrame({})
flights2['Airline'] = Airline
flights2['Destination'] = list1
flights2['Source'] = list2
flights2['Arrival_time'] = Arr_t
flights2['Departure_time'] =Dep_t
flights2['Total_Stops']=Total_s
flights2['Total_Duration']=Duration
flights2['Additional_Info']=pd.Series(Add_info)
flights2['Price']=price
flights2
# Out:
#        Airline Destination     Source Arrival_time  Departure_time  \
# 0     SpiceJet   Hyderabad  New Delhi        18:20           20:25
# 1     Go First   Hyderabad  New Delhi        05:45           07:55
# 2     Go First   Hyderabad  New Delhi        18:05           20:25
# 3     SpiceJet   Hyderabad  New Delhi        21:55  00:15\n+ 1 day
# 4       IndiGo   Hyderabad  New Delhi        12:45           14:50
# ..         ...         ...        ...          ...             ...
# 120  Air India   Hyderabad  New Delhi        20:15  21:15\n+ 1 day
# 121  Air India   Hyderabad  New Delhi        06:50           21:15
# 122     IndiGo   Hyderabad  New Delhi        08:45           16:45
# 123    Vistara   Hyderabad  New Delhi        13:40  12:15\n+ 1 day
# 124  Air India   Hyderabad  New Delhi        12:10           21:15
#
#     Total_Stops Total_Duration Additional_Info   Price
# 0      Non Stop         2h 05m       Free Meal   5,952
# ...

# %% [markdown]
# # Scraping data for Mumbai Banglore location.

# %%
# Connecting to the webdriver.

driver = webdriver.Chrome(r'C:\Users\91749\Downloads\chromedriver_win32\chromedriver.exe')

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=BOM&originCountry=IN&destination=BLR&destinationCountry=IN&flight_depart_date=24%2F09%2F2022&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=1590172357716'
driver.get(url)

# %%
airline=driver.find_elements("xpath",'//span[@class="i-b text ellipsis"]')
len(airline)
# Out:
# 124

# %%
Airline=[]
for i in airline:
    Airline.append(i.text)
Airline
# Out:
# ['Air India',
#  'Air India',
#  'Go First',
#  'Go First',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'Air Asia',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'Vistara',
#  'Vistara',
#  'Air Asia',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air Asia',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air Asia',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
# ...

# %%
flight_no=driver.find_elements("xpath",'//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]')
len(flight_no)
# Out:
# 124

# %%
Flight_no=[]
for i in flight_no:
    Flight_no.append(i.text)
Flight_no
# Out:
# ['AI-607',
#  'AI-641',
#  'G8-398',
#  'G8-317',
#  'AI-603',
#  'AI-639',
#  '6E-5383',
#  '6E-6819',
#  'I5-338',
#  'I5-1569',
#  '6E-6463',
#  '6E-6221',
#  '6E-6293',
#  'UK-857',
#  '6E-6258',
#  '6E-739',
#  '6E-5287',
#  '6E-5252',
#  '6E-6478',
#  'G8-383',
#  'UK-853',
#  'UK-843',
#  'I5-1784',
#  'I5-331/819',
#  '6E-192/6505',
#  '6E-5388/285',
#  '6E-136/6137',
#  '6E-5337/189',
#  '6E-908/6605',
#  '6E-5299/6892',
#  '6E-5314/285',
#  '6E-5386/6505',
#  '6E-5277/6225',
#  '6E-5388/6505',
#  '6E-136/6892',
#  '6E-5299/6605',
#  '6E-5307/6343',
#  '6E-461/827',
#  '6E-5337/6225',
#  'I5-331/1455',
#  '6E-219',
#  'UK-865',
#  'UK-845',
#  'UK-851',
#  '6E-5382',
#  '6E-128/921',
#  '6E-179/381',
#  '6E-399/589',
#  '6E-399/6806',
#  '6E-5236/172',
#  '6E-5205/7296',
#  '6E-5236/347',
#  'UK-863',
#  '6E-453/6482',
#  'UK-869/898',
#  'UK-873/894',
#  'UK-869/894',
#  'UK-873/898',
#  '6E-461/6066',
#  '6E-453/6675',
#  '6E-312/6225',
#  '6E-818/827',
#  '6E-5395/472',
# ...

# %%
source=driver.find_elements('xpath','//p[@class="fs-10 font-lightgrey no-wrap city ellipsis"]')
len(source)
# Out:
# 248

# %%
sources=[]
for i in source:
    sources.append(i.text)
sources
# Out:
# ['Mumbai',
#  'Bangalore',
#  'Mumbai',
#  'Bangalore',
#  'Mumbai',
#  'Bangalore',
#  'Mumbai',
#  'Bangalore',
#  'Mumbai',
#  'Bangalore',
#  'Mumbai',
#  'Bangalore',
#  'Mumbai',
#  'Bangalore',
#  'Mumbai',
#  'Bangalore',
#  'Mumbai',
#  'Bangalore',
#  'Mumbai',
#  'Bangalore',
#  'Mumbai',
#  'Bangalore',
#  'Mumbai',
#  'Bangalore',
#  'Mumbai',
#  'Bangalore',
#  'Mumbai',
#  'Bangalore',
#  'Mumbai',
#  'Bangalore',
#  'Mumbai',
#  'Bangalore',
#  'Mumbai',
#  'Bangalore',
#  'Mumbai',
#  'Bangalore',
#  'Mumbai',
#  'Bangalore',
#  'Mumbai',
#  'Bangalore',
#  'Mumbai',
#  'Bangalore',
#  'Mumbai',
#  'Bangalore',
#  'Mumbai',
#  'Bangalore',
#  'Mumbai',
#  'Bangalore',
#  'Mumbai',
#  'Bangalore',
#  'Mumbai',
#  'Bangalore',
#  'Mumbai',
#  'Bangalore',
#  'Mumbai',
#  'Bangalore',
#  'Mumbai',
#  'Bangalore',
#  'Mumbai',
#  'Bangalore',
#  'Mumbai',
#  'Bangalore',
#  'Mumbai',
#  'Bangalore',
#  'Mumbai',
#  'Bangalore',
#  'Mumbai',
#  'Bangalore',
#  'Mumbai',
# ...

# %%
list1 = [sources[i] for i in range(len(sources)) if i % 2 != 0]

# %%
list1
# Out:
# ['Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
# ...

# %%
list2=sources[::2]

# %%
list2
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %%
arr_t=driver.find_elements("xpath",'//div[@class="fs-15 bold time"]')
len(arr_t)
# Out:
# 124

# %%
Arr_t=[]
for i in arr_t:
    Arr_t.append(i.text)
Arr_t
# Out:
# ['16:40',
#  '19:00',
#  '20:30',
#  '05:40',
#  '06:10',
#  '09:30',
#  '22:40',
#  '00:10',
#  '19:00',
#  '21:20',
#  '07:10',
#  '17:10',
#  '07:35',
#  '21:30',
#  '06:05',
#  '20:30',
#  '08:30',
#  '19:05',
#  '09:55',
#  '16:30',
#  '16:00',
#  '17:30',
#  '22:00',
#  '04:05',
#  '19:55',
#  '17:30',
#  '05:35',
#  '15:30',
#  '09:15',
#  '07:00',
#  '16:05',
#  '18:05',
#  '16:45',
#  '17:30',
#  '05:35',
#  '07:00',
#  '10:15',
#  '06:05',
#  '15:30',
#  '04:05',
#  '14:40',
#  '19:10',
#  '06:00',
#  '07:00',
#  '11:50',
#  '04:55',
#  '11:25',
#  '16:55',
#  '16:55',
#  '08:50',
#  '18:45',
#  '08:50',
#  '09:05',
#  '06:20',
#  '21:20',
#  '06:20',
#  '21:20',
#  '06:20',
#  '06:05',
#  '06:20',
#  '17:50',
#  '07:15',
#  '17:25',
#  '17:25',
#  '13:05',
#  '18:00',
#  '10:00',
#  '17:00',
#  '09:00',
#  '16:00',
#  '08:00',
#  '07:00',
#  '10:00',
#  '09:00',
#  '20:40',
#  '21:00',
#  '08:00',
#  '07:00',
#  '19:00',
#  '18:00',
#  '17:00',
#  '19:20',
#  '19:20',
# ...

# %%
dep_t=driver.find_elements("xpath",'//p[@class="bold fs-15 mb-2 pr time"]')
len(dep_t)
# Out:
# 124

# %%
Dep_t=[]
for i in dep_t:
    Dep_t.append(i.text)
Dep_t
# Out:
# ['18:20',
#  '20:40',
#  '22:15',
#  '07:35',
#  '07:50',
#  '11:10',
#  '00:10\n+ 1 day',
#  '01:55',
#  '20:50',
#  '23:10',
#  '08:45',
#  '18:50',
#  '09:20',
#  '23:10',
#  '07:40',
#  '22:10',
#  '10:15',
#  '21:00',
#  '11:35',
#  '18:10',
#  '17:45',
#  '19:15',
#  '23:50',
#  '07:35',
#  '23:40',
#  '21:35',
#  '09:55',
#  '19:55',
#  '14:00',
#  '12:10',
#  '21:35',
#  '23:40',
#  '22:35',
#  '23:40',
#  '12:10',
#  '14:00',
#  '17:15',
#  '13:10',
#  '22:35',
#  '16:25',
#  '16:15',
#  '20:55',
#  '07:50',
#  '08:50',
#  '13:20',
#  '08:35',
#  '15:50',
#  '22:20',
#  '00:25\n+ 1 day',
#  '13:00',
#  '23:45',
#  '14:35',
#  '10:45',
#  '10:45',
#  '08:45\n+ 1 day',
#  '19:30',
#  '19:30\n+ 1 day',
#  '08:45\n+ 1 day',
#  '10:35',
#  '12:25',
#  '22:35',
#  '13:10',
#  '22:15',
#  '23:55',
#  '14:45',
#  '00:05\n+ 1 day',
#  '16:15',
#  '00:05\n+ 1 day',
#  '16:15',
#  '00:05\n+ 1 day',
#  '16:15',
#  '16:15',
#  '20:15',
#  '20:15',
#  '08:15\n+ 1 day',
# ...

# %%
duration_tag=driver.find_elements("xpath",'//p[@class="fs-12 bold du mb-2"]')
len(duration_tag)
# Out:
# 124

# %%
Duration=[]
for i in duration_tag:
    Duration.append(i.text)
Duration
# Out:
# ['1h 40m',
#  '1h 40m',
#  '1h 45m',
#  '1h 55m',
#  '1h 40m',
#  '1h 40m',
#  '1h 30m',
#  '1h 45m',
#  '1h 50m',
#  '1h 50m',
#  '1h 35m',
#  '1h 40m',
#  '1h 45m',
#  '1h 40m',
#  '1h 35m',
#  '1h 40m',
#  '1h 45m',
#  '1h 55m',
#  '1h 40m',
#  '1h 40m',
#  '1h 45m',
#  '1h 45m',
#  '1h 50m',
#  '3h 30m',
#  '3h 45m',
#  '4h 05m',
#  '4h 20m',
#  '4h 25m',
#  '4h 45m',
#  '5h 10m',
#  '5h 30m',
#  '5h 35m',
#  '5h 50m',
#  '6h 10m',
#  '6h 35m',
#  '7h 00m',
#  '7h 00m',
#  '7h 05m',
#  '7h 05m',
#  '12h 20m',
#  '1h 35m',
#  '1h 45m',
#  '1h 50m',
#  '1h 50m',
#  '1h 30m',
#  '3h 40m',
#  '4h 25m',
#  '5h 25m',
#  '7h 30m',
#  '4h 10m',
#  '5h 00m',
#  '5h 45m',
#  '1h 40m',
#  '4h 25m',
#  '11h 25m',
#  '13h 10m',
#  '22h 10m',
#  '26h 25m',
#  '4h 30m',
#  '6h 05m',
#  '4h 45m',
#  '5h 55m',
#  '4h 50m',
#  '6h 30m',
#  '1h 40m',
#  '6h 05m',
#  '6h 15m',
#  '7h 05m',
#  '7h 15m',
#  '8h 05m',
#  '8h 15m',
#  '9h 15m',
#  '10h 15m',
#  '11h 15m',
#  '11h 35m',
#  '11h 55m',
# ...

# %%
total_s=driver.find_elements("xpath",'//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')
len(total_s)
# Out:
# 124

# %%
Total_s=[]
for i in total_s:
    Total_s.append(i.text)
Total_s
# Out:
# ['Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
# ...

# %%
cost=driver.find_elements("xpath",'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
len(cost)
# Out:
# 124

# %%
price=[]
for i in cost:
    price.append(i.text)
price
# Out:
# ['2,721',
#  '2,721',
#  '2,826',
#  '2,826',
#  '3,246',
#  '4,506',
#  '4,787',
#  '4,787',
#  '5,042',
#  '5,042',
#  '5,101',
#  '5,101',
#  '5,101',
#  '5,103',
#  '5,154',
#  '5,521',
#  '5,521',
#  '5,521',
#  '5,941',
#  '6,201',
#  '6,426',
#  '6,426',
#  '6,722',
#  '7,098',
#  '7,098',
#  '7,098',
#  '7,098',
#  '7,098',
#  '7,098',
#  '7,098',
#  '7,098',
#  '7,098',
#  '7,098',
#  '7,098',
#  '7,098',
#  '7,098',
#  '7,098',
#  '7,098',
#  '7,098',
#  '7,098',
#  '7,516',
#  '7,623',
#  '7,623',
#  '7,623',
#  '7,936',
#  '8,090',
#  '8,090',
#  '8,090',
#  '8,090',
#  '8,096',
#  '8,096',
#  '8,096',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,148',
#  '8,201',
#  '8,463',
#  '8,526',
#  '9,146',
#  '9,198',
#  '9,198',
#  '9,872',
#  '10,070',
#  '10,070',
#  '10,070',
#  '10,070',
#  '10,070',
#  '10,070',
#  '10,070',
#  '10,070',
#  '10,070',
#  '10,070',
#  '10,070',
#  '10,070',
#  '10,070',
#  '10,070',
#  '10,070',
#  '10,070',
# ...

# %%
add_tag=driver.find_elements("xpath",'//span[@class="text"]')
len(add_tag)
# Out:
# 72

# %%
Add_info=[]
for i in add_tag:
    Add_info.append(i.text)
Add_info
# Out:
# ['Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
# ...

# %%
flights3 = pd.DataFrame({})
flights3['Airline'] = Airline
flights3['Destination'] = list1
flights3['Source'] = list2
flights3['Arrival_time'] = Arr_t
flights3['Departure_time'] =Dep_t
flights3['Total_Stops']=Total_s
flights3['Total_Duration']=Duration
flights3['Additional_Info']=pd.Series(Add_info)
flights3['Price']=price
flights3
# Out:
#        Airline Destination  Source Arrival_time  Departure_time Total_Stops  \
# 0    Air India   Bangalore  Mumbai        16:40           18:20    Non Stop
# 1    Air India   Bangalore  Mumbai        19:00           20:40    Non Stop
# 2     Go First   Bangalore  Mumbai        20:30           22:15    Non Stop
# 3     Go First   Bangalore  Mumbai        05:40           07:35    Non Stop
# 4    Air India   Bangalore  Mumbai        06:10           07:50    Non Stop
# ..         ...         ...     ...          ...             ...         ...
# 119  Air India   Bangalore  Mumbai        06:00           16:15   2 Stop(s)
# 120  Air India   Bangalore  Mumbai        06:00           20:15   2 Stop(s)
# 121    Vistara   Bangalore  Mumbai        08:45           17:05      1 Stop
# 122    Vistara   Bangalore  Mumbai        10:25           17:05      1 Stop
# 123  Air India   Bangalore  Mumbai        20:10  12:30\n+ 1 day   2 Stop(s)
#
#     Total_Duration Additional_Info   Price
# ...

# %% [markdown]
# # Scrapping data for Mumbai and Goa Loacation

# %%
Flight2=pd.concat([flights2,flights3],ignore_index=True)

# %%
Flight2.shape
# Out:
# (249, 9)

# %%
Flight2.head()
# Out:
#     Airline Destination     Source Arrival_time  Departure_time Total_Stops  \
# 0  SpiceJet   Hyderabad  New Delhi        18:20           20:25    Non Stop
# 1  Go First   Hyderabad  New Delhi        05:45           07:55    Non Stop
# 2  Go First   Hyderabad  New Delhi        18:05           20:25    Non Stop
# 3  SpiceJet   Hyderabad  New Delhi        21:55  00:15\n+ 1 day    Non Stop
# 4    IndiGo   Hyderabad  New Delhi        12:45           14:50    Non Stop
#
#   Total_Duration Additional_Info  Price
# 0         2h 05m       Free Meal  5,952
# 1         2h 10m       Free Meal  5,952
# 2         2h 20m       Free Meal  5,952
# 3         2h 20m       Free Meal  5,952
# 4         2h 05m       Free Meal  5,954

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=GOI&destinationCountry=IN&flexi=0&flight_depart_date=23%2F09%2F2022&hb=0&noOfSegments=1&origin=BOM&originCountry=IN&type=O&unique=1663576712823&viewName=normal'
driver.get(url)

# %%
airline=driver.find_elements("xpath",'//span[@class="i-b text ellipsis"]')
len(airline)
# Out:
# 87

# %%
Airline=[]
for i in airline:
    Airline.append(i.text)
Airline
# Out:
# ['Go First',
#  'Go First',
#  'Go First',
#  'Air Asia',
#  'Alliance Air',
#  'SpiceJet',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'Air India',
#  'IndiGo',
#  'SpiceJet',
#  'Air India',
#  'Go First',
#  'IndiGo',
#  'Air India',
#  'Vistara',
#  'SpiceJet',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air Asia',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Air Asia',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Air Asia',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'Vistara',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
# ...

# %%
flight_no=driver.find_elements("xpath",'//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]')
len(flight_no)
# Out:
# 87

# %%
Flight_no=[]
for i in flight_no:
    Flight_no.append(i.text)
Flight_no
# Out:
# ['G8-371',
#  'G8-382',
#  'G8-575',
#  'I5-679',
#  '9I-657',
#  'SG-453',
#  'I5-331',
#  '6E-711',
#  '6E-399',
#  'SG-2697/3419',
#  'AI-683',
#  '6E-977',
#  'SG-455',
#  'AI-663',
#  'G8-331',
#  '6E-128',
#  'AI-685',
#  'UK-841',
#  'SG-488',
#  'AI-687/883',
#  'AI-677/883',
#  'AI-866/883',
#  'AI-806/883',
#  'AI-864/883',
#  'AI-687/885',
#  'AI-677/885',
#  'AI-866/885',
#  'I5-338/1458',
#  'AI-660/883',
#  'AI-442/883',
#  'AI-809/883',
#  'AI-660/885',
#  'AI-442/885',
#  'AI-809/885',
#  'AI-637/532/885',
#  'AI-637/818/885',
#  'AI-637/532/883',
#  'AI-637/482/883',
#  'AI-637/818/883',
#  'UK-851/867',
#  'UK-863/867',
#  'I5-1784/816',
#  'AI-635/883',
#  'AI-635/885',
#  'AI-625/812/885',
#  'AI-864/885',
#  'AI-816/885',
#  'AI-816/883',
#  'UK-869/860/847',
#  'AI-888/883',
#  'UK-944/855',
#  'UK-994/855',
#  'I5-1569/816',
#  'UK-910/847',
#  'UK-902/847',
#  'AI-615/541/883',
#  'UK-988/855',
#  '6E-179',
#  'UK-988/847',
#  'UK-952/855',
#  'UK-960/855',
# ...

# %%
source=driver.find_elements('xpath','//p[@class="fs-10 font-lightgrey no-wrap city ellipsis"]')
len(source)
# Out:
# 174

# %%
sources=[]
for i in source:
    sources.append(i.text)
sources
# Out:
# ['Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
#  'Mumbai',
#  'Goa',
# ...

# %%
list1 = [sources[i] for i in range(len(sources)) if i % 2 != 0]

# %%
list1
# Out:
# ['Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa',
#  'Goa']

# %%
list2=sources[::2]

# %%
list2
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %%
arr_t=driver.find_elements("xpath",'//div[@class="fs-15 bold time"]')
len(arr_t)
# Out:
# 87

# %%
Arr_t=[]
for i in arr_t:
    Arr_t.append(i.text)
Arr_t
# Out:
# ['16:50',
#  '15:20',
#  '05:00',
#  '20:40',
#  '19:30',
#  '01:45',
#  '04:05',
#  '14:00',
#  '16:55',
#  '20:35',
#  '21:00',
#  '22:20',
#  '15:35',
#  '13:25',
#  '11:30',
#  '04:55',
#  '05:05',
#  '11:25',
#  '11:15',
#  '16:00',
#  '13:00',
#  '09:00',
#  '08:00',
#  '07:00',
#  '16:00',
#  '13:00',
#  '09:00',
#  '19:00',
#  '18:00',
#  '17:00',
#  '10:00',
#  '18:00',
#  '17:00',
#  '10:00',
#  '18:35',
#  '18:35',
#  '18:35',
#  '18:35',
#  '18:35',
#  '07:00',
#  '09:05',
#  '22:00',
#  '07:20',
#  '07:20',
#  '11:15',
#  '07:00',
#  '21:00',
#  '21:00',
#  '21:20',
#  '19:00',
#  '14:40',
#  '10:25',
#  '21:20',
#  '17:35',
#  '15:45',
#  '06:00',
#  '20:55',
#  '11:25',
#  '20:55',
#  '12:25',
#  '11:55',
#  '07:30',
#  '06:30',
#  '06:00',
#  '21:30',
#  '08:45',
#  '20:10',
#  '18:30',
#  '19:00',
#  '17:30',
#  '18:30',
#  '19:45',
#  '11:05',
#  '16:00',
#  '19:45',
#  '07:30',
#  '06:30',
#  '06:00',
#  '06:00',
#  '06:00',
#  '22:45',
#  '22:45',
#  '21:55',
# ...

# %%
dep_t=driver.find_elements("xpath",'//p[@class="bold fs-15 mb-2 pr time"]')
len(dep_t)
# Out:
# 87

# %%
Dep_t=[]
for i in dep_t:
    Dep_t.append(i.text)
Dep_t
# Out:
# ['18:00',
#  '16:35',
#  '06:15',
#  '22:00',
#  '20:55',
#  '03:15',
#  '05:05',
#  '15:15',
#  '18:10',
#  '12:50\n+ 1 day',
#  '22:20',
#  '23:30',
#  '17:05',
#  '14:35',
#  '12:45',
#  '06:15',
#  '06:20',
#  '12:45',
#  '12:55',
#  '00:40\n+ 1 day',
#  '00:40\n+ 1 day',
#  '00:40\n+ 1 day',
#  '00:40\n+ 1 day',
#  '00:40\n+ 1 day',
#  '13:35\n+ 1 day',
#  '13:35\n+ 1 day',
#  '13:35\n+ 1 day',
#  '00:45\n+ 1 day',
#  '00:40\n+ 1 day',
#  '00:40\n+ 1 day',
#  '00:40\n+ 1 day',
#  '13:35\n+ 1 day',
#  '13:35\n+ 1 day',
#  '13:35\n+ 1 day',
#  '13:35\n+ 1 day',
#  '13:35\n+ 1 day',
#  '00:40\n+ 2 days',
#  '00:40\n+ 2 days',
#  '00:40\n+ 2 days',
#  '14:05',
#  '14:05',
#  '05:55\n+ 1 day',
#  '00:40\n+ 1 day',
#  '13:35\n+ 1 day',
#  '13:35\n+ 1 day',
#  '13:35',
#  '13:35\n+ 1 day',
#  '00:40\n+ 2 days',
#  '13:50\n+ 1 day',
#  '00:40\n+ 1 day',
#  '21:20',
#  '21:20',
#  '05:55\n+ 1 day',
#  '13:50\n+ 1 day',
#  '13:50\n+ 1 day',
#  '00:40\n+ 1 day',
#  '21:20\n+ 1 day',
# ...

# %%
total_s=driver.find_elements("xpath",'//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')
len(total_s)
# Out:
# 87

# %%
Total_s=[]
for i in total_s:
    Total_s.append(i.text)
Total_s
# Out:
# ['Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
# ...

# %%
cost=driver.find_elements("xpath",'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
len(cost)
# Out:
# 87

# %%
price=[]
for i in cost:
    price.append(i.text)
price
# Out:
# ['4,259',
#  '4,259',
#  '4,518',
#  '4,574',
#  '4,574',
#  '4,998',
#  '5,414',
#  '5,523',
#  '5,523',
#  '5,942',
#  '6,258',
#  '6,468',
#  '6,678',
#  '9,303',
#  '9,541',
#  '11,403',
#  '11,928',
#  '12,243',
#  '12,348',
#  '12,978',
#  '12,978',
#  '12,978',
#  '12,978',
#  '12,978',
#  '12,978',
#  '12,978',
#  '12,978',
#  '13,188',
#  '13,503',
#  '13,503',
#  '13,503',
#  '13,503',
#  '13,503',
#  '13,503',
#  '13,955',
#  '13,955',
#  '13,955',
#  '13,955',
#  '13,955',
#  '14,238',
#  '15,393',
#  '15,498',
#  '15,603',
#  '15,603',
#  '15,635',
#  '15,708',
#  '16,128',
#  '16,128',
#  '16,396',
#  '16,496',
#  '16,714',
#  '16,714',
#  '16,723',
#  '16,790',
#  '16,790',
#  '16,863',
#  '17,178',
#  '17,494',
#  '17,840',
#  '18,121',
#  '18,121',
#  '18,121',
#  '18,121',
#  '18,121',
#  '18,438',
#  '18,646',
#  '18,753',
#  '18,753',
#  '18,929',
#  '18,963',
#  '19,415',
#  '19,488',
#  '19,593',
#  '19,593',
#  '20,150',
#  '20,643',
#  '20,643',
#  '20,643',
# ...

# %%
duration_tag=driver.find_elements("xpath",'//p[@class="fs-12 bold du mb-2"]')
len(duration_tag)
# Out:
# 87

# %%
Duration=[]
for i in duration_tag:
    Duration.append(i.text)
Duration
# Out:
# ['1h 10m',
#  '1h 15m',
#  '1h 15m',
#  '1h 20m',
#  '1h 25m',
#  '1h 30m',
#  '1h 00m',
#  '1h 15m',
#  '1h 15m',
#  '16h 15m',
#  '1h 20m',
#  '1h 10m',
#  '1h 30m',
#  '1h 10m',
#  '1h 15m',
#  '1h 20m',
#  '1h 15m',
#  '1h 20m',
#  '1h 40m',
#  '8h 40m',
#  '11h 40m',
#  '15h 40m',
#  '16h 40m',
#  '17h 40m',
#  '21h 35m',
#  '24h 35m',
#  '28h 35m',
#  '5h 45m',
#  '6h 40m',
#  '7h 40m',
#  '14h 40m',
#  '19h 35m',
#  '20h 35m',
#  '27h 35m',
#  '19h 00m',
#  '19h 00m',
#  '30h 05m',
#  '30h 05m',
#  '30h 05m',
#  '7h 05m',
#  '5h 00m',
#  '7h 55m',
#  '17h 20m',
#  '30h 15m',
#  '26h 20m',
#  '6h 35m',
#  '16h 35m',
#  '27h 40m',
#  '16h 30m',
#  '5h 40m',
#  '6h 40m',
#  '10h 55m',
#  '8h 35m',
#  '20h 15m',
#  '22h 05m',
#  '18h 40m',
#  '24h 25m',
#  '1h 15m',
#  '16h 55m',
#  '8h 55m',
#  '9h 25m',
#  '13h 50m',
#  '14h 50m',
#  '15h 20m',
#  '16h 35m',
#  '12h 35m',
#  '17h 25m',
#  '26h 50m',
#  '10h 55m',
#  '20h 35m',
#  '19h 20m',
#  '25h 35m',
#  '13h 35m',
# ...

# %%
add_tag=driver.find_elements("xpath",'//span[@class="text"]')
len(add_tag)
# Out:
# 68

# %%
Addd_info=[]
for i in add_tag:
    Add_info.append(i.text)
Add_info
# Out:
# ['Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
# ...

# %%
flights4 = pd.DataFrame({})
flights4['Airline'] = Airline
flights4['Destination'] = list1
flights4['Source'] = list2
flights4['Arrival_time'] = Arr_t
flights4['Departure_time'] =Dep_t
flights4['Total_Stops']=Total_s
flights4['Total_Duration'] = Duration
flights4['Additional_Info']=pd.Series(Add_info)
flights4['Price']=price
flights4
# Out:
#          Airline Destination  Source Arrival_time  Departure_time Total_Stops  \
# 0       Go First         Goa  Mumbai        16:50           18:00    Non Stop
# 1       Go First         Goa  Mumbai        15:20           16:35    Non Stop
# 2       Go First         Goa  Mumbai        05:00           06:15    Non Stop
# 3       Air Asia         Goa  Mumbai        20:40           22:00    Non Stop
# 4   Alliance Air         Goa  Mumbai        19:30           20:55    Non Stop
# ..           ...         ...     ...          ...             ...         ...
# 82       Vistara         Goa  Mumbai        21:55  14:05\n+ 1 day   2 Stop(s)
# 83       Vistara         Goa  Mumbai        21:55  14:05\n+ 1 day   2 Stop(s)
# 84       Vistara         Goa  Mumbai        22:45  14:05\n+ 1 day   2 Stop(s)
# 85       Vistara         Goa  Mumbai        21:55  14:05\n+ 1 day   2 Stop(s)
# 86       Vistara         Goa  Mumbai        19:10  14:05\n+ 1 day      1 Stop
#
# ...

# %% [markdown]
# # Scrapping data for Banglore and Lucknow Loacation

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=LKO&destinationCountry=IN&flexi=0&flight_depart_date=21%2F09%2F2022&hb=0&noOfSegments=1&origin=BLR&originCountry=IN&type=O&unique=1663659417671&viewName=normal'
driver.get(url)

# %%
airline=driver.find_elements("xpath",'//span[@class="i-b text ellipsis"]')
len(airline)
# Out:
# 85

# %%
Airline=[]
for i in airline:
    Airline.append(i.text)
Airline
# Out:
# ['Air Asia',
#  'IndiGo',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Air Asia',
#  'Air Asia',
#  'Vistara',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'IndiGo',
#  'Go First',
#  'Go First',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
# ...

# %%
flight_no=driver.find_elements("xpath",'//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]')
len(flight_no)
# Out:
# 85

# %%
Flight_no=[]
for i in flight_no:
    Flight_no.append(i.text)
Flight_no
# Out:
# ['I5-2472',
#  '6E-196',
#  'I5-1533',
#  '6E-451',
#  '6E-6353',
#  'UK-802/641',
#  '6E-852/518',
#  '6E-2174/2084',
#  '6E-541/6311',
#  '6E-6317/7127',
#  '6E-738/5391',
#  '6E-6991/307',
#  '6E-488/5228',
#  '6E-6379/5339',
#  '6E-6825/6311',
#  '6E-2147/2084',
#  '6E-6595/935',
#  '6E-5251/5391',
#  '6E-869/6184',
#  '6E-6491/866',
#  '6E-6269/6311',
#  '6E-5354/5339',
#  '6E-6779/6244',
#  '6E-5323/5228',
#  '6E-2514/2084',
#  '6E-6345/6811',
#  'UK-818/641',
#  'UK-816/641',
#  'I5-1451/550',
#  'I5-1622/550',
#  'UK-814/641',
#  '6E-2053/307',
#  'UK-806/641',
#  'UK-820/641',
#  'UK-897/870/641',
#  'UK-897/890/641',
#  'UK-897/880/641',
#  '6E-2401/2006',
#  'AI-501/811',
#  'AI-507/811',
#  'AI-505/811',
#  'AI-808/431',
#  'AI-509/431',
#  'AI-503/431',
#  'AI-808/811',
#  'AI-501/431',
#  'AI-509/811',
#  'AI-507/431',
#  'AI-503/811',
#  'AI-505/431',
#  'AI-640/625',
#  'AI-642/625',
#  'AI-610/625',
#  'UK-657/638/641',
#  '6E-2514/682',
#  'UK-915/914/641',
# ...

# %%
source=driver.find_elements('xpath','//p[@class="fs-10 font-lightgrey no-wrap city ellipsis"]')
len(source)
# Out:
# 170

# %%
sources=[]
for i in source:
    sources.append(i.text)
sources
# Out:
# ['Bangalore',
#  'Lucknow',
#  'Bangalore',
#  'Lucknow',
#  'Bangalore',
#  'Lucknow',
#  'Bangalore',
#  'Lucknow',
#  'Bangalore',
#  'Lucknow',
#  'Bangalore',
#  'Lucknow',
#  'Bangalore',
#  'Lucknow',
#  'Bangalore',
#  'Lucknow',
#  'Bangalore',
#  'Lucknow',
#  'Bangalore',
#  'Lucknow',
#  'Bangalore',
#  'Lucknow',
#  'Bangalore',
#  'Lucknow',
#  'Bangalore',
#  'Lucknow',
#  'Bangalore',
#  'Lucknow',
#  'Bangalore',
#  'Lucknow',
#  'Bangalore',
#  'Lucknow',
#  'Bangalore',
#  'Lucknow',
#  'Bangalore',
#  'Lucknow',
#  'Bangalore',
#  'Lucknow',
#  'Bangalore',
#  'Lucknow',
#  'Bangalore',
#  'Lucknow',
#  'Bangalore',
#  'Lucknow',
#  'Bangalore',
#  'Lucknow',
#  'Bangalore',
#  'Lucknow',
#  'Bangalore',
#  'Lucknow',
#  'Bangalore',
#  'Lucknow',
#  'Bangalore',
#  'Lucknow',
#  'Bangalore',
#  'Lucknow',
#  'Bangalore',
#  'Lucknow',
#  'Bangalore',
#  'Lucknow',
#  'Bangalore',
#  'Lucknow',
#  'Bangalore',
#  'Lucknow',
#  'Bangalore',
#  'Lucknow',
# ...

# %%
list1 = [sources[i] for i in range(len(sources)) if i % 2 != 0]

# %%
list1
# Out:
# ['Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
#  'Lucknow',
# ...

# %%
list2=sources[::2]

# %%
list2
# Out:
# ['Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
# ...

# %%
arr_t=driver.find_elements("xpath",'//div[@class="fs-15 bold time"]')
len(arr_t)
# Out:
# 85

# %%
Arr_t=[]
for i in arr_t:
    Arr_t.append(i.text)
Arr_t
# Out:
# ['06:50',
#  '13:20',
#  '14:00',
#  '18:20',
#  '06:05',
#  '18:45',
#  '10:20',
#  '18:00',
#  '09:35',
#  '18:25',
#  '17:50',
#  '00:45',
#  '10:00',
#  '12:20',
#  '08:05',
#  '16:20',
#  '13:55',
#  '16:50',
#  '11:45',
#  '12:50',
#  '07:00',
#  '11:00',
#  '01:40',
#  '08:20',
#  '14:55',
#  '13:00',
#  '19:40',
#  '11:30',
#  '05:40',
#  '10:55',
#  '21:15',
#  '23:05',
#  '09:45',
#  '17:45',
#  '07:45',
#  '07:45',
#  '07:45',
#  '13:55',
#  '13:20',
#  '11:15',
#  '10:00',
#  '21:20',
#  '19:15',
#  '17:00',
#  '21:20',
#  '13:20',
#  '19:15',
#  '11:15',
#  '17:00',
#  '10:00',
#  '06:45',
#  '21:20',
#  '19:10',
#  '11:30',
#  '14:55',
#  '17:30',
#  '17:30',
#  '07:45',
#  '18:15',
#  '11:15',
#  '18:15',
#  '13:55',
#  '08:10',
#  '08:10',
#  '06:10',
#  '20:10',
#  '20:10',
#  '07:45',
#  '13:40',
#  '07:45',
#  '12:45',
#  '18:55',
#  '06:30',
#  '08:25',
#  '06:45',
#  '06:45',
#  '21:20',
#  '13:40',
#  '11:30',
#  '19:55',
#  '18:25',
#  '08:00',
#  '21:40',
# ...

# %%
dep_t=driver.find_elements("xpath",'//p[@class="bold fs-15 mb-2 pr time"]')
len(dep_t)
# Out:
# 85

# %%
Dep_t=[]
for i in dep_t:
    Dep_t.append(i.text)
Dep_t
# Out:
# ['09:15',
#  '15:45',
#  '16:25',
#  '20:45',
#  '08:35',
#  '14:45\n+ 1 day',
#  '17:25',
#  '22:40',
#  '14:25',
#  '23:30',
#  '23:35',
#  '06:40',
#  '16:00',
#  '18:25',
#  '14:25',
#  '22:40',
#  '20:35',
#  '23:35',
#  '18:35',
#  '19:45',
#  '14:25',
#  '18:25',
#  '09:15',
#  '16:00',
#  '22:40',
#  '20:55',
#  '14:45\n+ 1 day',
#  '14:45\n+ 1 day',
#  '23:15',
#  '23:15',
#  '14:45\n+ 1 day',
#  '06:40\n+ 1 day',
#  '14:45',
#  '14:45\n+ 1 day',
#  '14:45\n+ 1 day',
#  '14:45\n+ 1 day',
#  '14:45\n+ 1 day',
#  '19:50',
#  '19:35',
#  '19:35',
#  '19:35',
#  '13:25\n+ 1 day',
#  '13:25\n+ 1 day',
#  '13:25\n+ 1 day',
#  '19:35\n+ 1 day',
#  '13:25\n+ 1 day',
#  '19:35\n+ 1 day',
#  '13:25\n+ 1 day',
#  '19:35\n+ 1 day',
#  '13:25\n+ 1 day',
#  '13:20',
#  '13:20\n+ 1 day',
#  '13:20\n+ 1 day',
#  '14:45\n+ 1 day',
#  '21:45',
#  '14:45\n+ 1 day',
#  '14:45\n+ 1 day',
#  '14:45\n+ 1 day',
#  '23:15',
#  '23:15',
#  '08:20\n+ 1 day',
#  '21:45',
#  '13:05',
#  '19:55',
# ...

# %%
total_s=driver.find_elements("xpath",'//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')
len(total_s)
# Out:
# 85

# %%
Total_s=[]
for i in total_s:
    Total_s.append(i.text)
Total_s
# Out:
# ['Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
# ...

# %%
cost=driver.find_elements("xpath",'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
len(cost)
# Out:
# 85

# %%
price=[]
for i in cost:
    price.append(i.text)
price
# Out:
# ['6,412',
#  '6,412',
#  '6,412',
#  '6,412',
#  '6,412',
#  '7,310',
#  '7,579',
#  '7,684',
#  '7,684',
#  '7,684',
#  '7,684',
#  '7,684',
#  '7,684',
#  '7,684',
#  '7,684',
#  '7,684',
#  '7,684',
#  '7,684',
#  '7,684',
#  '7,684',
#  '7,684',
#  '7,684',
#  '7,684',
#  '7,684',
#  '7,684',
#  '7,684',
#  '8,041',
#  '8,041',
#  '8,470',
#  '8,769',
#  '8,772',
#  '8,976',
#  '10,145',
#  '10,145',
#  '10,236',
#  '10,236',
#  '10,236',
#  '10,267',
#  '10,341',
#  '10,341',
#  '10,341',
#  '10,341',
#  '10,341',
#  '10,341',
#  '10,341',
#  '10,341',
#  '10,341',
#  '10,341',
#  '10,341',
#  '10,341',
#  '10,342',
#  '10,342',
#  '10,342',
#  '10,909',
#  '10,913',
#  '11,072',
#  '11,072',
#  '11,107',
#  '11,490',
#  '11,490',
#  '11,490',
#  '11,559',
#  '11,596',
#  '11,596',
#  '12,031',
#  '12,220',
#  '12,220',
#  '12,850',
#  '12,850',
#  '12,858',
#  '13,400',
#  '13,734',
#  '14,142',
#  '14,227',
#  '14,227',
#  '14,227',
#  '14,227',
#  '14,746',
#  '15,093',
# ...

# %%
duration_tag=driver.find_elements("xpath",'//p[@class="fs-12 bold du mb-2"]')
len(duration_tag)
# Out:
# 85

# %%
Duration=[]
for i in duration_tag:
    Duration.append(i.text)
Duration
# Out:
# ['2h 25m',
#  '2h 25m',
#  '2h 25m',
#  '2h 25m',
#  '2h 30m',
#  '20h 00m',
#  '7h 05m',
#  '4h 40m',
#  '4h 50m',
#  '5h 05m',
#  '5h 45m',
#  '5h 55m',
#  '6h 00m',
#  '6h 05m',
#  '6h 20m',
#  '6h 20m',
#  '6h 40m',
#  '6h 45m',
#  '6h 50m',
#  '6h 55m',
#  '7h 25m',
#  '7h 25m',
#  '7h 35m',
#  '7h 40m',
#  '7h 45m',
#  '7h 55m',
#  '19h 05m',
#  '27h 15m',
#  '17h 35m',
#  '12h 20m',
#  '17h 30m',
#  '7h 35m',
#  '5h 00m',
#  '21h 00m',
#  '31h 00m',
#  '31h 00m',
#  '31h 00m',
#  '5h 55m',
#  '6h 15m',
#  '8h 20m',
#  '9h 35m',
#  '16h 05m',
#  '18h 10m',
#  '20h 25m',
#  '22h 15m',
#  '24h 05m',
#  '24h 20m',
#  '26h 10m',
#  '26h 35m',
#  '27h 25m',
#  '6h 35m',
#  '16h 00m',
#  '18h 10m',
#  '27h 15m',
#  '6h 50m',
#  '21h 15m',
#  '21h 15m',
#  '31h 00m',
#  '5h 00m',
#  '12h 00m',
#  '14h 05m',
#  '7h 50m',
#  '4h 55m',
#  '11h 45m',
#  '13h 25m',
#  '18h 35m',
#  '18h 35m',
#  '6h 00m',
#  '6h 50m',
#  '7h 00m',
#  '26h 00m',
#  '19h 50m',
#  '7h 15m',
#  '11h 10m',
# ...

# %%
add_tag=driver.find_elements("xpath",'//span[@class="text"]')
len(add_tag)
# Out:
# 45

# %%
Add_info=[]
for i in add_tag:
    Add_info.append(i.text)
Add_info
# Out:
# ['Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal']

# %%
flights5 = pd.DataFrame({})
flights5['Airline'] = Airline
flights5['Destination'] = list1
flights5['Source'] = list2
flights5['Arrival_time'] = Arr_t
flights5['Departure_time'] =Dep_t
flights5['Total_Stops']=Total_s
flights5['Total_Duration'] = Duration
flights5['Additional_Info']=pd.Series(Add_info)
flights5['Price']=price
flights5
# Out:
#      Airline Destination     Source Arrival_time  Departure_time Total_Stops  \
# 0   Air Asia     Lucknow  Bangalore        06:50           09:15    Non Stop
# 1     IndiGo     Lucknow  Bangalore        13:20           15:45    Non Stop
# 2   Air Asia     Lucknow  Bangalore        14:00           16:25    Non Stop
# 3     IndiGo     Lucknow  Bangalore        18:20           20:45    Non Stop
# 4     IndiGo     Lucknow  Bangalore        06:05           08:35    Non Stop
# ..       ...         ...        ...          ...             ...         ...
# 80   Vistara     Lucknow  Bangalore        18:25  14:45\n+ 1 day   2 Stop(s)
# 81   Vistara     Lucknow  Bangalore        08:00           14:45      1 Stop
# 82   Vistara     Lucknow  Bangalore        21:40  14:45\n+ 1 day   2 Stop(s)
# 83   Vistara     Lucknow  Bangalore        21:40  14:45\n+ 1 day   2 Stop(s)
# 84   Vistara     Lucknow  Bangalore        21:40  14:45\n+ 1 day   2 Stop(s)
#
#    Total_Duration Additional_Info   Price
# ...

# %% [markdown]
# # Scrapping data for Banglore and Kolkata Loacation

# %%
Flight3=pd.concat([flights4,flights5],ignore_index=True)

# %%
Flight3.shape
# Out:
# (172, 9)

# %%
Flights=pd.concat([Flight1,Flight2,Flight3],ignore_index=True)

# %%
Flights.shape
# Out:
# (659, 9)

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=BLR&originCountry=IN&destination=CCU&destinationCountry=IN&flight_depart_date=20%2F09%2F2022&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=806836507913'
driver.get(url)

# %%
airline=driver.find_elements("xpath",'//span[@class="i-b text ellipsis"]')
len(airline)
# Out:
# 75

# %%
Airline=[]
for i in airline:
    Airline.append(i.text)
Airline
# Out:
# ['Go First',
#  'Go First',
#  'SpiceJet',
#  'SpiceJet',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Go First',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'Vistara',
# ...

# %%
flight_no=driver.find_elements("xpath",'//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]')
len(flight_no)
# Out:
# 75

# %%
Flight_no=[]
for i in flight_no:
    Flight_no.append(i.text)
Flight_no
# Out:
# ['G8-118/101',
#  'G8-803/532',
#  'SG-536/8263',
#  'SG-536/8251',
#  '6E-538',
#  '6E-676',
#  '6E-952',
#  'UK-850/775',
#  'UK-864/775',
#  'UK-850/773',
#  'UK-864/773',
#  '6E-978/7205',
#  '6E-684/664',
#  'AI-642/675',
#  'AI-610/675',
#  '6E-684/6494',
#  'UK-818/747',
#  'UK-818/737',
#  'UK-818/707',
#  'UK-818/727',
#  'I5-992',
#  '6E-855/6494',
#  '6E-217',
#  '6E-6067/944',
#  '6E-638/6494',
#  'UK-820/747',
#  'UK-820/737',
#  'UK-820/707',
#  'UK-854/775',
#  'UK-854/773',
#  '6E-6572',
#  'UK-850/771',
#  'UK-864/771',
#  'UK-854/771',
#  'UK-915/934/747',
#  'UK-915/934/737',
#  'UK-915/914/737',
#  'UK-915/934/707',
#  'UK-915/914/707',
#  'UK-915/934/727',
#  'UK-915/914/727',
#  'G8-399/511',
#  'UK-802/747',
#  'UK-802/737',
#  'UK-802/707',
#  'AI-503/762',
#  'AI-808/767',
#  'AI-509/767',
#  'AI-503/767',
#  'AI-808/764',
#  'AI-509/764',
#  'AI-808/762',
#  'AI-503/764',
#  'AI-509/762',
#  'UK-818/705',
#  'UK-802/705',
#  'UK-820/705',
# ...

# %%
source=driver.find_elements('xpath','//p[@class="fs-10 font-lightgrey no-wrap city ellipsis"]')
len(source)
# Out:
# 150

# %%
sources=[]
for i in source:
    sources.append(i.text)
sources
# Out:
# ['Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
# ...

# %%
list1 = [sources[i] for i in range(len(sources)) if i % 2 != 0]

# %%
list1
# Out:
# ['Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
# ...

# %%
list2=sources[::2]

# %%
list2
# Out:
# ['Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
# ...

# %%
arr_t=driver.find_elements("xpath",'//div[@class="fs-15 bold time"]')
len(arr_t)
# Out:
# 75

# %%
Arr_t=[]
for i in arr_t:
    Arr_t.append(i.text)
Arr_t
# Out:
# ['21:05',
#  '18:45',
#  '17:30',
#  '17:30',
#  '22:25',
#  '19:55',
#  '23:25',
#  '19:55',
#  '18:55',
#  '19:55',
#  '18:55',
#  '16:10',
#  '22:10',
#  '21:20',
#  '19:10',
#  '22:10',
#  '19:40',
#  '19:40',
#  '19:40',
#  '19:40',
#  '23:35',
#  '21:15',
#  '18:10',
#  '16:00',
#  '18:50',
#  '17:45',
#  '17:45',
#  '17:45',
#  '18:25',
#  '18:25',
#  '15:25',
#  '19:55',
#  '18:55',
#  '18:25',
#  '17:30',
#  '17:30',
#  '17:30',
#  '17:30',
#  '17:30',
#  '17:30',
#  '17:30',
#  '21:00',
#  '18:45',
#  '18:45',
#  '18:45',
#  '17:10',
#  '21:20',
#  '19:15',
#  '17:10',
#  '21:20',
#  '19:15',
#  '21:20',
#  '17:10',
#  '19:15',
#  '19:40',
#  '18:45',
#  '17:45',
#  '20:10',
#  '21:20',
#  '19:10',
#  '17:30',
#  '17:10',
#  '17:10',
#  '18:55',
#  '18:55',
#  '21:20',
#  '19:15',
#  '16:45',
#  '16:45',
#  '21:40',
#  '21:40',
#  '18:25',
#  '21:40',
#  '17:10',
#  '18:25']

# %%
dep_t=driver.find_elements("xpath",'//p[@class="bold fs-15 mb-2 pr time"]')
len(dep_t)
# Out:
# 75

# %%
Dep_t=[]
for i in dep_t:
    Dep_t.append(i.text)
Dep_t
# Out:
# ['08:00\n+ 1 day',
#  '08:45\n+ 1 day',
#  '09:05\n+ 1 day',
#  '21:00\n+ 1 day',
#  '00:35\n+ 1 day',
#  '22:30',
#  '02:00\n+ 1 day',
#  '16:55\n+ 1 day',
#  '16:55\n+ 1 day',
#  '19:55\n+ 1 day',
#  '19:55\n+ 1 day',
#  '22:40',
#  '08:20\n+ 1 day',
#  '08:50\n+ 1 day',
#  '08:50\n+ 1 day',
#  '05:15\n+ 1 day',
#  '08:20\n+ 1 day',
#  '18:05\n+ 1 day',
#  '19:35\n+ 1 day',
#  '22:45\n+ 1 day',
#  '02:05\n+ 1 day',
#  '05:15\n+ 1 day',
#  '20:35',
#  '22:30',
#  '05:15\n+ 1 day',
#  '08:20\n+ 1 day',
#  '18:05\n+ 1 day',
#  '19:35\n+ 1 day',
#  '16:55\n+ 1 day',
#  '19:55\n+ 1 day',
#  '18:00',
#  '09:40\n+ 1 day',
#  '09:40\n+ 1 day',
#  '09:40\n+ 1 day',
#  '08:20\n+ 1 day',
#  '18:05\n+ 1 day',
#  '18:05\n+ 1 day',
#  '19:35\n+ 1 day',
#  '19:35\n+ 1 day',
#  '22:45\n+ 1 day',
#  '22:45\n+ 1 day',
#  '09:40\n+ 1 day',
#  '08:20\n+ 1 day',
#  '18:05\n+ 1 day',
#  '19:35\n+ 1 day',
#  '23:05',
#  '14:30\n+ 1 day',
#  '14:30\n+ 1 day',
#  '14:30\n+ 1 day',
#  '19:10\n+ 1 day',
# ...

# %%
total_s=driver.find_elements("xpath",'//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')
len(total_s)
# Out:
# 75

# %%
Total_s=[]
for i in total_s:
    Total_s.append(i.text)
Total_s
# Out:
# ['1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '3 Stop(s)',
#  '3 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
# ...

# %%
cost=driver.find_elements("xpath",'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
len(cost)
# Out:
# 75

# %%
price=[]
for i in cost:
    price.append(i.text)
price
# Out:
# ['7,789',
#  '7,789',
#  '7,789',
#  '7,789',
#  '8,839',
#  '8,839',
#  '8,839',
#  '8,963',
#  '8,963',
#  '8,963',
#  '8,963',
#  '9,448',
#  '9,448',
#  '10,027',
#  '10,027',
#  '10,057',
#  '10,624',
#  '10,624',
#  '10,624',
#  '10,624',
#  '10,625',
#  '10,666',
#  '10,729',
#  '10,887',
#  '11,275',
#  '11,697',
#  '11,697',
#  '11,697',
#  '11,753',
#  '11,753',
#  '12,199',
#  '12,491',
#  '12,491',
#  '12,491',
#  '12,497',
#  '12,497',
#  '12,497',
#  '12,497',
#  '12,497',
#  '12,497',
#  '12,497',
#  '12,768',
#  '12,782',
#  '12,782',
#  '12,782',
#  '13,249',
#  '13,249',
#  '13,249',
#  '13,249',
#  '13,249',
#  '13,249',
#  '13,249',
#  '13,249',
#  '13,249',
#  '13,520',
#  '13,520',
#  '13,520',
#  '15,078',
#  '15,277',
#  '15,277',
#  '15,899',
#  '17,376',
#  '17,376',
#  '17,657',
#  '17,657',
#  '18,744',
#  '18,744',
#  '19,053',
#  '19,053',
#  '19,234',
#  '19,234',
#  '19,652',
#  '21,754',
#  '25,429',
#  '25,954']

# %%
duration_tag=driver.find_elements("xpath",'//p[@class="fs-12 bold du mb-2"]')
len(duration_tag)
# Out:
# 75

# %%
Duration=[]
for i in duration_tag:
    Duration.append(i.text)
Duration
# Out:
# ['10h 55m',
#  '14h 00m',
#  '15h 35m',
#  '27h 30m',
#  '2h 10m',
#  '2h 35m',
#  '2h 35m',
#  '21h 00m',
#  '22h 00m',
#  '24h 00m',
#  '25h 00m',
#  '6h 30m',
#  '10h 10m',
#  '11h 30m',
#  '13h 40m',
#  '7h 05m',
#  '12h 40m',
#  '22h 25m',
#  '23h 55m',
#  '27h 05m',
#  '2h 30m',
#  '8h 00m',
#  '2h 25m',
#  '6h 30m',
#  '10h 25m',
#  '14h 35m',
#  '24h 20m',
#  '25h 50m',
#  '22h 30m',
#  '25h 30m',
#  '2h 35m',
#  '13h 45m',
#  '14h 45m',
#  '15h 15m',
#  '14h 50m',
#  '24h 35m',
#  '24h 35m',
#  '26h 05m',
#  '26h 05m',
#  '29h 15m',
#  '29h 15m',
#  '12h 40m',
#  '13h 35m',
#  '23h 20m',
#  '24h 50m',
#  '5h 55m',
#  '17h 10m',
#  '19h 15m',
#  '21h 20m',
#  '21h 50m',
#  '23h 55m',
#  '25h 05m',
#  '26h 00m',
#  '27h 10m',
#  '13h 55m',
#  '14h 50m',
#  '15h 50m',
#  '20h 45m',
#  '26h 30m',
#  '28h 40m',
#  '16h 05m',
#  '15h 40m',
#  '15h 40m',
#  '13h 25m',
#  '14h 40m',
#  '19h 15m',
#  '21h 20m',
#  '15h 35m',
#  '16h 50m',
#  '19h 15m',
#  '22h 15m',
#  '13h 55m',
# ...

# %%
add_tag=driver.find_elements("xpath",'//span[@class="text"]')
len(add_tag)
# Out:
# 58

# %%
Add_info=[]
for i in add_tag:
    Add_info.append(i.text)
Add_info
# Out:
# ['Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal']

# %%
flights6 = pd.DataFrame({})
flights6['Airline'] = Airline
flights6['Destination'] = list1
flights6['Source'] = list2
flights6['Arrival_time'] = Arr_t
flights6['Departure_time'] =Dep_t
flights6['Total_Stops']=Total_s
flights6['Total_Duration'] = Duration
flights6['Additional_Info']=pd.Series(Add_info)
flights6['Price']=price
flights6
# Out:
#      Airline Destination     Source Arrival_time  Departure_time Total_Stops  \
# 0   Go First     Kolkata  Bangalore        21:05  08:00\n+ 1 day      1 Stop
# 1   Go First     Kolkata  Bangalore        18:45  08:45\n+ 1 day      1 Stop
# 2   SpiceJet     Kolkata  Bangalore        17:30  09:05\n+ 1 day      1 Stop
# 3   SpiceJet     Kolkata  Bangalore        17:30  21:00\n+ 1 day      1 Stop
# 4     IndiGo     Kolkata  Bangalore        22:25  00:35\n+ 1 day    Non Stop
# ..       ...         ...        ...          ...             ...         ...
# 70   Vistara     Kolkata  Bangalore        21:40  19:55\n+ 1 day      1 Stop
# 71   Vistara     Kolkata  Bangalore        18:25  08:20\n+ 1 day   2 Stop(s)
# 72   Vistara     Kolkata  Bangalore        21:40  09:40\n+ 1 day      1 Stop
# 73  Air Asia     Kolkata  Bangalore        17:10           19:50    Non Stop
# 74   Vistara     Kolkata  Bangalore        18:25  08:20\n+ 1 day   2 Stop(s)
#
#    Total_Duration Additional_Info   Price
# ...

# %% [markdown]
# # Scrapping data for Hydrabad and Kolkata Loacation

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=CCU&destinationCountry=IN&flexi=0&flight_depart_date=22%2F09%2F2022&hb=0&noOfSegments=1&origin=HYD&originCountry=IN&type=O&unique=1663580871186&viewName=normal'
driver.get(url)

# %%
airline=driver.find_elements("xpath",'//span[@class="i-b text ellipsis"]')
len(airline)
# Out:
# 93

# %%
Airline=[]
for i in airline:
    Airline.append(i.text)
Airline
# Out:
# ['IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'IndiGo',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'IndiGo',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'Vistara',
# ...

# %%
flight_no=driver.find_elements("xpath",'//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]')
len(flight_no)
# Out:
# 93

# %%
Flight_no=[]
for i in flight_no:
    Flight_no.append(i.text)
Flight_no
# Out:
# ['6E-6494',
#  '6E-283',
#  '6E-6907',
#  'G8-426/101',
#  'I5-517',
#  '6E-581/6038',
#  '6E-6211/6038',
#  'SG-160/8251',
#  'SG-160/8254',
#  'SG-160/8263',
#  'UK-874/775',
#  'UK-872/775',
#  '6E-421/6101',
#  '6E-922/7117',
#  '6E-886/7306',
#  '6E-6719/736',
#  '6E-938/801',
#  'UK-880/707',
#  'UK-880/727',
#  'UK-870/747',
#  'UK-870/705',
#  'UK-890/747',
#  'UK-890/705',
#  '6E-944',
#  '6E-915/507',
#  'UK-830/737',
#  'UK-830/707',
#  'UK-860/737',
#  'UK-860/707',
#  'UK-830/727',
#  'UK-860/727',
#  '6E-6911/7584',
#  'UK-878/773',
#  'UK-874/773',
#  'UK-872/773',
#  'UK-870/737',
#  '6E-514/923',
#  'AI-541/762',
#  'AI-559/767',
#  'AI-543/764',
#  'AI-543/762',
#  'AI-559/764',
#  'AI-559/762',
#  'AI-541/401',
#  'AI-543/401',
#  'AI-559/401',
#  '6E-102/6123',
#  '6E-514/6275',
#  'AI-541/764',
#  '6E-6007/987',
#  '6E-6007/321',
#  'AI-840/401',
#  '6E-6151/6275',
#  'I5-1543/1455',
#  'I5-974/992',
#  'I5-1543/592',
#  'I5-1543/992',
#  'I5-1518/611',
# ...

# %%
source=driver.find_elements('xpath','//p[@class="fs-10 font-lightgrey no-wrap city ellipsis"]')
len(source)
# Out:
# 186

# %%
sources=[]
for i in source:
    sources.append(i.text)
sources
# Out:
# ['Hyderabad',
#  'Kolkata',
#  'Hyderabad',
#  'Kolkata',
#  'Hyderabad',
#  'Kolkata',
#  'Hyderabad',
#  'Kolkata',
#  'Hyderabad',
#  'Kolkata',
#  'Hyderabad',
#  'Kolkata',
#  'Hyderabad',
#  'Kolkata',
#  'Hyderabad',
#  'Kolkata',
#  'Hyderabad',
#  'Kolkata',
#  'Hyderabad',
#  'Kolkata',
#  'Hyderabad',
#  'Kolkata',
#  'Hyderabad',
#  'Kolkata',
#  'Hyderabad',
#  'Kolkata',
#  'Hyderabad',
#  'Kolkata',
#  'Hyderabad',
#  'Kolkata',
#  'Hyderabad',
#  'Kolkata',
#  'Hyderabad',
#  'Kolkata',
#  'Hyderabad',
#  'Kolkata',
#  'Hyderabad',
#  'Kolkata',
#  'Hyderabad',
#  'Kolkata',
#  'Hyderabad',
#  'Kolkata',
#  'Hyderabad',
#  'Kolkata',
#  'Hyderabad',
#  'Kolkata',
#  'Hyderabad',
#  'Kolkata',
#  'Hyderabad',
#  'Kolkata',
#  'Hyderabad',
#  'Kolkata',
#  'Hyderabad',
#  'Kolkata',
#  'Hyderabad',
#  'Kolkata',
#  'Hyderabad',
#  'Kolkata',
#  'Hyderabad',
#  'Kolkata',
#  'Hyderabad',
#  'Kolkata',
#  'Hyderabad',
#  'Kolkata',
#  'Hyderabad',
#  'Kolkata',
# ...

# %%
list1 = [sources[i] for i in range(len(sources)) if i % 2 != 0]

# %%
list1
# Out:
# ['Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
# ...

# %%
list2=sources[::2]

# %%
list2
# Out:
# ['Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
#  'Hyderabad',
# ...

# %%
arr_t=driver.find_elements("xpath",'//div[@class="fs-15 bold time"]')
len(arr_t)
# Out:
# 93

# %%
Arr_t=[]
for i in arr_t:
    Arr_t.append(i.text)
Arr_t
# Out:
# ['03:05',
#  '17:05',
#  '15:00',
#  '21:05',
#  '12:10',
#  '11:30',
#  '06:30',
#  '06:10',
#  '06:10',
#  '06:10',
#  '08:30',
#  '07:10',
#  '08:30',
#  '15:50',
#  '11:00',
#  '08:30',
#  '09:25',
#  '13:25',
#  '13:25',
#  '20:30',
#  '20:30',
#  '17:40',
#  '17:40',
#  '20:25',
#  '09:20',
#  '10:10',
#  '10:10',
#  '07:00',
#  '07:00',
#  '10:10',
#  '07:00',
#  '11:10',
#  '12:55',
#  '08:30',
#  '07:10',
#  '20:30',
#  '13:50',
#  '16:10',
#  '06:40',
#  '10:05',
#  '10:05',
#  '06:40',
#  '06:40',
#  '16:10',
#  '10:05',
#  '06:40',
#  '17:55',
#  '13:50',
#  '16:10',
#  '23:15',
#  '23:15',
#  '20:40',
#  '10:05',
#  '14:20',
#  '20:20',
#  '14:20',
#  '14:20',
#  '21:55',
#  '20:20',
#  '10:05',
#  '13:50',
#  '20:40',
#  '06:15',
#  '05:55',
#  '07:30',
#  '07:30',
#  '07:30',
#  '07:30',
#  '20:40',
#  '07:30',
#  '13:15',
#  '21:35',
#  '21:35',
#  '16:10',
#  '22:25',
#  '21:35',
#  '21:05',
#  '07:30',
#  '20:20',
#  '20:40',
#  '20:40',
#  '20:40',
#  '20:40',
# ...

# %%
dep_t=driver.find_elements("xpath",'//p[@class="bold fs-15 mb-2 pr time"]')
len(dep_t)
# Out:
# 93

# %%
Dep_t=[]
for i in dep_t:
    Dep_t.append(i.text)
Dep_t
# Out:
# ['05:15',
#  '19:15',
#  '17:15',
#  '08:00\n+ 1 day',
#  '14:15',
#  '16:50',
#  '16:50',
#  '21:00',
#  '22:35',
#  '09:05\n+ 1 day',
#  '16:55',
#  '16:55',
#  '15:30',
#  '23:15',
#  '19:00',
#  '17:30',
#  '18:30',
#  '19:35',
#  '22:45',
#  '08:20\n+ 1 day',
#  '09:35\n+ 1 day',
#  '08:20\n+ 1 day',
#  '09:35\n+ 1 day',
#  '22:30',
#  '17:25',
#  '18:05',
#  '19:35',
#  '18:05',
#  '19:35',
#  '22:45',
#  '22:45',
#  '15:50',
#  '19:55',
#  '19:55',
#  '19:55',
#  '18:05\n+ 1 day',
#  '21:50',
#  '22:25',
#  '14:30',
#  '19:10',
#  '22:25',
#  '19:10',
#  '22:25',
#  '09:00\n+ 1 day',
#  '09:00\n+ 1 day',
#  '09:00\n+ 1 day',
#  '23:15',
#  '19:45',
#  '19:10\n+ 1 day',
#  '07:35\n+ 1 day',
#  '10:30\n+ 1 day',
#  '09:00\n+ 1 day',
#  '19:45',
#  '19:50',
#  '02:05\n+ 1 day',
#  '20:50',
#  '02:05\n+ 1 day',
#  '11:15\n+ 1 day',
#  '11:15\n+ 1 day',
#  '18:20',
#  '23:15',
#  '19:10\n+ 1 day',
#  '08:20',
#  '08:15',
#  '18:05',
#  '19:35',
#  '22:45',
#  '08:20\n+ 1 day',
# ...

# %%
total_s=driver.find_elements("xpath",'//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')
len(total_s)
# Out:
# 93

# %%
Total_s=[]
for i in total_s:
    Total_s.append(i.text)
Total_s
# Out:
# ['Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
# ...

# %%
cost=driver.find_elements("xpath",'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
len(cost)
# Out:
# 93

# %%
price=[]
for i in cost:
    price.append(i.text)
price
# Out:
# ['6,577',
#  '6,577',
#  '6,892',
#  '7,940',
#  '7,942',
#  '7,942',
#  '7,942',
#  '7,942',
#  '7,942',
#  '7,942',
#  '8,529',
#  '8,529',
#  '8,614',
#  '8,614',
#  '8,614',
#  '8,614',
#  '8,614',
#  '8,676',
#  '8,676',
#  '8,676',
#  '8,676',
#  '8,676',
#  '8,676',
#  '8,992',
#  '9,286',
#  '9,896',
#  '9,896',
#  '9,896',
#  '9,896',
#  '9,896',
#  '9,896',
#  '10,966',
#  '11,098',
#  '11,098',
#  '11,098',
#  '11,116',
#  '11,302',
#  '11,933',
#  '11,933',
#  '11,933',
#  '11,933',
#  '11,933',
#  '11,933',
#  '11,933',
#  '11,933',
#  '11,933',
#  '11,974',
#  '12,310',
#  '12,458',
#  '12,646',
#  '12,982',
#  '13,298',
#  '13,318',
#  '13,532',
#  '13,532',
#  '13,532',
#  '13,532',
#  '13,532',
#  '13,532',
#  '13,654',
#  '13,654',
#  '13,823',
#  '14,662',
#  '14,663',
#  '14,663',
#  '14,663',
#  '14,663',
#  '14,663',
#  '14,663',
#  '14,663',
#  '15,818',
#  '16,028',
#  '16,028',
#  '16,186',
#  '16,973',
#  '17,351',
#  '17,382',
#  '17,559',
#  '17,563',
# ...

# %%
duration_tag=driver.find_elements("xpath",'//p[@class="fs-12 bold du mb-2"]')
len(duration_tag)
# Out:
# 93

# %%
Duration=[]
for i in duration_tag:
    Duration.append(i.text)
Duration
# Out:
# ['2h 10m',
#  '2h 10m',
#  '2h 15m',
#  '10h 55m',
#  '2h 05m',
#  '5h 20m',
#  '10h 20m',
#  '14h 50m',
#  '16h 25m',
#  '26h 55m',
#  '8h 25m',
#  '9h 45m',
#  '7h 00m',
#  '7h 25m',
#  '8h 00m',
#  '9h 00m',
#  '9h 05m',
#  '6h 10m',
#  '9h 20m',
#  '11h 50m',
#  '13h 05m',
#  '14h 40m',
#  '15h 55m',
#  '2h 05m',
#  '8h 05m',
#  '7h 55m',
#  '9h 25m',
#  '11h 05m',
#  '12h 35m',
#  '12h 35m',
#  '15h 45m',
#  '4h 40m',
#  '7h 00m',
#  '11h 25m',
#  '12h 45m',
#  '21h 35m',
#  '8h 00m',
#  '6h 15m',
#  '7h 50m',
#  '9h 05m',
#  '12h 20m',
#  '12h 30m',
#  '15h 45m',
#  '16h 50m',
#  '22h 55m',
#  '26h 20m',
#  '5h 20m',
#  '5h 55m',
#  '27h 00m',
#  '8h 20m',
#  '11h 15m',
#  '12h 20m',
#  '9h 40m',
#  '5h 30m',
#  '5h 45m',
#  '6h 30m',
#  '11h 45m',
#  '13h 20m',
#  '14h 55m',
#  '8h 15m',
#  '9h 25m',
#  '22h 30m',
#  '2h 05m',
#  '2h 20m',
#  '10h 35m',
#  '12h 05m',
#  '15h 15m',
#  '24h 50m',
#  '25h 45m',
#  '26h 05m',
#  '9h 10m',
#  '12h 05m',
#  '19h 20m',
#  '22h 20m',
# ...

# %%
add_tag=driver.find_elements("xpath",'//span[@class="text"]')
len(add_tag)
# Out:
# 58

# %%
Add_info=[]
for i in add_tag:
    Add_info.append(i.text)
Add_info
# Out:
# ['Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal']

# %%
flights7 = pd.DataFrame({})
flights7['Airline'] = Airline
flights7['Destination'] = list1
flights7['Source'] = list2
flights7['Arrival_time'] = Arr_t
flights7['Departure_time'] =Dep_t
flights7['Total_Stops']=Total_s
flights7['Total_Duration'] = Duration
flights7['Additional_Info'] = pd.Series(Add_info)
flights7['Price']=price
flights7
# Out:
#       Airline Destination     Source Arrival_time  Departure_time Total_Stops  \
# 0      IndiGo     Kolkata  Hyderabad        03:05           05:15    Non Stop
# 1      IndiGo     Kolkata  Hyderabad        17:05           19:15    Non Stop
# 2      IndiGo     Kolkata  Hyderabad        15:00           17:15    Non Stop
# 3    Go First     Kolkata  Hyderabad        21:05  08:00\n+ 1 day      1 Stop
# 4    Air Asia     Kolkata  Hyderabad        12:10           14:15    Non Stop
# ..        ...         ...        ...          ...             ...         ...
# 88  Air India     Kolkata  Hyderabad        16:10  23:50\n+ 1 day   2 Stop(s)
# 89  Air India     Kolkata  Hyderabad        10:05  23:50\n+ 1 day   2 Stop(s)
# 90  Air India     Kolkata  Hyderabad        10:05  23:50\n+ 1 day   2 Stop(s)
# 91  Air India     Kolkata  Hyderabad        10:05  23:50\n+ 1 day   2 Stop(s)
# 92  Air India     Kolkata  Hyderabad        06:40  23:50\n+ 1 day   2 Stop(s)
#
# ...

# %%
driver = webdriver.Chrome(r'C:\Users\91749\Downloads\chromedriver_win32\chromedriver.exe')

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=MAA&originCountry=IN&destination=DEL&destinationCountry=IN&flight_depart_date=22%2F09%2F2022&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=340297921975'
driver.get(url)

# %%
airline_tag=driver.find_elements("xpath",'//span[@class="i-b text ellipsis"]')
len(airline)
# Out:
# 93

# %%
Airlines=[]
for i in airline_tag:
    Airlines.append(i.text)
Airlines
# Out:
# ['SpiceJet',
#  'IndiGo',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Vistara',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air Asia',
#  'IndiGo',
#  'Vistara',
#  'Air India',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'Air Asia',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'Vistara',
# ...

# %%
flight_no_tag=driver.find_elements("xpath",'//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]')
len(flight_no_tag)
# Out:
# 116

# %%
Flight_no=[]
for i in flight_no_tag:
    Flight_no.append(i.text)
Flight_no
# Out:
# ['SG-8104',
#  '6E-5038',
#  'UK-836',
#  '6E-2512',
#  '6E-2698',
#  '6E-6344',
#  '6E-2316',
#  '6E-2752',
#  'AI-538',
#  'UK-838',
#  'AI-440',
#  'AI-430',
#  'AI-539',
#  '6E-2098',
#  'G8-304/339',
#  'G8-304/322',
#  'G8-304/345',
#  'AI-672/660',
#  'AI-569/866',
#  'AI-569/809',
#  'AI-569/677',
#  'AI-569/687',
#  'AI-569/442',
#  'AI-569/660',
#  'AI-672/864',
#  'AI-672/806',
#  'AI-672/866',
#  'AI-672/677',
#  'AI-569/864',
#  'AI-672/687',
#  'UK-832',
#  '6E-2116',
#  'AI-672/888',
#  'AI-569/888',
#  'AI-672/809',
#  'AI-571/677',
#  '6E-6892/2514',
#  '6E-6892/2147',
#  'SG-612/8152',
#  'SG-612/8702',
#  'SG-612/8158',
#  '6E-6892/2401',
#  '6E-562/2106',
#  '6E-193/2324',
#  '6E-6137/869',
#  '6E-6805/2106',
#  '6E-6605/2147',
#  '6E-156/2335',
#  '6E-562/6684',
#  '6E-917/2069',
#  '6E-6805/6684',
#  '6E-562/2324',
#  '6E-193/2335',
#  '6E-6805/2324',
#  '6E-6605/2174',
#  'I5-821/722',
#  '6E-905/6081',
#  'UK-834',
#  'AI-672/637/532',
#  '6E-269/2063',
# ...

# %%
source_tag=driver.find_elements('xpath','//p[@class="fs-10 font-lightgrey no-wrap city ellipsis"]')
len(source_tag)
# Out:
# 232

# %%
sourcess=[]
for i in source_tag:
    sourcess.append(i.text)
sourcess
# Out:
# ['Chennai',
#  'New Delhi',
#  'Chennai',
#  'New Delhi',
#  'Chennai',
#  'New Delhi',
#  'Chennai',
#  'New Delhi',
#  'Chennai',
#  'New Delhi',
#  'Chennai',
#  'New Delhi',
#  'Chennai',
#  'New Delhi',
#  'Chennai',
#  'New Delhi',
#  'Chennai',
#  'New Delhi',
#  'Chennai',
#  'New Delhi',
#  'Chennai',
#  'New Delhi',
#  'Chennai',
#  'New Delhi',
#  'Chennai',
#  'New Delhi',
#  'Chennai',
#  'New Delhi',
#  'Chennai',
#  'New Delhi',
#  'Chennai',
#  'New Delhi',
#  'Chennai',
#  'New Delhi',
#  'Chennai',
#  'New Delhi',
#  'Chennai',
#  'New Delhi',
#  'Chennai',
#  'New Delhi',
#  'Chennai',
#  'New Delhi',
#  'Chennai',
#  'New Delhi',
#  'Chennai',
#  'New Delhi',
#  'Chennai',
#  'New Delhi',
#  'Chennai',
#  'New Delhi',
#  'Chennai',
#  'New Delhi',
#  'Chennai',
#  'New Delhi',
#  'Chennai',
#  'New Delhi',
#  'Chennai',
#  'New Delhi',
#  'Chennai',
#  'New Delhi',
#  'Chennai',
#  'New Delhi',
#  'Chennai',
#  'New Delhi',
#  'Chennai',
#  'New Delhi',
# ...

# %%
list1 = [sourcess[i] for i in range(len(sourcess)) if i % 2 != 0]

# %%
len(list1)
# Out:
# 116

# %%
list1
# Out:
# ['New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
#  'New Delhi',
# ...

# %%
list2=sourcess[::2]

# %%
len(list2)
# Out:
# 116

# %%
list2
# Out:
# ['Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
# ...

# %%
arr_tag=driver.find_elements("xpath",'//div[@class="fs-15 bold time"]')
len(arr_tag)
# Out:
# 116

# %%
Arri_t=[]
for i in arr_tag:
    Arri_t.append(i.text)
Arri_t
# Out:
# ['18:00',
#  '08:45',
#  '10:35',
#  '10:40',
#  '02:30',
#  '13:30',
#  '16:35',
#  '19:35',
#  '20:15',
#  '21:05',
#  '06:00',
#  '09:55',
#  '16:55',
#  '22:50',
#  '13:45',
#  '13:45',
#  '13:45',
#  '15:25',
#  '06:10',
#  '06:10',
#  '06:10',
#  '06:10',
#  '06:10',
#  '06:10',
#  '15:25',
#  '15:25',
#  '15:25',
#  '15:25',
#  '06:10',
#  '15:25',
#  '07:05',
#  '06:20',
#  '15:25',
#  '06:10',
#  '15:25',
#  '07:55',
#  '11:20',
#  '11:20',
#  '22:00',
#  '22:00',
#  '22:00',
#  '11:20',
#  '17:00',
#  '19:25',
#  '09:00',
#  '16:25',
#  '13:00',
#  '21:20',
#  '17:00',
#  '12:00',
#  '16:25',
#  '17:00',
#  '19:25',
#  '16:25',
#  '13:00',
#  '22:35',
#  '08:15',
#  '17:15',
#  '15:25',
#  '09:25',
#  '09:45',
#  '07:00',
#  '12:00',
#  '07:45',
#  '22:35',
#  '06:10',
#  '06:10',
#  '12:30',
#  '07:00',
#  '09:45',
#  '07:00',
#  '07:55',
#  '07:55',
#  '06:35',
#  '06:35',
#  '22:35',
#  '09:00',
#  '07:00',
#  '08:10',
#  '08:10',
#  '09:45',
#  '21:35',
#  '07:00',
# ...

# %%
dep_tag=driver.find_elements("xpath",'//p[@class="bold fs-15 mb-2 pr time"]')
len(dep_tag)
# Out:
# 116

# %%
Depa_t=[]
for i in dep_tag:
    Depa_t.append(i.text)
Depa_t
# Out:
# ['20:45',
#  '11:30',
#  '13:20',
#  '13:25',
#  '05:20',
#  '16:20',
#  '19:25',
#  '22:25',
#  '23:05',
#  '23:55',
#  '08:55',
#  '12:50',
#  '19:50',
#  '01:45\n+ 1 day',
#  '20:55',
#  '00:45\n+ 1 day',
#  '01:10\n+ 1 day',
#  '20:10',
#  '11:20',
#  '12:20',
#  '15:15',
#  '18:20',
#  '19:10',
#  '20:10',
#  '09:05\n+ 1 day',
#  '10:15\n+ 1 day',
#  '11:20\n+ 1 day',
#  '15:15\n+ 1 day',
#  '09:05\n+ 1 day',
#  '18:20\n+ 1 day',
#  '09:45',
#  '08:55',
#  '21:15',
#  '21:15',
#  '12:20\n+ 1 day',
#  '15:15',
#  '17:45',
#  '19:15',
#  '09:35\n+ 1 day',
#  '18:20\n+ 1 day',
#  '22:00\n+ 1 day',
#  '16:40',
#  '22:20',
#  '00:45\n+ 1 day',
#  '14:40',
#  '22:20',
#  '19:15',
#  '03:35\n+ 1 day',
#  '23:30',
#  '18:35',
#  '23:30',
#  '00:45\n+ 1 day',
#  '03:35\n+ 1 day',
#  '00:45\n+ 1 day',
#  '20:45',
#  '03:30\n+ 1 day',
#  '15:55',
#  '20:00',
#  '23:20',
#  '16:15',
#  '16:55',
#  '16:55',
#  '20:15',
#  '14:40',
#  '08:55\n+ 1 day',
#  '18:30',
#  '17:10\n+ 1 day',
# ...

# %%
total_s=driver.find_elements("xpath",'//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')
len(total_s)
# Out:
# 116

# %%
Total_s=[]
for i in total_s:
    Total_s.append(i.text)
Total_s
# Out:
# ['Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
# ...

# %%
cost_tag=driver.find_elements("xpath",'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
len(cost_tag)
# Out:
# 116

# %%
prices=[]
for i in cost_tag:
    prices.append(i.text)
prices
# Out:
# ['7,512',
#  '7,513',
#  '7,513',
#  '7,513',
#  '7,513',
#  '7,513',
#  '7,513',
#  '7,513',
#  '7,513',
#  '7,513',
#  '7,513',
#  '7,513',
#  '7,513',
#  '7,513',
#  '8,035',
#  '8,035',
#  '8,035',
#  '8,112',
#  '8,112',
#  '8,112',
#  '8,112',
#  '8,112',
#  '8,112',
#  '8,112',
#  '8,112',
#  '8,112',
#  '8,112',
#  '8,112',
#  '8,112',
#  '8,112',
#  '8,175',
#  '8,371',
#  '8,637',
#  '8,637',
#  '8,637',
#  '8,847',
#  '9,377',
#  '9,377',
#  '9,508',
#  '9,508',
#  '9,508',
#  '10,033',
#  '10,033',
#  '10,033',
#  '10,033',
#  '10,033',
#  '10,033',
#  '10,033',
#  '10,033',
#  '10,033',
#  '10,033',
#  '10,033',
#  '10,033',
#  '10,033',
#  '10,632',
#  '10,795',
#  '10,871',
#  '10,978',
#  '11,157',
#  '11,230',
#  '11,608',
#  '11,608',
#  '11,713',
#  '11,829',
#  '11,845',
#  '11,997',
#  '12,174',
#  '12,480',
#  '12,480',
#  '12,480',
#  '12,480',
#  '12,732',
#  '12,909',
#  '13,026',
#  '13,026',
#  '13,629',
#  '14,223',
#  '14,231',
#  '14,601',
#  '14,601',
# ...

# %%
duration_tag=driver.find_elements("xpath",'//p[@class="fs-12 bold du mb-2"]')
len(duration_tag)
# Out:
# 116

# %%
Duration=[]
for i in duration_tag:
    Duration.append(i.text)
Duration
# Out:
# ['2h 45m',
#  '2h 45m',
#  '2h 45m',
#  '2h 45m',
#  '2h 50m',
#  '2h 50m',
#  '2h 50m',
#  '2h 50m',
#  '2h 50m',
#  '2h 50m',
#  '2h 55m',
#  '2h 55m',
#  '2h 55m',
#  '2h 55m',
#  '7h 10m',
#  '11h 00m',
#  '11h 25m',
#  '4h 45m',
#  '5h 10m',
#  '6h 10m',
#  '9h 05m',
#  '12h 10m',
#  '13h 00m',
#  '14h 00m',
#  '17h 40m',
#  '18h 50m',
#  '19h 55m',
#  '23h 50m',
#  '26h 55m',
#  '26h 55m',
#  '2h 40m',
#  '2h 35m',
#  '5h 50m',
#  '15h 05m',
#  '20h 55m',
#  '7h 20m',
#  '6h 25m',
#  '7h 55m',
#  '11h 35m',
#  '20h 20m',
#  '24h 00m',
#  '5h 20m',
#  '5h 20m',
#  '5h 20m',
#  '5h 40m',
#  '5h 55m',
#  '6h 15m',
#  '6h 15m',
#  '6h 30m',
#  '6h 35m',
#  '7h 05m',
#  '7h 45m',
#  '8h 10m',
#  '8h 20m',
#  '7h 45m',
#  '4h 55m',
#  '7h 40m',
#  '2h 45m',
#  '7h 55m',
#  '6h 50m',
#  '7h 10m',
#  '9h 55m',
#  '8h 15m',
#  '6h 55m',
#  '10h 20m',
#  '12h 20m',
#  '35h 00m',
#  '5h 35m',
#  '7h 05m',
#  '8h 20m',
#  '11h 05m',
#  '10h 35m',
#  '33h 15m',
#  '5h 35m',
#  '7h 20m',
# ...

# %%
add_tag=driver.find_elements("xpath",'//span[@class="text"]')
len(add_tag)
# Out:
# 68

# %%
Add_info=[]
for i in add_tag:
    Add_info.append(i.text)
Add_info
# Out:
# ['Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
# ...

# %%
flights8 = pd.DataFrame({})
flights8['Airline'] = Airlines
flights8['Destination'] = list1
flights8['Source'] = list2
flights8['Arrival_time'] = Arri_t
flights8['Departure_time'] =Depa_t
flights8['Total_Stops']=Total_s
flights8['Total_Duration'] = Duration
flights8['Additional_Info'] = pd.Series(Add_info)
flights8['Price']=prices
flights8
# Out:
#       Airline Destination   Source Arrival_time  Departure_time Total_Stops  \
# 0    SpiceJet   New Delhi  Chennai        18:00           20:45    Non Stop
# 1      IndiGo   New Delhi  Chennai        08:45           11:30    Non Stop
# 2     Vistara   New Delhi  Chennai        10:35           13:20    Non Stop
# 3      IndiGo   New Delhi  Chennai        10:40           13:25    Non Stop
# 4      IndiGo   New Delhi  Chennai        02:30           05:20    Non Stop
# ..        ...         ...      ...          ...             ...         ...
# 111   Vistara   New Delhi  Chennai        12:30  14:20\n+ 1 day   2 Stop(s)
# 112   Vistara   New Delhi  Chennai        09:45  12:40\n+ 1 day   2 Stop(s)
# 113   Vistara   New Delhi  Chennai        09:45  14:20\n+ 1 day   2 Stop(s)
# 114   Vistara   New Delhi  Chennai        07:00  12:40\n+ 1 day   2 Stop(s)
# 115   Vistara   New Delhi  Chennai        12:30           21:25   2 Stop(s)
#
#     Total_Duration Additional_Info   Price
# ...

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=PNQ&destinationCountry=IN&flexi=0&flight_depart_date=20%2F09%2F2022&hb=&noOfSegments=1&origin=MAA&originCountry=IN&type=O&unique=1663586704565&viewName=normal'
driver.get(url)

# %%
airline_tag=driver.find_elements("xpath",'//span[@class="i-b text ellipsis"]')
len(airline_tag)
# Out:
# 71

# %%
Airlines=[]
for i in airline_tag:
    Airlines.append(i.text)
Airlines
# Out:
# ['IndiGo',
#  'IndiGo',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
# ...

# %%
flight_no_tag=driver.find_elements("xpath",'//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]')
len(flight_no_tag)
# Out:
# 71

# %%
Flight_no=[]
for i in flight_no_tag:
    Flight_no.append(i.text)
Flight_no
# Out:
# ['6E-401',
#  '6E-6232/241',
#  'I5-821/386',
#  '6E-156/351',
#  '6E-597/241',
#  '6E-6805/118',
#  '6E-495/6058',
#  '6E-6225/408',
#  '6E-6143/674',
#  '6E-237/674',
#  '6E-6011/674',
#  'AI-430/849',
#  'AI-440/857',
#  'AI-538/851',
#  'AI-430/853',
#  'AI-440/849',
#  'AI-539/851',
#  'AI-440/853',
#  'AI-538/481',
#  'AI-538/857',
#  'AI-539/481',
#  'AI-430/851',
#  'AI-538/849',
#  'AI-539/857',
#  'AI-538/853',
#  'AI-440/851',
#  'AI-539/849',
#  'AI-430/481',
#  'AI-539/853',
#  'AI-440/481',
#  '6E-6127/674',
#  '6E-727',
#  '6E-862',
#  'UK-838/997',
#  '6E-6225/699',
#  '6E-562/118',
#  '6E-193/351',
#  '6E-502',
#  'UK-832/997',
#  'UK-838/971',
#  'UK-832/973',
#  'UK-838/991',
#  '6E-6605/528',
#  '6E-917/202',
#  '6E-189/699',
#  '6E-6892/528',
#  '6E-6137/6104',
#  'UK-836/997',
#  'UK-836/991',
#  'UK-836/973',
#  'UK-832/991',
#  '6E-5028/6877',
#  '6E-6137/528',
#  'AI-672/637/481',
#  'AI-538/817/481',
#  'AI-539/817/481',
#  'AI-430/817/481',
# ...

# %%
source_tag=driver.find_elements('xpath','//p[@class="fs-10 font-lightgrey no-wrap city ellipsis"]')
len(source_tag)
# Out:
# 142

# %%
sources=[]
for i in source_tag:
    sources.append(i.text)
sources
# Out:
# ['Chennai',
#  'Pune',
#  'Chennai',
#  'Pune',
#  'Chennai',
#  'Pune',
#  'Chennai',
#  'Pune',
#  'Chennai',
#  'Pune',
#  'Chennai',
#  'Pune',
#  'Chennai',
#  'Pune',
#  'Chennai',
#  'Pune',
#  'Chennai',
#  'Pune',
#  'Chennai',
#  'Pune',
#  'Chennai',
#  'Pune',
#  'Chennai',
#  'Pune',
#  'Chennai',
#  'Pune',
#  'Chennai',
#  'Pune',
#  'Chennai',
#  'Pune',
#  'Chennai',
#  'Pune',
#  'Chennai',
#  'Pune',
#  'Chennai',
#  'Pune',
#  'Chennai',
#  'Pune',
#  'Chennai',
#  'Pune',
#  'Chennai',
#  'Pune',
#  'Chennai',
#  'Pune',
#  'Chennai',
#  'Pune',
#  'Chennai',
#  'Pune',
#  'Chennai',
#  'Pune',
#  'Chennai',
#  'Pune',
#  'Chennai',
#  'Pune',
#  'Chennai',
#  'Pune',
#  'Chennai',
#  'Pune',
#  'Chennai',
#  'Pune',
#  'Chennai',
#  'Pune',
#  'Chennai',
#  'Pune',
#  'Chennai',
#  'Pune',
#  'Chennai',
#  'Pune',
#  'Chennai',
#  'Pune',
#  'Chennai',
#  'Pune',
#  'Chennai',
#  'Pune',
#  'Chennai',
#  'Pune',
#  'Chennai',
#  'Pune',
#  'Chennai',
#  'Pune',
# ...

# %%
list1 = [sources[i] for i in range(len(sources)) if i % 2 != 0]

# %%
list1
# Out:
# ['Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune']

# %%
list2=sources[::2]

# %%
list2
# Out:
# ['Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai',
#  'Chennai']

# %%
arr_tag=driver.find_elements("xpath",'//div[@class="fs-15 bold time"]')
len(arr_tag)
# Out:
# 71

# %%
Arri_t=[]
for i in arr_tag:
    Arri_t.append(i.text)
Arri_t
# Out:
# ['03:30',
#  '21:10',
#  '22:35',
#  '21:20',
#  '17:25',
#  '16:25',
#  '06:35',
#  '21:35',
#  '19:00',
#  '16:15',
#  '14:35',
#  '09:55',
#  '06:00',
#  '20:15',
#  '09:55',
#  '06:00',
#  '16:55',
#  '06:00',
#  '20:15',
#  '20:15',
#  '16:55',
#  '09:55',
#  '20:15',
#  '16:55',
#  '20:15',
#  '06:00',
#  '16:55',
#  '09:55',
#  '16:55',
#  '06:00',
#  '12:35',
#  '14:55',
#  '22:35',
#  '21:05',
#  '21:35',
#  '17:00',
#  '19:25',
#  '09:05',
#  '07:05',
#  '21:05',
#  '07:05',
#  '21:05',
#  '13:00',
#  '12:00',
#  '19:10',
#  '11:20',
#  '09:00',
#  '10:35',
#  '10:35',
#  '10:35',
#  '07:05',
#  '17:50',
#  '09:00',
#  '15:25',
#  '20:15',
#  '16:55',
#  '09:55',
#  '06:00',
#  '12:30',
#  '12:30',
#  '09:45',
#  '09:45',
#  '19:25',
#  '17:15',
#  '12:30',
#  '13:00',
#  '17:15',
#  '09:45',
#  '16:20',
#  '07:00',
#  '09:45']

# %%
dep_tag=driver.find_elements("xpath",'//p[@class="bold fs-15 mb-2 pr time"]')
len(dep_tag)
# Out:
# 71

# %%
Depa_t=[]
for i in dep_tag:
    Depa_t.append(i.text)
Depa_t
# Out:
# ['05:05',
#  '03:35\n+ 1 day',
#  '05:00\n+ 1 day',
#  '05:45\n+ 1 day',
#  '03:35\n+ 1 day',
#  '23:30',
#  '15:10',
#  '06:50\n+ 1 day',
#  '23:00',
#  '23:00',
#  '23:00',
#  '18:10',
#  '15:20',
#  '07:00\n+ 1 day',
#  '21:10',
#  '18:10',
#  '07:00\n+ 1 day',
#  '21:10',
#  '12:10\n+ 1 day',
#  '15:20\n+ 1 day',
#  '12:10\n+ 1 day',
#  '07:00\n+ 1 day',
#  '18:10\n+ 1 day',
#  '15:20\n+ 1 day',
#  '21:10\n+ 1 day',
#  '07:00\n+ 1 day',
#  '18:10\n+ 1 day',
#  '12:10\n+ 1 day',
#  '21:10\n+ 1 day',
#  '12:10\n+ 1 day',
#  '23:00',
#  '16:35',
#  '00:20\n+ 1 day',
#  '16:20\n+ 1 day',
#  '03:55\n+ 1 day',
#  '23:30',
#  '05:45\n+ 1 day',
#  '10:30',
#  '16:20',
#  '10:40\n+ 1 day',
#  '23:05',
#  '20:00\n+ 1 day',
#  '18:25',
#  '17:15',
#  '03:55\n+ 1 day',
#  '18:25',
#  '12:20',
#  '16:20',
#  '20:00',
#  '23:05',
#  '20:00',
#  '02:40\n+ 1 day',
#  '18:25',
#  '12:10\n+ 1 day',
#  '12:10\n+ 1 day',
#  '12:10\n+ 1 day',
#  '12:10\n+ 1 day',
#  '12:10\n+ 1 day',
# ...

# %%
total_s=driver.find_elements("xpath",'//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')
len(total_s)
# Out:
# 71

# %%
Total_s=[]
for i in total_s:
    Total_s.append(i.text)
Total_s
# Out:
# ['Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)']

# %%
cost_tag=driver.find_elements("xpath",'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
len(cost_tag)
# Out:
# 71

# %%
prices=[]
for i in cost_tag:
    prices.append(i.text)
prices
# Out:
# ['7,198',
#  '7,198',
#  '7,198',
#  '7,198',
#  '7,555',
#  '9,340',
#  '9,340',
#  '9,340',
#  '9,666',
#  '9,666',
#  '9,666',
#  '10,170',
#  '10,170',
#  '10,170',
#  '10,170',
#  '10,170',
#  '10,170',
#  '10,170',
#  '10,170',
#  '10,170',
#  '10,170',
#  '10,170',
#  '10,170',
#  '10,170',
#  '10,170',
#  '10,170',
#  '10,170',
#  '10,170',
#  '10,170',
#  '10,170',
#  '10,243',
#  '10,453',
#  '10,453',
#  '10,453',
#  '10,768',
#  '11,125',
#  '11,125',
#  '11,188',
#  '11,526',
#  '11,526',
#  '11,526',
#  '11,526',
#  '11,733',
#  '11,839',
#  '11,839',
#  '12,533',
#  '12,910',
#  '13,349',
#  '13,349',
#  '13,349',
#  '13,349',
#  '13,446',
#  '13,981',
#  '14,023',
#  '14,055',
#  '14,055',
#  '14,055',
#  '14,055',
#  '14,634',
#  '14,634',
#  '14,634',
#  '14,634',
#  '15,651',
#  '17,226',
#  '18,045',
#  '18,400',
#  '18,969',
#  '21,195',
#  '23,211',
#  '23,998',
#  '23,998']

# %%
duration_tag=driver.find_elements("xpath",'//p[@class="fs-12 bold du mb-2"]')
len(duration_tag)
# Out:
# 71

# %%
Duration=[]
for i in duration_tag:
    Duration.append(i.text)
Duration
# Out:
# ['1h 35m',
#  '6h 25m',
#  '6h 25m',
#  '8h 25m',
#  '10h 10m',
#  '7h 05m',
#  '8h 35m',
#  '9h 15m',
#  '4h 00m',
#  '6h 45m',
#  '8h 25m',
#  '8h 15m',
#  '9h 20m',
#  '10h 45m',
#  '11h 15m',
#  '12h 10m',
#  '14h 05m',
#  '15h 10m',
#  '15h 55m',
#  '19h 05m',
#  '19h 15m',
#  '21h 05m',
#  '21h 55m',
#  '22h 25m',
#  '24h 55m',
#  '25h 00m',
#  '25h 15m',
#  '26h 15m',
#  '28h 15m',
#  '30h 10m',
#  '10h 25m',
#  '1h 40m',
#  '1h 45m',
#  '19h 15m',
#  '6h 20m',
#  '6h 30m',
#  '10h 20m',
#  '1h 25m',
#  '9h 15m',
#  '13h 35m',
#  '16h 00m',
#  '22h 55m',
#  '5h 25m',
#  '5h 15m',
#  '8h 45m',
#  '7h 05m',
#  '3h 20m',
#  '5h 45m',
#  '9h 25m',
#  '12h 30m',
#  '12h 55m',
#  '8h 50m',
#  '9h 25m',
#  '20h 45m',
#  '15h 55m',
#  '19h 15m',
#  '26h 15m',
#  '30h 10m',
#  '17h 25m',
#  '17h 25m',
#  '20h 10m',
#  '20h 10m',
#  '4h 05m',
#  '5h 50m',
#  '10h 35m',
#  '8h 45m',
#  '17h 25m',
#  '10h 15m',
#  '5h 25m',
#  '9h 20m',
#  '10h 15m']

# %%
add_tag=driver.find_elements("xpath",'//span[@class="text"]')
len(add_tag)
# Out:
# 43

# %%
Add_info=[]
for i in add_tag:
    Add_info.append(i.text)
Add_info
# Out:
# ['Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal']

# %%
flights9 = pd.DataFrame({})
flights9['Airline'] = Airlines
flights9['Destination'] = list1
flights9['Source'] = list2
flights9['Arrival_time'] = Arri_t
flights9['Departure_time'] =Depa_t
flights9['Total_Stops']=Total_s
flights9['Total_Duration'] = Duration
flights9['Additional_Info'] =pd.Series(Add_info)
flights9['Price']=prices
flights9
# Out:
#      Airline Destination   Source Arrival_time  Departure_time Total_Stops  \
# 0     IndiGo        Pune  Chennai        03:30           05:05    Non Stop
# 1     IndiGo        Pune  Chennai        21:10  03:35\n+ 1 day      1 Stop
# 2   Air Asia        Pune  Chennai        22:35  05:00\n+ 1 day      1 Stop
# 3     IndiGo        Pune  Chennai        21:20  05:45\n+ 1 day      1 Stop
# 4     IndiGo        Pune  Chennai        17:25  03:35\n+ 1 day      1 Stop
# ..       ...         ...      ...          ...             ...         ...
# 66   Vistara        Pune  Chennai        17:15  10:40\n+ 1 day      1 Stop
# 67   Vistara        Pune  Chennai        09:45           20:00   2 Stop(s)
# 68    IndiGo        Pune  Chennai        16:20           21:45      1 Stop
# 69   Vistara        Pune  Chennai        07:00           16:20   2 Stop(s)
# 70   Vistara        Pune  Chennai        09:45           20:00   2 Stop(s)
#
#    Total_Duration Additional_Info   Price
# ...

# %%
Flights1=pd.concat([flights6,flights7,flights8,flights9],ignore_index=True)

# %%
Flights1.shape
# Out:
# (355, 9)

# %%
Flights2=pd.concat([Flights,Flights1],ignore_index=True)

# %%
Flights2.shape
# Out:
# (1014, 9)

# %%
Flights2.head(10)
# Out:
#     Airline Destination     Source Arrival_time Departure_time Total_Stops  \
# 0  Go First      Mumbai  New Delhi        02:40          04:50    Non Stop
# 1  Go First      Mumbai  New Delhi        08:15          10:25    Non Stop
# 2  Go First      Mumbai  New Delhi        15:45          17:55    Non Stop
# 3  SpiceJet      Mumbai  New Delhi        19:00          21:10    Non Stop
# 4  Go First      Mumbai  New Delhi        20:50          23:00    Non Stop
# 5  SpiceJet      Mumbai  New Delhi        07:20          09:35    Non Stop
# 6  Go First      Mumbai  New Delhi        18:20          20:35    Non Stop
# 7  SpiceJet      Mumbai  New Delhi        21:40          23:55    Non Stop
# 8    IndiGo      Mumbai  New Delhi        15:25          17:20    Non Stop
# 9    IndiGo      Mumbai  New Delhi        11:55          13:55    Non Stop
#
#   Total_Duration Additional_Info  Price
# 0         2h 10m       Free Meal  5,950
# 1         2h 10m       Free Meal  5,950
# ...

# %%
# Connecting to the webdriver.

driver = webdriver.Chrome(r'C:\Users\91749\Downloads\chromedriver_win32\chromedriver.exe')

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=CCU&destinationCountry=IN&flexi=0&flight_depart_date=20%2F09%2F2022&hb=0&noOfSegments=1&origin=PNQ&originCountry=IN&type=O&unique=161456816893&version=1.1&viewName=normal'
driver.get(url)

# %%
airline_tag=driver.find_elements("xpath",'//span[@class="i-b text ellipsis"]')
len(airline_tag)
# Out:
# 45

# %%
Airlines=[]
for i in airline_tag:
    Airlines.append(i.text)
Airlines
# Out:
# ['IndiGo',
#  'Go First',
#  'SpiceJet',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'Air Asia',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'Air Asia',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara']

# %%
source_tag=driver.find_elements('xpath','//p[@class="fs-10 font-lightgrey no-wrap city ellipsis"]')
len(source_tag)
# Out:
# 90

# %%
sources=[]
for i in source_tag:
    sources.append(i.text)
sources
# Out:
# ['Pune',
#  'Kolkata',
#  'Pune',
#  'Kolkata',
#  'Pune',
#  'Kolkata',
#  'Pune',
#  'Kolkata',
#  'Pune',
#  'Kolkata',
#  'Pune',
#  'Kolkata',
#  'Pune',
#  'Kolkata',
#  'Pune',
#  'Kolkata',
#  'Pune',
#  'Kolkata',
#  'Pune',
#  'Kolkata',
#  'Pune',
#  'Kolkata',
#  'Pune',
#  'Kolkata',
#  'Pune',
#  'Kolkata',
#  'Pune',
#  'Kolkata',
#  'Pune',
#  'Kolkata',
#  'Pune',
#  'Kolkata',
#  'Pune',
#  'Kolkata',
#  'Pune',
#  'Kolkata',
#  'Pune',
#  'Kolkata',
#  'Pune',
#  'Kolkata',
#  'Pune',
#  'Kolkata',
#  'Pune',
#  'Kolkata',
#  'Pune',
#  'Kolkata',
#  'Pune',
#  'Kolkata',
#  'Pune',
#  'Kolkata',
#  'Pune',
#  'Kolkata',
#  'Pune',
#  'Kolkata',
#  'Pune',
#  'Kolkata',
#  'Pune',
#  'Kolkata',
#  'Pune',
#  'Kolkata',
#  'Pune',
#  'Kolkata',
#  'Pune',
#  'Kolkata',
#  'Pune',
#  'Kolkata',
#  'Pune',
#  'Kolkata',
#  'Pune',
#  'Kolkata',
#  'Pune',
#  'Kolkata',
#  'Pune',
#  'Kolkata',
#  'Pune',
#  'Kolkata',
#  'Pune',
#  'Kolkata',
#  'Pune',
#  'Kolkata',
# ...

# %%
list1 = [sources[i] for i in range(len(sources)) if i % 2 != 0]
list1
# Out:
# ['Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata']

# %%
list2=sources[::2]
list2
# Out:
# ['Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune',
#  'Pune']

# %%
arr_tag=driver.find_elements("xpath",'//div[@class="fs-15 bold time"]')
len(arr_tag)
# Out:
# 45

# %%
Arri_t=[]
for i in arr_tag:
    Arri_t.append(i.text)
Arri_t
# Out:
# ['16:15',
#  '22:15',
#  '17:35',
#  '16:55',
#  '20:35',
#  '16:55',
#  '20:35',
#  '20:35',
#  '16:55',
#  '20:35',
#  '16:55',
#  '15:55',
#  '21:55',
#  '18:50',
#  '21:55',
#  '15:55',
#  '18:50',
#  '21:55',
#  '15:55',
#  '18:50',
#  '19:05',
#  '17:50',
#  '20:35',
#  '16:55',
#  '20:50',
#  '19:05',
#  '19:15',
#  '21:55',
#  '18:50',
#  '15:55',
#  '18:55',
#  '18:55',
#  '18:55',
#  '18:50',
#  '15:55',
#  '17:40',
#  '19:15',
#  '18:55',
#  '18:55',
#  '20:35',
#  '18:55',
#  '16:55',
#  '18:55',
#  '20:35',
#  '20:35']

# %%
dep_tag=driver.find_elements("xpath",'//p[@class="bold fs-15 mb-2 pr time"]')
len(dep_tag)
# Out:
# 45

# %%
Depa_t=[]
for i in dep_tag:
    Depa_t.append(i.text)
Depa_t
# Out:
# ['00:15\n+ 1 day',
#  '08:00\n+ 1 day',
#  '09:05\n+ 1 day',
#  '22:45',
#  '08:20\n+ 1 day',
#  '08:20\n+ 1 day',
#  '18:05\n+ 1 day',
#  '19:35\n+ 1 day',
#  '18:05\n+ 1 day',
#  '22:45\n+ 1 day',
#  '19:35\n+ 1 day',
#  '23:05',
#  '14:30\n+ 1 day',
#  '14:30\n+ 1 day',
#  '19:10\n+ 1 day',
#  '14:30\n+ 1 day',
#  '19:10\n+ 1 day',
#  '22:25\n+ 1 day',
#  '19:10\n+ 1 day',
#  '22:25\n+ 1 day',
#  '00:35\n+ 1 day',
#  '22:30',
#  '09:35\n+ 1 day',
#  '09:35\n+ 1 day',
#  '05:05\n+ 1 day',
#  '02:00\n+ 1 day',
#  '02:05\n+ 1 day',
#  '09:00\n+ 1 day',
#  '09:00\n+ 1 day',
#  '09:00\n+ 1 day',
#  '18:05\n+ 1 day',
#  '19:35\n+ 1 day',
#  '22:45\n+ 1 day',
#  '08:15\n+ 1 day',
#  '08:15\n+ 1 day',
#  '23:15',
#  '11:15\n+ 1 day',
#  '18:05\n+ 1 day',
#  '16:55\n+ 1 day',
#  '16:55\n+ 1 day',
#  '16:55\n+ 1 day',
#  '09:40\n+ 1 day',
#  '09:40\n+ 1 day',
#  '16:55\n+ 1 day',
#  '16:55\n+ 1 day']

# %%
total_s=driver.find_elements("xpath",'//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')
len(total_s)
# Out:
# 45

# %%
Total_s=[]
for i in total_s:
    Total_s.append(i.text)
Total_s
# Out:
# ['1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)']

# %%
cost_tag=driver.find_elements("xpath",'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
len(cost_tag)
# Out:
# 45

# %%
prices=[]
for i in cost_tag:
    prices.append(i.text)
prices
# Out:
# ['9,723',
#  '9,723',
#  '9,723',
#  '11,006',
#  '11,006',
#  '11,006',
#  '11,006',
#  '11,006',
#  '11,006',
#  '11,006',
#  '11,006',
#  '11,823',
#  '11,823',
#  '11,823',
#  '11,823',
#  '11,823',
#  '11,823',
#  '11,823',
#  '11,823',
#  '11,823',
#  '11,907',
#  '11,981',
#  '12,976',
#  '12,976',
#  '12,999',
#  '13,766',
#  '15,314',
#  '15,341',
#  '15,341',
#  '15,341',
#  '16,055',
#  '16,055',
#  '16,055',
#  '16,559',
#  '16,559',
#  '16,821',
#  '16,890',
#  '18,950',
#  '22,880',
#  '23,751',
#  '24,665',
#  '25,744',
#  '27,185',
#  '28,056',
#  '30,366']

# %%
duration_tag=driver.find_elements("xpath",'//p[@class="fs-12 bold du mb-2"]')
len(duration_tag)
# Out:
# 45

# %%
Duration=[]
for i in duration_tag:
    Duration.append(i.text)
Duration
# Out:
# ['8h 00m',
#  '9h 45m',
#  '15h 30m',
#  '5h 50m',
#  '11h 45m',
#  '15h 25m',
#  '21h 30m',
#  '23h 00m',
#  '25h 10m',
#  '26h 10m',
#  '26h 40m',
#  '7h 10m',
#  '16h 35m',
#  '19h 40m',
#  '21h 15m',
#  '22h 35m',
#  '24h 20m',
#  '24h 30m',
#  '27h 15m',
#  '27h 35m',
#  '5h 30m',
#  '4h 40m',
#  '13h 00m',
#  '16h 40m',
#  '8h 15m',
#  '6h 55m',
#  '6h 50m',
#  '11h 05m',
#  '14h 10m',
#  '17h 05m',
#  '23h 10m',
#  '24h 40m',
#  '27h 50m',
#  '13h 25m',
#  '16h 20m',
#  '5h 35m',
#  '16h 00m',
#  '23h 10m',
#  '22h 00m',
#  '20h 20m',
#  '22h 00m',
#  '16h 45m',
#  '14h 45m',
#  '20h 20m',
#  '20h 20m']

# %%
add_tag=driver.find_elements("xpath",'//span[@class="text"]')
len(add_tag)
# Out:
# 35

# %%
Add_info=[]
for i in add_tag:
    Add_info.append(i.text)
Add_info
# Out:
# ['Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal',
#  'Free Meal']

# %%
flights10 = pd.DataFrame({})
flights10['Airline'] = Airlines
flights10['Destination'] = list1
flights10['Source'] = list2
flights10['Arrival_time'] = Arri_t
flights10['Departure_time'] =Depa_t
flights10['Total_Stops']=Total_s
flights10['Total_Duration'] = Duration
flights10['Additional_Info'] = pd.Series(Add_info)
flights10['Price']=prices
flights10.head()
# Out:
#     Airline Destination Source Arrival_time  Departure_time Total_Stops  \
# 0    IndiGo     Kolkata   Pune        16:15  00:15\n+ 1 day      1 Stop
# 1  Go First     Kolkata   Pune        22:15  08:00\n+ 1 day      1 Stop
# 2  SpiceJet     Kolkata   Pune        17:35  09:05\n+ 1 day      1 Stop
# 3   Vistara     Kolkata   Pune        16:55           22:45      1 Stop
# 4   Vistara     Kolkata   Pune        20:35  08:20\n+ 1 day      1 Stop
#
#   Total_Duration Additional_Info   Price
# 0         8h 00m       Free Meal   9,723
# 1         9h 45m       Free Meal   9,723
# 2        15h 30m       Free Meal   9,723
# 3         5h 50m       Free Meal  11,006
# 4        11h 45m       Free Meal  11,006

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BLR&destinationCountry=IN&flexi=0&flight_depart_date=20%2F09%2F2022&hb=0&noOfSegments=1&origin=CCU&originCountry=IN&type=O&unique=732215010118&version=1.1&viewName=normal'
driver.get(url)

# %%
airline_tag=driver.find_elements("xpath",'//span[@class="i-b text ellipsis"]')
len(airline_tag)
# Out:
# 46

# %%
Airlines=[]
for i in airline_tag:
    Airlines.append(i.text)
Airlines
# Out:
# ['IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air Asia',
#  'IndiGo',
#  'Air Asia',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Air India',
#  'Air India',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara']

# %%
source_tag=driver.find_elements('xpath','//p[@class="fs-10 font-lightgrey no-wrap city ellipsis"]')
len(source_tag)
# Out:
# 92

# %%
sources=[]
for i in source_tag:
    sources.append(i.text)
sources
# Out:
# ['Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
#  'Kolkata',
#  'Bangalore',
# ...

# %%
list1 = [sources[i] for i in range(len(sources)) if i % 2 != 0]
list1
# Out:
# ['Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore',
#  'Bangalore']

# %%
list2=sources[::2]
list2
# Out:
# ['Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata',
#  'Kolkata']

# %%
arr_tag=driver.find_elements("xpath",'//div[@class="fs-15 bold time"]')
len(arr_tag)
# Out:
# 46

# %%
Arri_t=[]
for i in arr_tag:
    Arri_t.append(i.text)
Arri_t
# Out:
# ['18:45',
#  '19:55',
#  '21:20',
#  '20:25',
#  '23:10',
#  '18:40',
#  '20:35',
#  '20:35',
#  '20:20',
#  '20:20',
#  '18:45',
#  '18:45',
#  '20:20',
#  '18:45',
#  '20:20',
#  '18:45',
#  '20:20',
#  '18:45',
#  '20:15',
#  '20:15',
#  '20:15',
#  '20:15',
#  '20:20',
#  '20:20',
#  '18:45',
#  '20:20',
#  '18:45',
#  '20:20',
#  '18:45',
#  '20:15',
#  '20:15',
#  '20:20',
#  '20:20',
#  '18:45',
#  '18:45',
#  '23:55',
#  '20:20',
#  '20:20',
#  '18:45',
#  '18:45',
#  '20:20',
#  '18:45',
#  '20:35',
#  '20:35',
#  '20:20',
#  '18:45']

# %%
dep_tag=driver.find_elements("xpath",'//p[@class="bold fs-15 mb-2 pr time"]')
len(dep_tag)
# Out:
# 46

# %%
Depa_t=[]
for i in dep_tag:
    Depa_t.append(i.text)
Depa_t
# Out:
# ['21:05',
#  '22:25',
#  '23:50',
#  '23:10',
#  '09:30\n+ 1 day',
#  '22:30',
#  '17:45\n+ 1 day',
#  '19:15\n+ 1 day',
#  '21:50\n+ 1 day',
#  '21:50\n+ 1 day',
#  '21:50\n+ 1 day',
#  '21:50\n+ 1 day',
#  '09:00\n+ 1 day',
#  '09:00\n+ 1 day',
#  '17:05\n+ 1 day',
#  '17:05\n+ 1 day',
#  '18:50\n+ 1 day',
#  '18:50\n+ 1 day',
#  '08:55\n+ 1 day',
#  '18:20\n+ 1 day',
#  '20:15\n+ 1 day',
#  '00:05\n+ 2 days',
#  '22:40\n+ 1 day',
#  '23:20\n+ 1 day',
#  '22:40\n+ 1 day',
#  '10:50\n+ 1 day',
#  '10:50\n+ 1 day',
#  '20:25\n+ 1 day',
#  '20:25\n+ 1 day',
#  '10:30\n+ 1 day',
#  '16:15\n+ 1 day',
#  '17:45\n+ 1 day',
#  '17:45\n+ 1 day',
#  '17:45\n+ 1 day',
#  '17:45\n+ 1 day',
#  '09:55\n+ 1 day',
#  '19:15\n+ 1 day',
#  '19:15\n+ 1 day',
#  '19:15\n+ 1 day',
#  '19:15\n+ 1 day',
#  '11:50\n+ 1 day',
#  '11:50\n+ 1 day',
#  '07:50\n+ 1 day',
#  '10:45\n+ 1 day',
#  '10:45\n+ 1 day',
#  '10:45\n+ 1 day']

# %%
total_s=driver.find_elements("xpath",'//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')
len(total_s)
# Out:
# 46

# %%
Total_s=[]
for i in total_s:
    Total_s.append(i.text)
Total_s
# Out:
# ['Non Stop',
#  'Non Stop',
#  'Non Stop',
#  'Non Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '2 Stop(s)',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '1 Stop',
#  '2 Stop(s)',
#  '2 Stop(s)']

# %%
cost_tag=driver.find_elements("xpath",'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
len(cost_tag)
# Out:
# 46

# %%
prices=[]
for i in cost_tag:
    prices.append(i.text)
prices
# Out:
# ['9,132',
#  '9,132',
#  '9,132',
#  '9,132',
#  '9,132',
#  '11,758',
#  '12,784',
#  '12,784',
#  '12,790',
#  '12,790',
#  '12,790',
#  '12,790',
#  '13,075',
#  '13,075',
#  '13,075',
#  '13,075',
#  '13,075',
#  '13,075',
#  '13,542',
#  '13,542',
#  '13,542',
#  '13,542',
#  '13,813',
#  '13,813',
#  '13,813',
#  '14,621',
#  '14,621',
#  '14,621',
#  '14,621',
#  '16,272',
#  '16,272',
#  '17,303',
#  '17,303',
#  '17,303',
#  '17,303',
#  '17,658',
#  '17,975',
#  '17,975',
#  '17,975',
#  '17,975',
#  '19,107',
#  '19,107',
#  '24,357',
#  '24,357',
#  '25,115',
#  '25,115']

# %%
duration_tag=driver.find_elements("xpath",'//p[@class="fs-12 bold du mb-2"]')
len(duration_tag)
# Out:
# 46

# %%
Duration=[]
for i in duration_tag:
    Duration.append(i.text)
Duration
# Out:
# ['2h 20m',
#  '2h 30m',
#  '2h 30m',
#  '2h 45m',
#  '10h 20m',
#  '3h 50m',
#  '21h 10m',
#  '22h 40m',
#  '25h 30m',
#  '25h 30m',
#  '27h 05m',
#  '27h 05m',
#  '12h 40m',
#  '14h 15m',
#  '20h 45m',
#  '22h 20m',
#  '22h 30m',
#  '24h 05m',
#  '12h 40m',
#  '22h 05m',
#  '24h 00m',
#  '27h 50m',
#  '26h 20m',
#  '27h 00m',
#  '27h 55m',
#  '14h 30m',
#  '16h 05m',
#  '24h 05m',
#  '25h 40m',
#  '14h 15m',
#  '20h 00m',
#  '21h 25m',
#  '21h 25m',
#  '23h 00m',
#  '23h 00m',
#  '10h 00m',
#  '22h 55m',
#  '22h 55m',
#  '24h 30m',
#  '24h 30m',
#  '15h 30m',
#  '17h 05m',
#  '11h 15m',
#  '14h 10m',
#  '14h 25m',
#  '16h 00m']

# %%
add_tag=driver.find_elements("xpath",'//span[@class="text"]')
len(add_tag)
# Out:
# 39

# %%
Add_info=[]
for i in add_tag:
    Add_info.append(i.text)

# %%
flights11 = pd.DataFrame({})
flights11['Airline'] = Airlines
flights11['Destination'] = list1
flights11['Source'] = list2
flights11['Arrival_time'] = Arri_t
flights11['Departure_time'] =Depa_t
flights11['Total_Stops']=Total_s
flights11['Total_Duration'] = Duration
flights11['Additional_Info'] = pd.Series(Add_info)
flights11['Price']=prices
flights11.head()
# Out:
#     Airline Destination   Source Arrival_time  Departure_time Total_Stops  \
# 0    IndiGo   Bangalore  Kolkata        18:45           21:05    Non Stop
# 1    IndiGo   Bangalore  Kolkata        19:55           22:25    Non Stop
# 2    IndiGo   Bangalore  Kolkata        21:20           23:50    Non Stop
# 3  Air Asia   Bangalore  Kolkata        20:25           23:10    Non Stop
# 4    IndiGo   Bangalore  Kolkata        23:10  09:30\n+ 1 day      1 Stop
#
#   Total_Duration Additional_Info  Price
# 0         2h 20m       Free Meal  9,132
# 1         2h 30m       Free Meal  9,132
# 2         2h 30m       Free Meal  9,132
# 3         2h 45m       Free Meal  9,132
# 4        10h 20m       Free Meal  9,132

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=HYD&destinationCountry=IN&flexi=0&flight_depart_date=21%2F09%2F2022&hb=0&noOfSegments=1&origin=BOM&originCountry=IN&type=O&unique=1663673433891&viewName=normal'
driver.get(url)

# %%
airline_tag=driver.find_elements("xpath",'//span[@class="i-b text ellipsis"]')
len(airline_tag)
# Out:
# 87

# %%
Airline=[]
for i in airline_tag:
    Airline.append(i.text)

# %%
source_tag=driver.find_elements('xpath','//p[@class="fs-10 font-lightgrey no-wrap city ellipsis"]')
len(source_tag)
# Out:
# 174

# %%
sources=[]
for i in source_tag:
    sources.append(i.text)

# %%
list1 = [sources[i] for i in range(len(sources)) if i % 2 != 0]
len(list1)
# Out:
# 87

# %%
list2=sources[::2]
len(list2)
# Out:
# 87

# %%
arr_tag=driver.find_elements("xpath",'//div[@class="fs-15 bold time"]')
len(arr_tag)
# Out:
# 87

# %%
Arri_t=[]
for i in arr_tag:
    Arri_t.append(i.text)

# %%
dep_tag=driver.find_elements("xpath",'//p[@class="bold fs-15 mb-2 pr time"]')
len(dep_tag)
# Out:
# 87

# %%
Depa_t=[]
for i in dep_tag:
    Depa_t.append(i.text)

# %%
total_s=driver.find_elements("xpath",'//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')
len(total_s)
# Out:
# 87

# %%
Total_s=[]
for i in total_s:
    Total_s.append(i.text)

# %%
cost_tag=driver.find_elements("xpath",'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
len(cost_tag)
# Out:
# 87

# %%
prices=[]
for i in cost_tag:
    prices.append(i.text)

# %%
duration_tag=driver.find_elements("xpath",'//p[@class="fs-12 bold du mb-2"]')
len(duration_tag)
# Out:
# 87

# %%
Duration=[]
for i in duration_tag:
    Duration.append(i.text)

# %%
add_tag=driver.find_elements("xpath",'//span[@class="text"]')
len(add_tag)
# Out:
# 64

# %%
Add_info=[]
for i in add_tag:
    Add_info.append(i.text)

# %%
flights12 = pd.DataFrame({})
flights12['Airline'] = Airlines
flights12['Destination'] = list1
flights12['Source'] = list2
flights12['Arrival_time'] = Arri_t
flights12['Departure_time'] =Depa_t
flights12['Total_Stops']=Total_s
flights12['Total_Duration'] = Duration
flights12['Additional_Info'] = pd.Series(Add_info)
flights12['Price']=prices
flights12.head()
# Out:
#      Airline Destination  Source Arrival_time Departure_time Total_Stops  \
# 0   Go First   Hyderabad  Mumbai        22:30          23:55    Non Stop
# 1     IndiGo   Hyderabad  Mumbai        14:10          15:30    Non Stop
# 2    Vistara   Hyderabad  Mumbai        21:20          22:40    Non Stop
# 3     IndiGo   Hyderabad  Mumbai        06:05          07:30    Non Stop
# 4  Air India   Hyderabad  Mumbai        11:05          12:30    Non Stop
#
#   Total_Duration Additional_Info  Price
# 0         1h 25m       Free Meal  4,262
# 1         1h 20m       Free Meal  4,263
# 2         1h 20m       Free Meal  4,263
# 3         1h 25m       Free Meal  4,263
# 4         1h 25m       Free Meal  4,263

# %%
Flights3=pd.concat([flights10,flights11,flights12],ignore_index=True)

# %%
Flights3.shape
# Out:
# (178, 9)

# %%
Airline1=pd.concat([Flights2,Flights3],ignore_index=True)

# %%
Airline1.shape
# Out:
# (1192, 9)

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=HYD&destinationCountry=IN&flexi=0&flight_depart_date=22%2F09%2F2022&hb=0&noOfSegments=1&origin=PNQ&originCountry=IN&type=O&unique=1663674901778&viewName=normal'
driver.get(url)

# %%
airline_tag=driver.find_elements("xpath",'//span[@class="i-b text ellipsis"]')
len(airline_tag)
# Out:
# 77

# %%
Airline=[]
for i in airline_tag:
    Airline.append(i.text)

# %%
source_tag=driver.find_elements('xpath','//p[@class="fs-10 font-lightgrey no-wrap city ellipsis"]')
len(source_tag)
# Out:
# 154

# %%
sources=[]
for i in source_tag:
    sources.append(i.text)

# %%
list1 = [sources[i] for i in range(len(sources)) if i % 2 != 0]
len(list1)
# Out:
# 77

# %%
list2=sources[::2]
len(list2)
# Out:
# 77

# %%
arr_tag=driver.find_elements("xpath",'//div[@class="fs-15 bold time"]')
len(arr_tag)
# Out:
# 77

# %%
Arri_t=[]
for i in arr_tag:
    Arri_t.append(i.text)

# %%
dep_tag=driver.find_elements("xpath",'//p[@class="bold fs-15 mb-2 pr time"]')
len(dep_tag)
# Out:
# 77

# %%
Depa_t=[]
for i in dep_tag:
    Depa_t.append(i.text)

# %%
total_s=driver.find_elements("xpath",'//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')
len(total_s)
# Out:
# 77

# %%
Total_s=[]
for i in total_s:
    Total_s.append(i.text)

# %%
cost_tag=driver.find_elements("xpath",'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
len(cost_tag)
# Out:
# 77

# %%
prices=[]
for i in cost_tag:
    prices.append(i.text)

# %%
duration_tag=driver.find_elements("xpath",'//p[@class="fs-12 bold du mb-2"]')
len(duration_tag)
# Out:
# 77

# %%
Duration=[]
for i in duration_tag:
    Duration.append(i.text)

# %%
add_tag=driver.find_elements("xpath",'//span[@class="text"]')
len(add_tag)
# Out:
# 50

# %%
Add_info=[]
for i in add_tag:
    Add_info.append(i.text)

# %%
flights13 = pd.DataFrame({})
flights13['Airline'] = Airline
flights13['Destination'] = list1
flights13['Source'] = list2
flights13['Arrival_time'] = Arri_t
flights13['Departure_time'] =Depa_t
flights13['Total_Stops']=Total_s
flights13['Total_Duration'] = Duration
flights13['Additional_Info'] = pd.Series(Add_info)
flights13['Price']=prices
flights13.head()
# Out:
#         Airline Destination Source Arrival_time Departure_time Total_Stops  \
# 0        IndiGo   Hyderabad   Pune        06:25          07:35    Non Stop
# 1        IndiGo   Hyderabad   Pune        00:05          01:20    Non Stop
# 2        IndiGo   Hyderabad   Pune        13:55          15:10    Non Stop
# 3        IndiGo   Hyderabad   Pune        17:50          19:05    Non Stop
# 4  Alliance Air   Hyderabad   Pune        21:30          23:10    Non Stop
#
#   Total_Duration Additional_Info  Price
# 0         1h 10m    No Meal Fare  4,578
# 1         1h 15m       Free Meal  4,578
# 2         1h 15m       Free Meal  4,578
# 3         1h 15m       Free Meal  4,578
# 4         1h 40m       Free Meal  4,578

# %%
# Connecting to the webdriver.

driver = webdriver.Chrome(r'C:\Users\91749\Downloads\chromedriver_win32\chromedriver.exe')

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=HYD&destinationCountry=IN&flexi=0&flight_depart_date=22%2F09%2F2022&hb=0&noOfSegments=1&origin=BLR&originCountry=IN&type=O&unique=1317858004036&version=1.2&viewName=normal'
driver.get(url)

# %%
airline_tag=driver.find_elements("xpath",'//span[@class="i-b text ellipsis"]')
len(airline_tag)
# Out:
# 102

# %%
Airline=[]
for i in airline_tag:
    Airline.append(i.text)

# %%
source_tag=driver.find_elements('xpath','//p[@class="fs-10 font-lightgrey no-wrap city ellipsis"]')
len(source_tag)
# Out:
# 204

# %%
sources=[]
for i in source_tag:
    sources.append(i.text)

# %%
list1 = [sources[i] for i in range(len(sources)) if i % 2 != 0]
len(list1)
# Out:
# 102

# %%
list2=sources[::2]
len(list2)
# Out:
# 102

# %%
arr_tag=driver.find_elements("xpath",'//div[@class="fs-15 bold time"]')
len(arr_tag)
# Out:
# 102

# %%
Arri_t=[]
for i in arr_tag:
    Arri_t.append(i.text)

# %%
dep_tag=driver.find_elements("xpath",'//p[@class="bold fs-15 mb-2 pr time"]')
len(dep_tag)
# Out:
# 102

# %%
Depa_t=[]
for i in dep_tag:
    Depa_t.append(i.text)

# %%
total_s=driver.find_elements("xpath",'//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')
len(total_s)
# Out:
# 102

# %%
Total_s=[]
for i in total_s:
    Total_s.append(i.text)

# %%
cost_tag=driver.find_elements("xpath",'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
len(cost_tag)
# Out:
# 102

# %%
prices=[]
for i in cost_tag:
    prices.append(i.text)

# %%
duration_tag=driver.find_elements("xpath",'//p[@class="fs-12 bold du mb-2"]')
len(duration_tag)
# Out:
# 102

# %%
Duration=[]
for i in duration_tag:
    Duration.append(i.text)

# %%
add_tag=driver.find_elements("xpath",'//span[@class="text"]')
len(add_tag)
# Out:
# 66

# %%
Add_info=[]
for i in add_tag:
    Add_info.append(i.text)

# %%
flights14 = pd.DataFrame({})
flights14['Airline'] = Airline
flights14['Destination'] = list1
flights14['Source'] = list2
flights14['Arrival_time'] = Arri_t
flights14['Departure_time'] =Depa_t
flights14['Total_Stops']=Total_s
flights14['Total_Duration'] = Duration
flights14['Additional_Info'] = pd.Series(Add_info)
flights14['Price']=prices
flights14.head()
# Out:
#         Airline Destination     Source Arrival_time Departure_time  \
# 0  Alliance Air   Hyderabad  Bangalore        08:35          10:10
# 1      Go First   Hyderabad  Bangalore        15:35          16:45
# 2      Air Asia   Hyderabad  Bangalore        14:25          15:40
# 3      Air Asia   Hyderabad  Bangalore        16:15          17:30
# 4        IndiGo   Hyderabad  Bangalore        16:00          16:55
#
#   Total_Stops Total_Duration Additional_Info  Price
# 0    Non Stop         1h 35m    No Meal Fare  3,269
# 1    Non Stop         1h 10m    No Meal Fare  4,532
# 2    Non Stop         1h 15m       Free Meal  4,532
# 3    Non Stop         1h 15m       Free Meal  4,532
# 4    Non Stop         0h 55m       Free Meal  4,534

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=GOI&destinationCountry=IN&flexi=0&flight_depart_date=22%2F09%2F2022&hb=0&noOfSegments=1&origin=BLR&originCountry=IN&type=O&unique=622986798458&version=1.2&viewName=normal'
driver.get(url)

# %%
airline_tag=driver.find_elements("xpath",'//span[@class="i-b text ellipsis"]')
len(airline_tag)
# Out:
# 74

# %%
Airline=[]
for i in airline_tag:
    Airline.append(i.text)

# %%
source_tag=driver.find_elements('xpath','//p[@class="fs-10 font-lightgrey no-wrap city ellipsis"]')
len(source_tag)
# Out:
# 148

# %%
sources=[]
for i in source_tag:
    sources.append(i.text)

# %%
list1 = [sources[i] for i in range(len(sources)) if i % 2 != 0]
len(list1)
# Out:
# 74

# %%
list2=sources[::2]
len(list2)
# Out:
# 74

# %%
arr_tag=driver.find_elements("xpath",'//div[@class="fs-15 bold time"]')
len(arr_tag)
# Out:
# 74

# %%
Arri_t=[]
for i in arr_tag:
    Arri_t.append(i.text)

# %%
dep_tag=driver.find_elements("xpath",'//p[@class="bold fs-15 mb-2 pr time"]')
len(dep_tag)
# Out:
# 74

# %%
Depa_t=[]
for i in dep_tag:
    Depa_t.append(i.text)

# %%
total_s=driver.find_elements("xpath",'//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')
len(total_s)
# Out:
# 74

# %%
Total_s=[]
for i in total_s:
    Total_s.append(i.text)

# %%
cost_tag=driver.find_elements("xpath",'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
len(cost_tag)
# Out:
# 74

# %%
prices=[]
for i in cost_tag:
    prices.append(i.text)

# %%
duration_tag=driver.find_elements("xpath",'//p[@class="fs-12 bold du mb-2"]')
len(duration_tag)
# Out:
# 74

# %%
Duration=[]
for i in duration_tag:
    Duration.append(i.text)

# %%
add_tag=driver.find_elements("xpath",'//span[@class="text"]')
len(add_tag)
# Out:
# 55

# %%
Add_info=[]
for i in add_tag:
    Add_info.append(i.text)

# %%
flights15= pd.DataFrame({})
flights15['Airline'] = Airline
flights15['Destination'] = list1
flights15['Source'] = list2
flights15['Arrival_time'] = Arri_t
flights15['Departure_time'] =Depa_t
flights15['Total_Stops']=Total_s
flights15['Total_Duration'] = Duration
flights15['Additional_Info'] = pd.Series(Add_info)
flights15['Price']=prices
flights15.head()
# Out:
#     Airline Destination     Source Arrival_time  Departure_time Total_Stops  \
# 0  SpiceJet         Goa  Bangalore        20:00           21:25    Non Stop
# 1  Air Asia         Goa  Bangalore        23:40  00:45\n+ 1 day    Non Stop
# 2  Air Asia         Goa  Bangalore        04:35           05:55    Non Stop
# 3    IndiGo         Goa  Bangalore        21:30           22:40    Non Stop
# 4    IndiGo         Goa  Bangalore        19:25           20:40    Non Stop
#
#   Total_Duration Additional_Info  Price
# 0         1h 25m       Free Meal  4,691
# 1         1h 05m       Free Meal  5,370
# 2         1h 20m       Free Meal  5,370
# 3         1h 10m       Free Meal  5,479
# 4         1h 15m       Free Meal  6,214

# %%
Airline2=pd.concat([flights13,flights14,flights15],ignore_index=True)

# %%
Airline3=pd.concat([Airline1,Airline2],ignore_index=True)

# %%
Airline3.shape
# Out:
# (1417, 9)

# %%
# Connecting to the webdriver.

driver = webdriver.Chrome(r'C:\Users\91749\Downloads\chromedriver_win32\chromedriver.exe')

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=MAA&originCountry=IN&destination=GOI&destinationCountry=IN&flight_depart_date=22%2F09%2F2022&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=118126787093'
driver.get(url)

# %%
airline_tag=driver.find_elements("xpath",'//span[@class="i-b text ellipsis"]')
len(airline_tag)
# Out:
# 74

# %%
Airline=[]
for i in airline_tag:
    Airline.append(i.text)

# %%
source_tag=driver.find_elements('xpath','//p[@class="fs-10 font-lightgrey no-wrap city ellipsis"]')
len(source_tag)
# Out:
# 148

# %%
sources=[]
for i in source_tag:
    sources.append(i.text)

# %%
list1 = [sources[i] for i in range(len(sources)) if i % 2 != 0]
len(list1)
# Out:
# 74

# %%
list2=sources[::2]
len(list2)
# Out:
# 74

# %%
arr_tag=driver.find_elements("xpath",'//div[@class="fs-15 bold time"]')
len(arr_tag)
# Out:
# 74

# %%
Arri_t=[]
for i in arr_tag:
    Arri_t.append(i.text)

# %%
dep_tag=driver.find_elements("xpath",'//p[@class="bold fs-15 mb-2 pr time"]')
len(dep_tag)
# Out:
# 74

# %%
Depa_t=[]
for i in dep_tag:
    Depa_t.append(i.text)

# %%
total_s=driver.find_elements("xpath",'//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')
len(total_s)
# Out:
# 74

# %%
Total_s=[]
for i in total_s:
    Total_s.append(i.text)

# %%
cost_tag=driver.find_elements("xpath",'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
len(cost_tag)
# Out:
# 74

# %%
prices=[]
for i in cost_tag:
    prices.append(i.text)

# %%
duration_tag=driver.find_elements("xpath",'//p[@class="fs-12 bold du mb-2"]')
len(duration_tag)
# Out:
# 74

# %%
Duration=[]
for i in duration_tag:
    Duration.append(i.text)

# %%
add_tag=driver.find_elements("xpath",'//span[@class="text"]')
len(add_tag)
# Out:
# 37

# %%
Add_info=[]
for i in add_tag:
    Add_info.append(i.text)

# %%
flights16= pd.DataFrame({})
flights16['Airline'] = Airline
flights16['Destination'] = list1
flights16['Source'] = list2
flights16['Arrival_time'] = Arri_t
flights16['Departure_time'] =Depa_t
flights16['Total_Stops']=Total_s
flights16['Total_Duration'] = Duration
flights16['Additional_Info'] = pd.Series(Add_info)
flights16['Price']=prices
flights16.head()
# Out:
#      Airline Destination   Source Arrival_time  Departure_time Total_Stops  \
# 0   SpiceJet         Goa  Chennai        22:00  03:15\n+ 1 day      1 Stop
# 1   SpiceJet         Goa  Chennai        22:00  17:05\n+ 1 day      1 Stop
# 2     IndiGo         Goa  Chennai        22:20  06:15\n+ 1 day      1 Stop
# 3  Air India         Goa  Chennai        15:25           22:20      1 Stop
# 4  Air India         Goa  Chennai        21:40  22:20\n+ 1 day      1 Stop
#
#   Total_Duration Additional_Info  Price
# 0         5h 15m       Free Meal  7,198
# 1        19h 05m       Free Meal  7,198
# 2         7h 55m       Free Meal  7,476
# 3         6h 55m       Free Meal  7,587
# 4        24h 40m       Free Meal  7,587

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=CCU&destinationCountry=IN&flexi=0&flight_depart_date=22%2F09%2F2022&hb=0&noOfSegments=1&origin=MAA&originCountry=IN&type=O&unique=708820920668&version=1.4&viewName=normal'
driver.get(url)

# %%
airline_tag=driver.find_elements("xpath",'//span[@class="i-b text ellipsis"]')
len(airline_tag)
# Out:
# 101

# %%
Airline=[]
for i in airline_tag:
    Airline.append(i.text)

# %%
source_tag=driver.find_elements('xpath','//p[@class="fs-10 font-lightgrey no-wrap city ellipsis"]')
len(source_tag)
# Out:
# 202

# %%
sources=[]
for i in source_tag:
    sources.append(i.text)

# %%
list1 = [sources[i] for i in range(len(sources)) if i % 2 != 0]
len(list1)
# Out:
# 101

# %%
list2=sources[::2]
len(list2)
# Out:
# 101

# %%
arr_tag=driver.find_elements("xpath",'//div[@class="fs-15 bold time"]')
len(arr_tag)
# Out:
# 101

# %%
Arri_t=[]
for i in arr_tag:
    Arri_t.append(i.text)

# %%
dep_tag=driver.find_elements("xpath",'//p[@class="bold fs-15 mb-2 pr time"]')
len(dep_tag)
# Out:
# 101

# %%
Depa_t=[]
for i in dep_tag:
    Depa_t.append(i.text)

# %%
total_s=driver.find_elements("xpath",'//div[@class=" font-lightgrey fs-10 tipsy i-b fs-10"]')
len(total_s)
# Out:
# 101

# %%
Total_s=[]
for i in total_s:
    Total_s.append(i.text)

# %%
cost_tag=driver.find_elements("xpath",'//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
len(cost_tag)
# Out:
# 101

# %%
prices=[]
for i in cost_tag:
    prices.append(i.text)

# %%
duration_tag=driver.find_elements("xpath",'//p[@class="fs-12 bold du mb-2"]')
len(duration_tag)
# Out:
# 101

# %%
Duration=[]
for i in duration_tag:
    Duration.append(i.text)

# %%
add_tag=driver.find_elements("xpath",'//span[@class="text"]')
len(add_tag)
# Out:
# 57

# %%
Add_info=[]
for i in add_tag:
    Add_info.append(i.text)

# %%
flights17= pd.DataFrame({})
flights17['Airline'] = Airline
flights17['Destination'] = list1
flights17['Source'] = list2
flights17['Arrival_time'] = Arri_t
flights17['Departure_time'] =Depa_t
flights17['Total_Stops']=Total_s
flights17['Total_Duration'] = Duration
flights17['Additional_Info'] = pd.Series(Add_info)
flights17['Price']=prices
flights17.head()
# Out:
#     Airline Destination   Source Arrival_time  Departure_time Total_Stops  \
# 0  SpiceJet     Kolkata  Chennai        08:30           14:55      1 Stop
# 1  SpiceJet     Kolkata  Chennai        18:00  09:05\n+ 1 day      1 Stop
# 2  SpiceJet     Kolkata  Chennai        22:00  21:30\n+ 1 day      1 Stop
# 3  SpiceJet     Kolkata  Chennai        12:05  14:55\n+ 1 day      1 Stop
# 4  SpiceJet     Kolkata  Chennai        18:00  21:00\n+ 1 day      1 Stop
#
#   Total_Duration Additional_Info  Price
# 0         6h 25m       Free Meal  7,618
# 1        15h 05m       Free Meal  7,618
# 2        23h 30m       Free Meal  7,618
# 3        26h 50m       Free Meal  7,618
# 4        27h 00m       Free Meal  7,618

# %%
Airline4=pd.concat([flights16,flights17,Airline3],ignore_index=True)

# %%
Airline4.shape
# Out:
# (1592, 9)

# %% [markdown]
# # Saving the scrapped data into csv and excel format

# %%
Airline4.to_csv('Flight_data.csv')

# %%
Airline4.to_excel('Flights_data.xlsx')
